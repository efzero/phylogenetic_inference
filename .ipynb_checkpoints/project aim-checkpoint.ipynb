# %%
import numpy as np
import pandas as pd
import numpy.linalg as la

# %%
states = [['C', 'C'],['A', 'G'], ['T', 1], ['T', 2], ['A', 4], [3,5], ['A', 6]]

# %%
[]

# %% [markdown]
# $$ P(x, t | \tau) = P(x| t, \tau)P(t | \tau) $$

# %% [markdown]
# ![Screen%20Shot%202022-02-03%20at%2010.09.47%20PM.png](attachment:Screen%20Shot%202022-02-03%20at%2010.09.47%20PM.png)

# %% [markdown]
# # def pxtgiventau(likelihood, coa)
# n: number of leaves
#
# coalescent_times should from 0 to tn, tn-1, ..., t2,
# tk: the time that number of coalescents decreases from k to k -1
#
# t2 is the largest, tk is the smallest
# t2,...,tk

# %%
1/(kchoose2(2)/10), 1/(kchoose2(3)/10), 1/(kchoose2(4)/10)
# Out:
# (10.0, 3.3333333333333335, 1.6666666666666667)

# %%
# coalescent_times[0] - coalescent_times[1]
# Out:
# 0
# 1

# %%
distribution of t is exponential, but 


hence p(t) is exponential(lambda_)
q(t) should be exponential(lambda_2)

# %%
def prior_coalescent(coalescent_times, Ne):
    
    ###########lambdas have already been fixed
    ld_true = [kchoose2(i+2)/Ne for i in range(len(coalescent_times))]
    prior = q_coalescent_time_prior(coalescent_times, ld_true)
    
    return prior


def pxtgiventau(likelihood, coalescent_times, Ne):

    prior = prior_coalescent(coalescent_times, Ne)
    return prior*likelihood
    
    
###model delta_x as exponential distribution
def exponential_distribution(lambda_, t):
    return lambda_ * np.exp(-lambda_ * t)
    
    #####assume that each delta t distribution based on the formula above
    
def kchoose2(k):
    if k == 1:
        return 1
    else:
        return k*(k-1)/2
    
def q_coalescent_time_prior(coalescent_times, lambdas_):
    
    #####coalescent_times: large to small, q[0] represents deltat[0]
    
    time_diff = []
    for i in range(len(coalescent_times) - 1):
        time_diff.append(coalescent_times[i] - coalescent_times[i+1])
        
    time_diff.append(coalescent_times[-1])
    q = 1
    for i in range(len(time_diff)):
        q = q*exponential_distribution(lambdas_[i], time_diff[i])
    return q

# %%
coalescent_times = [4,3.5,2]
time_diff = []
for i in range(len(coalescent_times) - 1):
    time_diff.append(coalescent_times[i] - coalescent_times[i+1])

time_diff.append(coalescent_times[-1])
time_diff
ld_true = [.7,1.3,1.7]
ld_true = [1,1,1]
q_coalescent_time_prior(coalescent_times, ld_true)
ld_true = [1/.7,1/1.3,1/1.8]
q_coalescent_time_prior(coalescent_times, ld_true)
# Out:
# [0.5, 1.5, 2]
# [0.5, 1.5, 2]
# 0.03103253947027161

# %%
[kchoose2(2)/3, kchoose2(3)/3, kchoose2(4)/3]
# Out:
# [0.3333333333333333, 1.0, 2.0]

# %%
def black_box_vi(states, Ne, n):
    
    
    
    log_lr = []

    lambdas_ = np.ones(n)
    coalescent_times = [4,3.5,2]
#     ld_true = [1/.7, 1/1.3, 1/1.8]
    ld_true = [kchoose2(2)/Ne, kchoose2(3)/Ne, kchoose2(4)/Ne]
    for k in range(1000):
        total_grad = 0
        gap = 0
        for i in range(50):

            zs = [] ####simulated coalescent times
            for j in range(len(lambdas_)):
                z = np.random.exponential(scale = lambdas_[j])
                zs.append(z)
            zs = np.array(zs)
            c_time = np.cumsum(zs[::-1])[::-1] ####large to small
            l_ = likelihood(states, len(states), c_time[::-1])
#             pxz = prior_coalescent(c_time, Ne)
            pxz = pxtgiventau(l_, c_time, Ne)
#             pxz = q_coalescent_time_prior(c_time, ld_true)
            pq = q_coalescent_time_prior(c_time, lambdas_)
            log_pxz, log_pq = np.log(pxz), np.log(pq)
            gap += log_pxz - log_pq
            grad = (1/lambdas_ - zs)
            total_sc_grad = grad*(log_pxz - log_pq)
            total_grad += total_sc_grad
        total_grad /=50
        gap /= 50
        log_lr.append(gap)
        print(gap, "gap")
        lambdas_ = lambdas_ + r_m_sequence(k)/5*total_grad
        lambdas_ = (lambdas_ > 0) * lambdas_ + 1*(lambdas_ <= 0) ###stabilizer
        print(lambdas_)
        
    return lambdas_, log_lr
        
        

def r_m_sequence(t, tau = .99, kappa= -1):
    return (t+tau)**kappa


def compute_likelihood(states, site, subroot, coalescent_times):

    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    left_child_likelihood, right_child_likelihood = 0,0
    left_t, right_t = -1,-1
    
    
    if type(left_child) not in [int, float]:
        init_state = np.zeros(4)
        init_state[mmap[left_child]] = 1
        left_child_likelihood = init_state
        left_t = coalescent_times[subroot-1]
    
    else:   
        left_child_likelihood = compute_likelihood(states, site, left_child, coalescent_times)
        left_t = coalescent_times[subroot-1] - coalescent_times[left_child-1] 
        
    if type(right_child) not in [int, float]:
        init_state = np.zeros(4)
        init_state[mmap[right_child]] = 1
        right_t = coalescent_times[subroot-1]
        right_child_likelihood = init_state
        
        ###gradient corresponding to coalescent time?
        ###have the
    else:
        
        right_child_likelihood = compute_likelihood(states, site, right_child, coalescent_times)
        right_t = coalescent_times[subroot-1] - coalescent_times[right_child-1]   
    likelihood = (Pij(left_t, evecs, evals, evec_inv)@left_child_likelihood) *\
    (Pij(right_t, evecs, evals, evec_inv)@right_child_likelihood)
    return likelihood

def likelihood(states, root, coalescent_times):
    
    """
    root is the number of leaves - 1
    
    """
    likelihood_vec = compute_likelihood(states, 0, root, coalescent_times)
    final_likelihood = 0.25*np.sum(likelihood_vec)
    return final_likelihood

def Pij(t, evecs, evals, evec_inv):
    return evecs@np.diag(np.exp(evals*t))@evec_inv

# %%
n = 3
# states = [['C', 'C'],['A', 'G'], ['T', 1], ['T', 2], ['A', 4], [3,5], ['A', 6]]
# coalescent_times = [.15, .6, 2]
states = [['A', 'A'],['C', 'T'], [1, 2]]
mmap = {'A':0, 'C':1, 'G':2, 'T':3}
q = np.ones((4,4))/3
for i in range(4):
    q[i,i]= -1
evals, evecs = la.eig(q)
evec_inv = la.inv(evecs)
lbs = black_box_vi(states, 3, len(states))
# Out:
# -6.045505698155647 gap
# [0.90436287 0.84279921 1.37575248]
# -6.302118676069549 gap
# [0.69506592 0.69448446 1.94855828]
# -5.8144310556472245 gap
# [0.33798528 0.36952194 2.55139815]
# -3.380085154438417 gap
# [1.         1.         2.79978994]
# -3.8491297365614954 gap
# [0.98602999 1.00949941 2.81531971]
# -3.829712695051077 gap
# [0.97779284 1.04579315 2.97170482]
# -3.080044659775409 gap
# [0.98021054 1.05298501 3.02953997]
# -3.1225988860618643 gap
# [0.96727024 1.05846994 2.97722877]
# -3.5745048757085187 gap
# [0.95143376 1.06306403 3.04601907]
# -2.358504688577925 gap
# [0.9320793  1.06409898 2.97448457]
# -3.790623161573901 gap
# [0.90574689 1.08868457 2.99898667]
# -3.719829029498469 gap
# [0.87748713 1.08678244 3.04739584]
# -3.118348791867557 gap
# [0.85252645 1.07886432 3.04647981]
# -3.0603894842422408 gap
# [0.83025027 1.09706898 2.9370466 ]
# -3.468222554508222 gap
# [0.81044771 1.10119585 2.90274704]
# -2.9607519695728866 gap
# [0.79895831 1.10269886 2.89856005]
# -3.362951054366621 gap
# [0.77720244 1.10796508 2.94842598]
# -3.7547025751997514 gap
# [0.75819016 1.10774785 2.97840908]
# -3.4805953130672713 gap
# [0.73100426 1.1058557  3.00810687]
# -2.772983194135181 gap
# [0.71430024 1.11355865 3.00962657]
# -3.3553201524372467 gap
# [0.69952315 1.1080583  3.0010063 ]
# -3.5481345538110416 gap
# [0.67198439 1.10247869 3.02696776]
# -2.619928356427881 gap
# [0.64679665 1.09946016 2.9952443 ]
# -3.6170966194265954 gap
# [0.62048769 1.10131141 3.02230766]
# -3.6921638083109927 gap
# [0.5860173  1.11444875 3.05731471]
# -3.3098004646802406 gap
# [0.55797979 1.1152601  3.06634017]
# -2.211797056395115 gap
# [0.5383332  1.12006851 3.01562081]
# -2.8888401829909647 gap
# [0.51649567 1.11902862 3.02322747]
# -3.176244435104022 gap
# [0.48634207 1.12930683 3.04329887]
# -2.9904548024708033 gap
# [0.45508853 1.13630891 3.04573727]
# -2.4816156568890997 gap
# [0.42861488 1.14218755 3.04527867]
# -2.4431511320116117 gap
# [0.40157327 1.14816516 3.03185925]
# -2.8720267222795473 gap
# [0.3650782  1.15397525 3.01960557]
# -2.7680783795902784 gap
# [0.32665708 1.1471516  3.01677025]
# -2.7073344850342984 gap
# [0.28387579 1.15239333 3.02119717]
# -3.202920907160739 gap
# [0.22598732 1.15716021 3.03031214]
# -1.3709817265002442 gap
# [0.19520033 1.15355841 2.97809564]
# -2.005987149707896 gap
# [0.14297741 1.15245463 2.95143011]
# -2.3264409609189927 gap
# [0.06157431 1.15301445 2.94735032]
# -1.5896368494506274 gap
# [1.         1.15293626 2.93632792]
# -3.5633041052972447 gap
# [0.99982053 1.15411259 2.94666273]
# -3.8664698551008443 gap
# [0.99572262 1.16108429 2.97339076]
# -3.8069738554129007 gap
# [0.98976609 1.16073857 2.99516736]
# -3.5545204166642144 gap
# [0.98460853 1.1619797  2.99400951]
# -3.154978545243535 gap
# [0.98047845 1.16542632 2.99419777]
# -2.8218481374016737 gap
# [0.98286541 1.17742304 2.96444583]
# -3.6063263344628997 gap
# [0.97448366 1.18004119 2.96213594]
# -3.073244845193546 gap
# [0.9693757  1.18378586 2.96589117]
# -3.1909927130644946 gap
# [0.96442238 1.18646827 2.95621383]
# -3.555657007808357 gap
# [0.96226255 1.188818   2.97577066]
# -3.2904830104528533 gap
# [0.96242807 1.19346255 2.97961533]
# -3.4562522030582272 gap
# [0.95603563 1.19693449 2.99103776]
# -2.859511376667417 gap
# [0.9520623 1.2017136 2.9861855]
# -2.94023507341885 gap
# [0.94788195 1.20648918 2.97913888]
# -3.0022169539703873 gap
# [0.94713118 1.20855412 2.98820256]
# -3.5079664282733343 gap
# [0.9411991  1.20953887 2.99178087]
# -3.6990585797223186 gap
# [0.93822548 1.21273671 3.00440889]
# -2.3753913703160277 gap
# [0.93867212 1.21687205 2.99313529]
# -3.355461480714883 gap
# [0.93376978 1.22268224 2.99143594]
# -2.952500751166486 gap
# [0.93037154 1.22118759 2.97677111]
# -2.653000948839208 gap
# [0.92583346 1.22263044 2.9764382 ]
# -3.6694951048321878 gap
# [0.92132577 1.22381622 2.98035843]
# -3.6174548227022654 gap
# [0.91607794 1.2262101  2.98770036]
# -2.5813047779782208 gap
# [0.91519357 1.22791654 2.99194981]
# -2.6952463023930484 gap
# [0.91179338 1.22907468 2.96965068]
# -3.443376895042249 gap
# [0.90698676 1.23472701 2.97657432]
# -2.22653468390334 gap
# [0.90252254 1.23578521 2.95675199]
# -3.2647367971262833 gap
# [0.89613489 1.23819984 2.95634772]
# -2.807240134433136 gap
# [0.89334087 1.23940763 2.944092  ]
# -3.174050524926775 gap
# [0.88977711 1.24179969 2.9394888 ]
# -3.496211199691903 gap
# [0.886517   1.24113213 2.94488304]
# -2.427913212158866 gap
# [0.88623543 1.24552762 2.94387839]
# -2.736959964007243 gap
# [0.8808162  1.25166368 2.92485826]
# -2.8174674303828646 gap
# [0.87986587 1.25517203 2.90703494]
# -3.144070320727246 gap
# [0.87721638 1.2576545  2.908717  ]
# -4.238986204261924 gap
# [0.87048886 1.26113768 2.92052803]
# -3.334992215643834 gap
# [0.86602203 1.26319567 2.92197185]
# -3.0374269829685865 gap
# [0.86333778 1.26579301 2.9215261 ]
# -3.090301005348447 gap
# [0.85985966 1.27214486 2.92394388]
# -3.411191817876347 gap
# [0.85878821 1.27540035 2.92637922]
# -4.045720371473366 gap
# [0.85373573 1.27804476 2.93842937]
# -4.164360973562904 gap
# [0.84792859 1.28323947 2.94803414]
# -3.0592456505869854 gap
# [0.84498628 1.28745862 2.93900106]
# -2.9661503482996454 gap
# [0.84143804 1.28784674 2.93722985]
# -4.483385454355656 gap
# [0.83596768 1.28883891 2.94562699]
# -3.2819235070350294 gap
# [0.83061147 1.29199404 2.94837495]
# -3.6587429364047583 gap
# [0.82490363 1.29627793 2.95225513]
# -3.1224401604175176 gap
# [0.8205705  1.29814098 2.9542532 ]
# -3.1997447455287897 gap
# [0.81700723 1.3015088  2.95572679]
# -3.378795586191222 gap
# [0.81291259 1.30256819 2.96525775]
# -3.8273992316932475 gap
# [0.80819842 1.3051196  2.97027917]
# -3.091469190898695 gap
# [0.80331312 1.30617488 2.96479047]
# -3.1427586286018396 gap
# [0.79846438 1.31054485 2.97254221]
# -3.5215185214693703 gap
# [0.79376634 1.31245722 2.97990069]
# -2.9957062724978534 gap
# [0.79116565 1.31368994 2.98268871]
# -3.075741837146141 gap
# [0.78748279 1.31623528 2.98184081]
# -3.903793258002452 gap
# [0.78339278 1.31976513 2.9898955 ]
# -3.3187084311377735 gap
# [0.78075986 1.32268671 2.99108711]
# -1.9632876559700525 gap
# [0.7775478  1.32524822 2.98094149]
# -2.703803642691853 gap
# [0.77479126 1.32880931 2.98252082]
# -2.141194093410231 gap
# [0.77173174 1.32998678 2.97611046]
# -3.629944756194788 gap
# [0.76697827 1.33312835 2.97736873]
# -3.021831028876044 gap
# [0.76227542 1.33508678 2.97784035]
# -2.7852473887394633 gap
# [0.75961014 1.33741061 2.97689931]
# -2.8066543178023835 gap
# [0.75658392 1.34156763 2.98079113]
# -3.3273983282436883 gap
# [0.75291736 1.34379125 2.98528116]
# -2.964160001866032 gap
# [0.74813313 1.34775482 2.98497673]
# -3.291119236666282 gap
# [0.74456922 1.3496562  2.98426294]
# -3.4096989275968195 gap
# [0.7407908  1.35269151 2.99009327]
# -3.0495729356851626 gap
# [0.73765692 1.3548669  2.98970864]
# -3.438605518944484 gap
# [0.73415935 1.35915684 2.99145912]
# -3.4481729399288628 gap
# [0.72889415 1.36288188 2.99508824]
# -3.7482377066690793 gap
# [0.72417892 1.3652155  3.00180951]
# -3.4032003332416276 gap
# [0.71933573 1.3681405  3.0012847 ]
# -3.820725599135942 gap
# [0.71479527 1.37178248 3.00570441]
# -3.3315955464882707 gap
# [0.71123954 1.3756807  3.01543528]
# -2.9310451151683776 gap
# [0.70683842 1.37960406 3.01488041]
# -2.681100346186465 gap
# [0.70503518 1.38174848 3.01348855]
# -3.18956933490077 gap
# [0.70179374 1.38349781 3.01747685]
# -2.891147800150205 gap
# [0.69785822 1.38538966 3.01799179]
# -3.432484621478543 gap
# [0.69266245 1.38728851 3.02130475]
# -3.3174638863569816 gap
# [0.68820286 1.38887854 3.02587098]
# -2.8482565886038524 gap
# [0.68494459 1.39038786 3.02708945]
# -3.0499708546094633 gap
# [0.68053589 1.39329647 3.02791577]
# -3.073025373659369 gap
# [0.67654964 1.39548041 3.03015564]
# -2.905119539098531 gap
# [0.67200839 1.3977439  3.03103871]
# -2.4597323859938083 gap
# [0.66790379 1.40140983 3.02867885]
# -3.1968416070806183 gap
# [0.66329864 1.40266417 3.03126519]
# -3.658728808494359 gap
# [0.65718512 1.40445162 3.03697057]
# -2.9252099063808 gap
# [0.65271029 1.40558268 3.03412569]
# -3.1992103466048167 gap
# [0.64826928 1.40732794 3.03823675]
# -2.924480647186719 gap
# [0.64418719 1.4107287  3.03871013]
# -3.046841581200421 gap
# [0.63972667 1.41236176 3.04448806]
# -2.8974497290668264 gap
# [0.63485077 1.41500008 3.0402122 ]
# -2.2806341324257726 gap
# [0.6310218  1.4150529  3.03204826]
# -3.1122917819583376 gap
# [0.6263486  1.41717405 3.0333777 ]
# -2.461608400131605 gap
# [0.62273748 1.42100508 3.03067716]
# -2.494308496291932 gap
# [0.6185755  1.42362344 3.02065863]
# -2.699765594172405 gap
# [0.6141923  1.42595976 3.01992538]
# -2.1335577028084685 gap
# [0.60971141 1.42726687 3.00280968]
# -3.4794054181349408 gap
# [0.60451708 1.42861477 3.00594603]
# -3.099363509486852 gap
# [0.60010121 1.429812   3.00392649]
# -3.144771105808147 gap
# [0.59464809 1.43135686 3.00776086]
# -2.679089338941356 gap
# [0.59037866 1.43446425 2.99924774]
# -2.50346721307376 gap
# [0.58625691 1.43547319 2.99465056]
# -2.8844376086889265 gap
# [0.58168281 1.43855752 2.99572632]
# -2.452341238547142 gap
# [0.57769326 1.44004538 2.99321541]
# -3.431166791917271 gap
# [0.57252707 1.44226481 2.99289556]
# -3.7294028506035453 gap
# [0.56605457 1.44418642 2.9972955 ]
# -3.10651880484029 gap
# [0.56190587 1.44655049 2.99845513]
# -3.012344532653862 gap
# [0.55755299 1.44891664 2.9983465 ]
# -2.6612504694031633 gap
# [0.55343728 1.45062695 2.99864077]
# -3.0415669546876853 gap
# [0.54854303 1.45249444 3.00084003]
# -2.8283405611828774 gap
# [0.54380556 1.45473055 2.99562171]
# -2.426147006088795 gap
# [0.53953018 1.45673795 2.99027514]
# -2.8209328267937392 gap
# [0.53418055 1.45926017 2.9922151 ]
# -2.846200243518709 gap
# [0.52901576 1.45975968 2.98879736]
# -2.5920963196958793 gap
# [0.52426898 1.46100043 2.98548648]
# -2.569259248658532 gap
# [0.51999366 1.46252784 2.98735432]
# -3.062581616340245 gap
# [0.51476809 1.46423574 2.98725522]
# -2.4996236200826285 gap
# [0.5097377  1.46545153 2.98229895]
# -2.8610346267914473 gap
# [0.50431978 1.46615899 2.97865337]
# -1.6897930852473992 gap
# [0.50124417 1.46778708 2.96779279]
# -2.8679403605555156 gap
# [0.49626846 1.47042873 2.96818498]
# -3.313408987625527 gap
# [0.48968055 1.47120696 2.96795593]
# -2.8999712132172153 gap
# [0.4842999  1.47241247 2.96606088]
# -2.977815485158697 gap
# [0.47792177 1.47336692 2.96549316]
# -2.6006478543166685 gap
# [0.47301043 1.47575848 2.96473958]
# -2.650426494125768 gap
# [0.46761997 1.47809922 2.95724235]
# -2.2330302894947023 gap
# [0.46382302 1.47973378 2.95222701]
# -3.1714585486015086 gap
# [0.45707556 1.48113825 2.95275147]
# -2.772466570236794 gap
# [0.45140906 1.48354479 2.95379166]
# -3.3067616650552503 gap
# [0.44446846 1.48610936 2.9552718 ]
# -2.425756217786519 gap
# [0.43942911 1.48655441 2.95368527]
# -2.5523025169099203 gap
# [0.43397314 1.48762243 2.95010624]
# -3.1507946724288978 gap
# [0.42728383 1.48975971 2.95173644]
# -2.610520020808345 gap
# [0.42142316 1.48976977 2.94946665]
# -3.170955013226599 gap
# [0.41448649 1.49174179 2.95188967]
# -2.5282645541888016 gap
# [0.40887032 1.4919804  2.95239141]
# -2.968958059341727 gap
# [0.40157625 1.49329355 2.94939603]
# -3.377964997073882 gap
# [0.39344321 1.49465095 2.95147188]
# -2.685384852825539 gap
# [0.38768172 1.49470792 2.94722187]
# -2.8453120404594294 gap
# [0.38073243 1.49489741 2.94379393]
# -2.8130117915095085 gap
# [0.37371185 1.49562071 2.9433661 ]
# -2.985435583851833 gap
# [0.3664607  1.49712823 2.94589999]
# -2.6390716130932987 gap
# [0.3597284  1.49863353 2.94545586]
# -3.384928022356861 gap
# [0.35097367 1.50030622 2.94827135]
# -2.8334001348529863 gap
# [0.34289268 1.50086852 2.94537651]
# -2.9363034881020127 gap
# [0.3347984  1.50345205 2.945895  ]
# -3.245786570374845 gap
# [0.32546662 1.50477561 2.9472738 ]
# -2.9663516486613646 gap
# [0.31713782 1.50569069 2.94791107]
# -3.0701955448863574 gap
# [0.30812735 1.5066081  2.94879721]
# -2.5259588486924183 gap
# [0.30057477 1.50828856 2.95015909]
# -2.0878693688922794 gap
# [0.29392796 1.50934478 2.95025315]
# -3.0837652585118485 gap
# [0.28401254 1.51121073 2.95352087]
# -2.8747736001720643 gap
# [0.27453869 1.51312275 2.95517343]
# -2.767541821901402 gap
# [0.26510052 1.5131397  2.95407244]
# -2.698148371596758 gap
# [0.25539247 1.51349862 2.95670171]
# -2.73512462927714 gap
# [0.24548605 1.51390742 2.95898812]
# -2.4393776829834284 gap
# [0.23610849 1.51551951 2.96048944]
# -2.729930216543356 gap
# [0.22522758 1.51724528 2.96196284]
# -2.3478220912966057 gap
# [0.21540862 1.5177282  2.94838782]
# -3.302165077857361 gap
# [0.20091422 1.51844997 2.95157287]
# -2.2372302901603947 gap
# [0.19036729 1.52007742 2.94795089]
# -1.7465109979389377 gap
# [0.18161874 1.52063776 2.94555679]
# -1.829105494087248 gap
# [0.1720999  1.51982101 2.9404402 ]
# -2.2565538436291313 gap
# [0.15974169 1.52071869 2.93884526]
# -1.8153296592628159 gap
# [0.14906262 1.52137029 2.93200255]
# -2.144614069010478 gap
# [0.13566058 1.522731   2.93297945]
# -1.625274215383526 gap
# [0.12453449 1.52334186 2.92886088]
# -1.9606925083574338 gap
# [0.10990122 1.52337087 2.92566675]
# -1.6704289497664666 gap
# [0.09575954 1.52439619 2.92242733]
# -1.5944900807151905 gap
# [0.08029571 1.52506828 2.91976403]
# -1.121453142092827 gap
# [0.06735114 1.52422942 2.91579444]
# -1.506450409139641 gap
# [0.04667497 1.52369908 2.91255035]
# -0.9176399118059854 gap
# [0.02850912 1.52371191 2.91030281]
# -0.21484945748234296 gap
# [0.02156656 1.52298238 2.90219276]
# -0.1918341026814837 gap
# [0.01340653 1.5219295  2.89405697]
# 0.08823154718406798 gap
# [0.01941651 1.52129868 2.89023742]
# -0.2582075743197198 gap
# [0.00733915 1.51931315 2.88015319]
# 1.158785054878576 gap
# [0.15022312 1.5177528  2.8718401 ]
# -1.7105946226822608 gap
# [0.14022938 1.51649212 2.86674351]
# -2.2681961367445442 gap
# [0.12606853 1.51743905 2.86482848]
# -2.1572165337378832 gap
# [0.11099026 1.51829258 2.86445956]
# -2.316619097004046 gap
# [0.09267301 1.51888988 2.8642507 ]
# -1.6012606559155502 gap
# [0.07756587 1.51883706 2.86184413]
# -1.552298739311994 gap
# [0.05999306 1.51820627 2.8579192 ]
# -1.4572404652950122 gap
# [0.03872831 1.51835785 2.85655744]
# -0.5252955226064692 gap
# [0.0268861  1.51778343 2.84675221]
# -0.8846283071316313 gap
# [1.         1.51676243 2.8457369 ]
# -3.6736464179814816 gap
# [0.99927246 1.51784259 2.84976744]
# -3.789223973030991 gap
# [0.99883839 1.51911554 2.85368026]
# -3.241281972906913 gap
# [0.99779636 1.52094775 2.8539612 ]
# -2.9175260350558947 gap
# [0.99677886 1.52220237 2.85501866]
# -3.351643006975517 gap
# [0.99608952 1.52354744 2.85384492]
# -3.777156576163188 gap
# [0.99493385 1.52455411 2.85756181]
# -2.7389659181648325 gap
# [0.99447009 1.52499441 2.8548777 ]
# -3.818292527494593 gap
# [0.99353915 1.52685762 2.85904045]
# -3.525372617007428 gap
# [0.99309927 1.52772093 2.86230678]
# -3.8965793914762084 gap
# [0.99294724 1.52890528 2.86683395]
# -3.6914753903609907 gap
# [0.99181784 1.53085885 2.86997097]
# -3.6458761194226548 gap
# [0.99083101 1.53200392 2.87333002]
# -3.4666553838985084 gap
# [0.9896348  1.53275305 2.87525699]
# -3.2218874290956614 gap
# [0.98894094 1.53408129 2.87695223]
# -2.950075681100642 gap
# [0.98842257 1.53506667 2.87447023]
# -3.4565797213950096 gap
# [0.98753792 1.53594146 2.87708007]
# -3.4005834646415196 gap
# [0.98689976 1.53713418 2.87654665]
# -3.368291283452842 gap
# [0.9864266  1.53822206 2.87793661]
# -3.089639384541666 gap
# [0.98570846 1.5401438  2.87877693]
# -3.233368662901739 gap
# [0.98572071 1.54233399 2.88034978]
# -3.649403936394924 gap
# [0.98476133 1.54329269 2.88245908]
# -2.91242056979896 gap
# [0.98397647 1.54566187 2.88259052]
# -3.7367191444874073 gap
# [0.98349316 1.546522   2.88557913]
# -3.84530666097974 gap
# [0.98326591 1.54789035 2.88845487]
# -3.6434332596572148 gap
# [0.98179496 1.54914309 2.89178437]
# -3.390839815740169 gap
# [0.98106957 1.55014998 2.89330603]
# -3.61470062391937 gap
# [0.97978601 1.55079349 2.8913159 ]
# -3.239823171764384 gap
# [0.9792893  1.5520849  2.89331365]
# -3.3028416501086246 gap
# [0.97828996 1.55313102 2.89467858]
# -2.9786499615822306 gap
# [0.97829185 1.55459504 2.89478024]
# -3.0537062529156764 gap
# [0.97714735 1.55519569 2.89528878]
# -3.638888406435731 gap
# [0.97622705 1.55651347 2.89744915]
# -3.2269031494389075 gap
# [0.97542129 1.55781721 2.89597751]
# -2.8914412947223314 gap
# [0.97479392 1.55887623 2.8967896 ]
# -3.2812859026315575 gap
# [0.97400875 1.55943743 2.89732776]
# -1.8253198754660016 gap
# [0.97345952 1.56022275 2.88313811]
# -3.260682750525275 gap
# [0.97298094 1.56134304 2.88549721]
# -2.9305240674817066 gap
# [0.97222477 1.56397883 2.88669792]
# -3.283142145247487 gap
# [0.97128015 1.56506546 2.88789668]
# -3.505491154943302 gap
# [0.97089723 1.56639988 2.88875328]
# -3.3183279496064846 gap
# [0.97059056 1.56757946 2.89062015]
# -2.262268452908694 gap
# [0.96952107 1.56839599 2.88483282]
# -3.6073334127605206 gap
# [0.96838747 1.56949957 2.88747592]
# -3.277411803120515 gap
# [0.96788986 1.57027682 2.88906154]
# -3.6125586465445183 gap
# [0.96682677 1.57175479 2.88983174]
# -3.3248580151504847 gap
# [0.96619718 1.57299185 2.89149968]
# -2.64442587215366 gap
# [0.96586873 1.5748096  2.89119929]
# -3.664444372251684 gap
# [0.96537772 1.57634034 2.8937504 ]
# -2.6523181262742725 gap
# [0.96485077 1.57759915 2.89375684]
# -3.8091769027582916 gap
# [0.96406938 1.57906124 2.89683748]
# -2.9813206749403 gap
# [0.96357673 1.57978428 2.89644913]
# -2.898794814265112 gap
# [0.96309545 1.58078203 2.89872362]
# -3.3325627339356907 gap
# [0.96259097 1.58186718 2.90043985]
# -3.1308764721393407 gap
# [0.96263716 1.58250045 2.90115583]
# -2.836818925025068 gap
# [0.96170091 1.58336969 2.9035156 ]
# -3.132987846714027 gap
# [0.96104107 1.58537014 2.90644658]
# -1.9222511234445223 gap
# [0.96114314 1.58642464 2.90440623]
# -3.382866592178795 gap
# [0.96081817 1.58807104 2.90380732]
# -2.7523819490882797 gap
# [0.9601593  1.58986969 2.90224929]
# -3.573927198268247 gap
# [0.95964033 1.59199066 2.90420947]
# -2.7362438809198295 gap
# [0.95911365 1.59313705 2.90417266]
# -2.8402935996292573 gap
# [0.95875175 1.59363482 2.90252167]
# -2.9464299574819366 gap
# [0.95851336 1.59429165 2.90099317]
# -2.9699476442957375 gap
# [0.95817191 1.59512302 2.89959652]
# -2.882073141224749 gap
# [0.95790092 1.59600737 2.89966683]
# -3.9493532047290323 gap
# [0.9572295  1.59784134 2.90242196]
# -2.8751128496971154 gap
# [0.95658896 1.59782302 2.90351863]
# -3.0576757565274 gap
# [0.95666213 1.59846563 2.9033911 ]
# -2.690559638300893 gap
# [0.95679228 1.59902343 2.90172378]
# -3.3507866511281357 gap
# [0.95648098 1.60041061 2.90416466]
# -3.320592268241461 gap
# [0.95539448 1.60222124 2.90568514]
# -3.605699447128178 gap
# [0.95453983 1.6032271  2.90771992]
# -2.780213818650699 gap
# [0.95406557 1.60414851 2.90683006]
# -3.4592427908673953 gap
# [0.95347149 1.60493653 2.908065  ]
# -3.5403757188105995 gap
# [0.95280364 1.60559189 2.91042504]
# -3.5085240473453547 gap
# [0.95195803 1.60680392 2.9109577 ]
# -2.6928696041096747 gap
# [0.95146984 1.60802175 2.91209352]
# -2.6544714372877034 gap
# [0.95102069 1.6088688  2.91043675]
# -2.485252903028298 gap
# [0.95085016 1.60947019 2.90777363]
# -3.293807977011491 gap
# [0.95038687 1.60962738 2.90804089]
# -2.9789788157983548 gap
# [0.94971261 1.61080953 2.90864076]
# -3.4747007938591072 gap
# [0.948914   1.6119128  2.91129434]
# -3.281391432890317 gap
# [0.94829461 1.61278758 2.91306431]
# -3.2619141350121152 gap
# [0.9479456  1.61384973 2.91476177]
# -2.665365876882072 gap
# [0.9475129  1.6149631  2.91429883]
# -2.522263328320421 gap
# [0.94700732 1.61531587 2.913115  ]
# -2.806636677660161 gap
# [0.94659632 1.61595814 2.91308587]
# -2.7255844682496586 gap
# [0.94575925 1.61666177 2.91229939]
# -3.664474972934739 gap
# [0.94527739 1.61698252 2.91279833]
# -3.254909511266199 gap
# [0.94457645 1.61789058 2.9120202 ]
# -2.9169749784202987 gap
# [0.94382788 1.61935151 2.91257948]
# -3.66905074491041 gap
# [0.94310584 1.62019068 2.91476784]
# -2.3311162523364812 gap
# [0.94254582 1.62124035 2.91447107]
# -2.9171960204903677 gap
# [0.94197219 1.62198737 2.91344397]
# -3.0724457721580967 gap
# [0.94174449 1.62282672 2.91590193]
# -2.6488510014129503 gap
# [0.94113645 1.62345947 2.91602251]
# -2.830820629772573 gap
# [0.94041666 1.62370134 2.91681299]
# -2.3967922831161648 gap
# [0.9402868  1.62371791 2.91230462]
# -3.6033095581746544 gap
# [0.93964186 1.62449315 2.91451231]
# -3.0667615409125037 gap
# [0.93898572 1.6255064  2.91530825]
# -2.3744504376964466 gap
# [0.93803247 1.62632025 2.91461115]
# -2.9435161614239007 gap
# [0.9374874  1.6279742  2.91319788]
# -3.15511401188224 gap
# [0.93705298 1.62907587 2.91498792]
# -3.379075853557079 gap
# [0.93635712 1.63032068 2.91652341]
# -3.15581429114781 gap
# [0.93611738 1.63061376 2.91777721]
# -2.5929733453184234 gap
# [0.93489044 1.63127068 2.91627064]
# -2.7929667823556277 gap
# [0.93415618 1.63232536 2.91379506]
# -3.0088313314924995 gap
# [0.93376886 1.63374608 2.91395122]
# -3.4378357370990256 gap
# [0.93332215 1.63482049 2.9162103 ]
# -3.345221621640515 gap
# [0.9328759  1.63590726 2.91707067]
# -2.926328620737108 gap
# [0.9325407  1.63657452 2.91888171]
# -2.3260587785780786 gap
# [0.93213904 1.63689908 2.91908303]
# -3.4471639614460234 gap
# [0.9313161  1.63820501 2.92084195]
# -3.0386951041517527 gap
# [0.93087648 1.63949576 2.91985963]
# -3.0453371965179 gap
# [0.93041569 1.64076241 2.91993307]
# -3.222986495627362 gap
# [0.93024116 1.6421599  2.92071559]
# -3.116876416319298 gap
# [0.92939759 1.64241079 2.92144436]
# -3.486473473832161 gap
# [0.92893974 1.64366889 2.92385902]
# -3.125012068100474 gap
# [0.92817429 1.64480047 2.92575134]
# -2.5083860792127064 gap
# [0.9278179  1.64518013 2.92675011]
# -2.791454609439039 gap
# [0.92773141 1.6460099  2.92660673]
# -3.5866834883892627 gap
# [0.92699656 1.64738971 2.9290217 ]
# -2.6873954806040516 gap
# [0.92618686 1.64746175 2.9290432 ]
# -3.0511113988126795 gap
# [0.92571817 1.64779756 2.927622  ]
# -2.839900256912177 gap
# [0.92527462 1.64865782 2.92827684]
# -2.4340427432353753 gap
# [0.92475055 1.64855423 2.92745994]
# -3.143060801638248 gap
# [0.92440697 1.64988528 2.92907728]
# -2.331317642547301 gap
# [0.92394839 1.64971692 2.92719156]
# -3.4428681605962628 gap
# [0.92381291 1.6501495  2.92708677]
# -2.325297548979433 gap
# [0.92307192 1.65116806 2.92193404]
# -2.7712667405179694 gap
# [0.9226711  1.65149385 2.92229228]
# -3.3982084893827693 gap
# [0.92192697 1.65288855 2.92426572]
# -1.901372726324247 gap
# [0.92172864 1.65276122 2.91204252]
# -2.966348318565517 gap
# [0.92120319 1.65398315 2.91032696]
# -2.71815625748148 gap
# [0.92052349 1.65464793 2.91193664]
# -3.5148470337452813 gap
# [0.91997666 1.65496734 2.91234599]
# -2.208616622909631 gap
# [0.92011771 1.65544448 2.91169687]
# -2.5363621150082203 gap
# [0.91981457 1.65599603 2.9123965 ]
# -3.113907405841209 gap
# [0.91935042 1.65650295 2.91376032]
# -2.523181025129268 gap
# [0.9188806  1.65747274 2.91334723]
# -2.6403891265487625 gap
# [0.91823265 1.65853813 2.91396717]
# -3.0800754276108484 gap
# [0.9174144  1.65914447 2.91463337]
# -2.0419811832914023 gap
# [0.91689524 1.65935231 2.91119529]
# -3.5129217096793144 gap
# [0.91626546 1.66098103 2.91333095]
# -2.3744036923917 gap
# [0.91577094 1.6618532  2.91266289]
# -3.2271760206913225 gap
# [0.91522339 1.66350948 2.9134732 ]
# -3.057974116325509 gap
# [0.91429881 1.66399514 2.91376728]
# -3.1834368107699675 gap
# [0.91424371 1.66422383 2.91527472]
# -2.3777607432275087 gap
# [0.9136852  1.66398163 2.9150069 ]
# -2.7867743650625183 gap
# [0.91325953 1.66465125 2.91079751]
# -3.0579248308700446 gap
# [0.91260602 1.66555133 2.9101252 ]
# -2.8863814505188596 gap
# [0.9121384  1.66674402 2.91022214]
# -1.9865713835474372 gap
# [0.91192674 1.66605315 2.90820664]
# -2.506857542019201 gap
# [0.91174663 1.66656839 2.90732221]
# -2.849397474946894 gap
# [0.91157438 1.66667721 2.9084338 ]
# -2.8676863686459573 gap
# [0.91099539 1.66724374 2.90728229]
# -3.104911446945108 gap
# [0.91037317 1.66810318 2.90809441]
# -3.111970954233593 gap
# [0.90982212 1.66916182 2.90870431]
# -3.0849766842950146 gap
# [0.90951373 1.6699031  2.90951315]
# -3.1682953315168527 gap
# [0.90889033 1.67033834 2.91141518]
# -2.2950268827725586 gap
# [0.9088256  1.67057023 2.91164938]
# -2.4895398152775594 gap
# [0.90819284 1.67087801 2.91169986]
# -2.284406625533307 gap
# [0.9075786  1.67107862 2.9101415 ]
# -3.5691677828094854 gap
# [0.90712619 1.67111733 2.91168219]
# -3.453006085401971 gap
# [0.90669236 1.67230132 2.91351235]
# -3.2647426097091934 gap
# [0.90616838 1.67342587 2.91591682]
# -3.4906564191066525 gap
# [0.90552022 1.67406269 2.91772034]
# -2.9694270031405727 gap
# [0.90468737 1.67475306 2.91764747]
# -2.8705665945925567 gap
# [0.90436466 1.67530048 2.91742073]
# -2.8900888560211357 gap
# [0.90382303 1.67588866 2.91712617]
# -2.503757713954272 gap
# [0.90345539 1.67635279 2.9159817 ]
# -2.99015331753234 gap
# [0.90305467 1.67709872 2.91715999]
# -3.467989530351527 gap
# [0.90231632 1.67775328 2.91966876]
# -2.9400004872607597 gap
# [0.90190303 1.67853597 2.92080797]
# -3.1216269239533374 gap
# [0.90138178 1.67891894 2.92205069]
# -3.18590631001504 gap
# [0.90079161 1.6789712  2.92276205]
# -3.030166573539958 gap
# [0.90006594 1.67964998 2.92254271]
# -3.113979571324576 gap
# [0.89915091 1.68039059 2.92336784]
# -3.085196863226258 gap
# [0.89823774 1.68053498 2.9234646 ]
# -2.4261605161819957 gap
# [0.89772626 1.68110682 2.92261383]
# -3.2960031071707814 gap
# [0.89744488 1.68188064 2.92450936]
# -2.3345428883865442 gap
# [0.89693377 1.68244382 2.9212605 ]
# -2.0776932719178807 gap
# [0.89693651 1.68243806 2.92068041]
# -1.9220956570629784 gap
# [0.8968806  1.68179819 2.91800877]
# -2.859365363410859 gap
# [0.8962785  1.68265128 2.91841194]
# -3.0139732132309134 gap
# [0.89593298 1.6831462  2.91867798]
# -2.6841897057870243 gap
# [0.8956026  1.68263748 2.91816874]
# -2.5796927023043907 gap
# [0.89493329 1.68292812 2.91814506]
# -2.6702459906220124 gap
# [0.89444677 1.68337008 2.91926344]
# -2.812407232785724 gap
# [0.89374856 1.68418495 2.92059253]
# -2.7353292888077867 gap
# [0.89310905 1.68478804 2.92049311]
# -3.3010955079882227 gap
# [0.89247484 1.68630496 2.92140997]
# -2.8151964242252165 gap
# [0.89203633 1.68670042 2.92131558]
# -3.849367917008903 gap
# [0.89122677 1.68746055 2.92358414]
# -2.675262247407673 gap
# [0.89088495 1.68814667 2.9245666 ]
# -3.0997266272672266 gap
# [0.89032674 1.68881211 2.92539285]
# -2.3486515729256854 gap
# [0.88981023 1.68900719 2.92190079]
# -2.1586032753039306 gap
# [0.88958602 1.68862753 2.92094085]
# -2.5928426571196024 gap
# [0.88907693 1.68876519 2.92180405]
# -2.7453183419480633 gap
# [0.88838869 1.68933197 2.92111041]
# -3.007931005421199 gap
# [0.88819157 1.68984912 2.92192755]
# -3.6198938260090436 gap
# [0.88757327 1.69065545 2.92150438]
# -2.8219165894325164 gap
# [0.88702154 1.69115359 2.92194452]
# -2.8397661026715286 gap
# [0.88681029 1.69182229 2.92327236]
# -3.1509609515886665 gap
# [0.88637228 1.69240985 2.92444445]
# -2.88095440508291 gap
# [0.88577893 1.69232521 2.9209331 ]
# -2.484399856138739 gap
# [0.88528268 1.69285565 2.92022556]
# -2.4958868910278103 gap
# [0.88513904 1.69298272 2.91822326]
# -3.5863116475953727 gap
# [0.88466284 1.69387499 2.92014004]
# -3.145089707889303 gap
# [0.88434617 1.69453099 2.92161734]
# -2.656265683047907 gap
# [0.88393824 1.69470795 2.92182617]
# -3.62538160214869 gap
# [0.88324648 1.69527799 2.92322027]
# -2.8120146048439345 gap
# [0.88284998 1.69596827 2.92090296]
# -2.4758390226877958 gap
# [0.882221   1.69683227 2.91998292]
# -2.791052652156879 gap
# [0.88194222 1.69739338 2.91926889]
# -1.9751215662567443 gap
# [0.88138327 1.69757583 2.91706307]
# -3.4687655953317194 gap
# [0.8804437  1.69735479 2.91658015]
# -3.8591744749879093 gap
# [0.87990181 1.69868236 2.91821387]
# -2.6281847744737457 gap
# [0.87974556 1.69892328 2.91701324]
# -3.1272123404927314 gap
# [0.87939266 1.69999808 2.9172312 ]
# -2.5392960022783257 gap
# [0.87937645 1.70034511 2.91450368]
# -3.581291388234263 gap
# [0.87835072 1.70126934 2.91493843]
# -2.8982491318859163 gap
# [0.87736534 1.70147169 2.91208876]
# -1.6634096682003103 gap
# [0.87684783 1.70133701 2.90849744]
# -2.6788451974856424 gap
# [0.87655957 1.70151678 2.90801063]
# -2.9372645310089593 gap
# [0.87590951 1.70258158 2.90868476]
# -3.2511043537602458 gap
# [0.87557231 1.70327118 2.90997213]
# -3.20285769307083 gap
# [0.87504533 1.70403121 2.91157416]
# -2.998383559986077 gap
# [0.87505506 1.70457283 2.91287581]
# -3.069273115034328 gap
# [0.87457952 1.70556947 2.91337923]
# -2.8743079441152695 gap
# [0.87422705 1.70631912 2.91339408]
# -3.3916656460125383 gap
# [0.87349415 1.70700282 2.91472578]
# -2.72917317939874 gap
# [0.87282336 1.70760495 2.91503282]
# -3.1618286219838967 gap
# [0.87212833 1.70748607 2.91464672]
# -3.1674983737259312 gap
# [0.87151365 1.70779655 2.91512981]
# -3.138086675840323 gap
# [0.87123105 1.70839368 2.91672517]
# -3.390395880621907 gap
# [0.87073551 1.70922847 2.91866601]
# -3.3476982719150707 gap
# [0.87021337 1.70956546 2.91937145]
# -2.6290565987567085 gap
# [0.86976908 1.70900926 2.91832749]
# -2.575345506765391 gap
# [0.8691025  1.70928009 2.91800925]
# -2.8224403019094892 gap
# [0.86846668 1.70929573 2.91668433]
# -2.7945726202199843 gap
# [0.86831908 1.70968267 2.91674794]
# -2.759825216860455 gap
# [0.86793296 1.70987188 2.91648199]
# -3.2569204079473972 gap
# [0.86740893 1.71033423 2.91695922]
# -3.037824228203183 gap
# [0.86677372 1.71100637 2.91777155]
# -3.2337532928502735 gap
# [0.86623898 1.71192376 2.91756205]
# -3.252314492168289 gap
# [0.86575897 1.71266664 2.91807158]
# -2.0648037096590572 gap
# [0.86531107 1.71218945 2.91612236]
# -3.0840203340658348 gap
# [0.86481421 1.71274318 2.91725162]
# -2.38169451510357 gap
# [0.86391008 1.712472   2.91531132]
# -2.584308644763295 gap
# [0.86382021 1.71350187 2.91613782]
# -3.6418694976775647 gap
# [0.86307648 1.71422833 2.91771737]
# -2.748980649229011 gap
# [0.86241197 1.71469947 2.91840246]
# -2.8321285107690546 gap
# [0.86201338 1.71534013 2.91886309]
# -2.2820035701890227 gap
# [0.86193835 1.71560147 2.9181252 ]
# -2.2078794514727393 gap
# [0.86153939 1.71622478 2.91731061]
# -3.393567396167999 gap
# [0.86091927 1.71700634 2.91863335]
# -2.94727125109273 gap
# [0.86041665 1.71774599 2.91843063]
# -3.555324630294505 gap
# [0.8599819  1.71808205 2.91972823]
# -3.370112937192391 gap
# [0.85950306 1.71884145 2.92131514]
# -3.050429370860215 gap
# [0.85899835 1.71917197 2.92114043]
# -2.9109847681173644 gap
# [0.85867251 1.71956073 2.91876366]
# -3.7356131153330625 gap
# [0.85796901 1.72022934 2.91997749]
# -2.084358847722464 gap
# [0.8575862  1.72072035 2.91852955]
# -3.0953943958870433 gap
# [0.85722616 1.72110263 2.91768321]
# -3.031718943007557 gap
# [0.85663787 1.72203216 2.91827036]
# -2.6828204519607497 gap
# [0.85615181 1.72187233 2.91750765]
# -2.52868202486584 gap
# [0.85589673 1.72246724 2.91759028]
# -3.4543787351822086 gap
# [0.855488   1.72319952 2.91844407]
# -3.38533770317144 gap
# [0.85493869 1.72361344 2.91971276]
# -3.296053122335025 gap
# [0.8542806  1.72485871 2.92109245]
# -3.0161193825447103 gap
# [0.85372311 1.72575682 2.9214682 ]
# -2.4342924637240952 gap
# [0.85336385 1.72623585 2.9221812 ]
# -3.250990480501553 gap
# [0.85265569 1.72552715 2.92308664]
# -3.082404749406728 gap
# [0.85230772 1.72635708 2.92386022]
# -2.7454420260631265 gap
# [0.85179706 1.72689866 2.92218242]
# -3.3939961603068456 gap
# [0.85130922 1.72711205 2.92260582]
# -3.7284882917825333 gap
# [0.85070115 1.72767622 2.92371192]
# -3.214546399451543 gap
# [0.84998743 1.72819643 2.92439734]
# -2.265058275299398 gap
# [0.84985761 1.72844377 2.92308265]
# -2.963852682454349 gap
# [0.84931751 1.72934398 2.92340601]
# -3.0755089829104545 gap
# [0.84884265 1.72922529 2.92339002]
# -2.9988592021990637 gap
# [0.84838197 1.73028558 2.92424015]
# -2.330517465178937 gap
# [0.84748747 1.73009412 2.9234559 ]
# -3.293608530849892 gap
# [0.84655688 1.73037208 2.92346566]
# -3.2597826596628647 gap
# [0.84574006 1.7306486  2.92376335]
# -3.3329744464654647 gap
# [0.84551339 1.73121746 2.92506295]
# -3.163299528596541 gap
# [0.8450112  1.73188613 2.92591553]
# -1.8310335579897634 gap
# [0.8445156  1.73265652 2.92514807]
# -3.3830810385260195 gap
# [0.84386943 1.7335845  2.92677381]
# -2.4024089880403023 gap
# [0.84334414 1.73386918 2.92728225]
# -2.055201473313555 gap
# [0.84291852 1.73412178 2.92710639]
# -3.1743214814617473 gap
# [0.84243585 1.73463045 2.92809169]
# -1.76877996303327 gap
# [0.84230532 1.7347772  2.92388918]
# -3.7486748525603404 gap
# [0.8415282  1.73570863 2.92514409]
# -3.0767985284785535 gap
# [0.84086468 1.7364444  2.92602443]
# -3.076436982950634 gap
# [0.84006209 1.73638108 2.92564038]
# -3.002540903096102 gap
# [0.83963282 1.73672341 2.92662115]
# -2.8362211255612793 gap
# [0.83908879 1.73724942 2.92668227]
# -3.3914451174207523 gap
# [0.83824983 1.7377317  2.92805835]
# -2.8171167514269913 gap
# [0.83790182 1.73838107 2.92805381]
# -2.417499323276444 gap
# [0.83745104 1.73834659 2.92784974]
# -2.615116886885935 gap
# [0.83674339 1.73836113 2.92696933]
# -2.997921606096544 gap
# [0.83601468 1.73852182 2.92660086]
# -3.088399484662421 gap
# [0.83557749 1.73892285 2.92729089]
# -3.251392009189982 gap
# [0.83528149 1.73951087 2.92826851]
# -2.3855810074009574 gap
# [0.83463797 1.73935512 2.92753558]
# -3.0241891478084115 gap
# [0.83409887 1.74011045 2.92842524]
# -3.6957122949636156 gap
# [0.83357336 1.74081785 2.92915999]
# -2.978820567091794 gap
# [0.83278034 1.74127688 2.92980965]
# -2.8056087155103753 gap
# [0.83241025 1.74135108 2.92938322]
# -2.52675014218972 gap
# [0.83161405 1.74156235 2.92966151]
# -2.2744020297225576 gap
# [0.83103571 1.74160986 2.92871674]
# -2.7851275175506705 gap
# [0.83029617 1.74187735 2.92814759]
# -2.1159745927983447 gap
# [0.82994251 1.74229556 2.92792767]
# -2.4347207553049532 gap
# [0.82937384 1.74227209 2.92710022]
# -3.1015409878625144 gap
# [0.82873617 1.74287961 2.92721823]
# -3.11524371467156 gap
# [0.82834346 1.74289848 2.92795521]
# -2.896701494566277 gap
# [0.82780357 1.74357091 2.92913577]
# -3.051364801443073 gap
# [0.82750649 1.7441577  2.93016132]
# -2.3485408551524727 gap
# [0.82690284 1.74468639 2.92884506]
# -3.087342025368103 gap
# [0.8262784  1.74526291 2.92937028]
# -2.923682803514458 gap
# [0.82594795 1.74576092 2.93013824]
# -2.750483410631659 gap
# [0.82540262 1.74588968 2.93017835]
# -2.5603792226722932 gap
# [0.82523907 1.74614015 2.92987784]
# -2.3416819361191132 gap
# [0.82466682 1.74619352 2.92814142]
# -2.336243766895285 gap
# [0.82419264 1.74610249 2.92773755]
# -3.1925634277957107 gap
# [0.82362844 1.74627642 2.92869493]
# -2.794299185318837 gap
# [0.82306499 1.74681336 2.92862796]
# -3.5703936794157802 gap
# [0.82252322 1.7474491  2.92959528]
# -2.5710822211885858 gap
# [0.82205267 1.74737958 2.92928899]
# -2.885288469253357 gap
# [0.82176331 1.74778337 2.9297302 ]
# -2.2224760120590252 gap
# [0.82151566 1.74835448 2.9288077 ]
# -2.801861309757367 gap
# [0.82083144 1.74864318 2.92827475]
# -2.4809416073936905 gap
# [0.82032228 1.74867193 2.92208112]
# -3.6796460223048255 gap
# [0.81968867 1.7493279  2.92317762]
# -2.800818827141536 gap
# [0.81881874 1.74978445 2.92351032]
# -3.16982767384847 gap
# [0.81827831 1.75067337 2.92502769]
# -2.40841491839368 gap
# [0.81785095 1.75114495 2.9246895 ]
# -2.803636714172392 gap
# [0.81706884 1.75092014 2.92402487]
# -2.4733311998765615 gap
# [0.81652031 1.75072513 2.92417534]
# -2.7781445353561427 gap
# [0.8162566  1.75093672 2.92380068]
# -2.0091155114199784 gap
# [0.81583463 1.75073453 2.92289228]
# -2.788766587486226 gap
# [0.81530545 1.75138097 2.92321234]
# -2.9166817534994753 gap
# [0.81473574 1.75195173 2.92385285]
# -2.7867024934476508 gap
# [0.81432995 1.75212222 2.92506158]
# -3.1002079049591473 gap
# [0.8137629  1.75299786 2.92640993]
# -2.939991460676329 gap
# [0.8131323  1.7535725  2.92661888]
# -2.716904612794048 gap
# [0.81257803 1.7542648  2.92702634]
# -2.509953440082563 gap
# [0.81225457 1.75473498 2.92773549]
# -2.669489742820277 gap
# [0.81137115 1.75504901 2.92692005]
# -2.3764211653725615 gap
# [0.81104787 1.75531866 2.92624588]
# -1.9280649407519368 gap
# [0.81109012 1.75447281 2.92438051]
# -2.9266634517270766 gap
# [0.81054114 1.75492348 2.92530912]
# -3.347120645307517 gap
# [0.81013895 1.75557932 2.92624036]
# -3.058665953625466 gap
# [0.80945349 1.75637625 2.92666909]
# -2.3191571366874455 gap
# [0.80893609 1.75644865 2.92586304]
# -3.1099072671034174 gap
# [0.8083041  1.75709495 2.92703687]
# -2.669261041465682 gap
# [0.80802888 1.7575439  2.92736323]
# -2.3717878628995077 gap
# [0.80780223 1.75695404 2.92530247]
# -3.5052571720727355 gap
# [0.80731768 1.75759597 2.9267923 ]
# -2.3408010597140647 gap
# [0.806852   1.75809519 2.92671722]
# -2.741000122088922 gap
# [0.80643117 1.75862947 2.9266201 ]
# -3.1794511963036998 gap
# [0.80561305 1.75902385 2.9259407 ]
# -2.9481501152888465 gap
# [0.80530249 1.75842919 2.92594005]
# -3.079516620734217 gap
# [0.80478234 1.75915714 2.92525791]
# -2.7063529551976035 gap
# [0.80424554 1.75954595 2.92566747]
# -3.2749056115892965 gap
# [0.80366356 1.7600012  2.92583418]
# -3.044354767733432 gap
# [0.80308027 1.76037831 2.92706601]
# -2.3502230811972646 gap
# [0.80247372 1.76038315 2.92745936]
# -3.282445043547079 gap
# [0.80178664 1.76095007 2.92843939]
# -2.0373563653354685 gap
# [0.8013736  1.76148029 2.92797206]
# -3.271494245348174 gap
# [0.80072718 1.76201179 2.9276265 ]
# -2.4494257363757104 gap
# [0.80015313 1.76186379 2.92620891]
# -3.4195327227698322 gap
# [0.7992613  1.76279527 2.92660872]
# -2.764824273190109 gap
# [0.79859141 1.7628061  2.92660397]
# -2.8240129264913696 gap
# [0.79820587 1.76303737 2.92660242]
# -3.1725472507957666 gap
# [0.79753435 1.76329909 2.92672593]
# -2.346315147219467 gap
# [0.7968941  1.76328511 2.92585191]
# -2.7641668413179605 gap
# [0.79657517 1.76377556 2.92568697]
# -3.2031274477825264 gap
# [0.79604726 1.76427787 2.92715971]
# -2.3550209155131814 gap
# [0.79565782 1.76433273 2.92504078]
# -2.1471548899068074 gap
# [0.795187   1.76444957 2.92347172]
# -3.4910440792702904 gap
# [0.7943986  1.76477795 2.92475413]
# -3.5196611769307307 gap
# [0.79362751 1.76559588 2.9259638 ]
# -2.3151618765390976 gap
# [0.79313187 1.76558244 2.92528033]
# -2.4180153850092516 gap
# [0.79259058 1.76577822 2.92480546]
# -2.833736221541467 gap
# [0.79214445 1.76571032 2.92367841]
# -2.6084527625107365 gap
# [0.79178965 1.76618269 2.9224751 ]
# -2.768166490147879 gap
# [0.79095058 1.76646132 2.92191467]
# -3.958510064370253 gap
# [0.79023301 1.76726949 2.92322317]
# -2.3742883329899573 gap
# [0.78994306 1.7682637  2.92357594]
# -2.779765665891874 gap
# [0.78948295 1.76835884 2.92358577]
# -3.0441821252027297 gap
# [0.78869039 1.76900661 2.92447271]
# -3.455950082846643 gap
# [0.78807995 1.76931292 2.92570051]
# -2.8233347293321596 gap
# [0.78737458 1.76928892 2.92634079]
# -3.008770574513593 gap
# [0.78679472 1.76912579 2.92677507]
# -2.1835411741803323 gap
# [0.78640256 1.76961747 2.92540584]
# -2.0439204903539756 gap
# [0.78581081 1.76897226 2.92400417]
# -2.91825687932268 gap
# [0.78509384 1.76921622 2.92355099]
# -3.1588634243639744 gap
# [0.78437184 1.76970083 2.924581  ]
# -2.89960289156145 gap
# [0.78377228 1.77024653 2.9247979 ]
# -3.057269247916373 gap
# [0.783303   1.77075068 2.92477194]
# -2.5543570835929565 gap
# [0.7826757 1.7709855 2.9239951]
# -2.624453552826578 gap
# [0.7822433  1.77157442 2.92416036]
# -2.8203238138174087 gap
# [0.78175679 1.77218725 2.92474616]
# -2.9725283887980076 gap
# [0.78114146 1.77260314 2.92520259]
# -2.5479113643246616 gap
# [0.78070718 1.77320924 2.92496777]
# -2.2019052423730567 gap
# [0.78016151 1.77351559 2.92188742]
# -2.035132640338222 gap
# [0.77971273 1.77384489 2.92083097]
# -3.1167441512366696 gap
# [0.77916826 1.77408523 2.92116305]
# -2.591079345850221 gap
# [0.77864273 1.77407267 2.9209307 ]
# -2.9172234716835077 gap
# [0.77791059 1.77455432 2.9216345 ]
# -2.450646344437726 gap
# [0.77747791 1.77474652 2.91995195]
# -2.5107569080423366 gap
# [0.77705672 1.77494735 2.91749237]
# -2.0925987832713133 gap
# [0.77653632 1.77458982 2.9163605 ]
# -2.325558833766789 gap
# [0.77623489 1.77502261 2.91494945]
# -3.1395689033010203 gap
# [0.77581733 1.77589965 2.91551804]
# -2.6512557983166234 gap
# [0.77532758 1.77599909 2.91524693]
# -2.6542537487737534 gap
# [0.77479828 1.77635582 2.91579778]
# -2.299775591433063 gap
# [0.77425583 1.77635658 2.91593731]
# -3.261261455925993 gap
# [0.7738371  1.7767175  2.91656767]
# -2.2117783286469965 gap
# [0.77329865 1.77636655 2.9156969 ]
# -2.398883955051124 gap
# [0.77263727 1.77665687 2.91555555]
# -1.5346939258721672 gap
# [0.77213242 1.77646664 2.91353779]
# -3.4770573899052066 gap
# [0.77121913 1.77658108 2.91418431]
# -3.3378252845723027 gap
# [0.77065024 1.77733718 2.91525219]
# -3.136797958828985 gap
# [0.77014349 1.77749205 2.91470285]
# -2.064393612167693 gap
# [0.76984137 1.77730169 2.91421362]
# -3.249279150968109 gap
# [0.76901752 1.77754328 2.91504345]
# -3.2167620294488914 gap
# [0.76840698 1.77813966 2.91540885]
# -2.2843103054559517 gap
# [0.76812916 1.77847243 2.914516  ]
# -3.3810294746597793 gap
# [0.76771151 1.77882658 2.91529642]
# -2.720435652768241 gap
# [0.7671739  1.77927339 2.91585089]
# -2.6945247737667506 gap
# [0.76658205 1.77968147 2.91609886]
# -2.91638373408567 gap
# [0.76602886 1.78007326 2.91673827]
# -3.119831665245313 gap
# [0.76538562 1.78001743 2.91685075]
# -3.322896001299607 gap
# [0.76467999 1.78028958 2.91829962]
# -2.619879757044137 gap
# [0.76424371 1.7806262  2.91894279]
# -2.030612669603241 gap
# [0.76379962 1.78064071 2.91807415]
# -2.4200403811923414 gap
# [0.76329114 1.78094891 2.91846238]
# -3.2886865548355346 gap
# [0.76275395 1.78119042 2.9175166 ]
# -2.486600561519214 gap
# [0.76239368 1.7811673  2.91689912]
# -1.9965300076895678 gap
# [0.76198561 1.78156196 2.91553642]
# -2.696151834882686 gap
# [0.76136862 1.78126414 2.91571478]
# -2.6548263907009915 gap
# [0.76085678 1.78111677 2.914969  ]
# -2.7243679482702134 gap
# [0.76025729 1.78141936 2.9153845 ]
# -2.8627041721843285 gap
# [0.75949081 1.78115793 2.91580944]
# -2.634713255248487 gap
# [0.75905009 1.78114525 2.91576543]
# -3.1082066314638097 gap
# [0.75857925 1.7814238  2.91634695]
# -3.6307449790861237 gap
# [0.75773355 1.78167771 2.91700654]
# -2.6554806272729636 gap
# [0.75733676 1.78164264 2.91657345]
# -2.7027156457011525 gap
# [0.75693391 1.78172214 2.91611077]
# -3.4590978783135555 gap
# [0.75606883 1.78195778 2.91690984]
# -2.598719305107681 gap
# [0.75532514 1.78206229 2.91661535]
# -2.8417367659883905 gap
# [0.75476088 1.78257942 2.91710384]
# -3.1398807029352325 gap
# [0.75428877 1.78304004 2.91759621]
# -2.623276598005467 gap
# [0.75378415 1.783034   2.91718318]
# -3.5947612386733754 gap
# [0.75298592 1.78354708 2.91824964]
# -2.5430790177423908 gap
# [0.75243691 1.78371214 2.91876493]
# -2.776175587237434 gap
# [0.75178638 1.78404953 2.91811758]
# -2.0084515943829224 gap
# [0.75142274 1.7832248  2.91737164]
# -2.864620839519181 gap
# [0.75077359 1.78349457 2.91740952]
# -2.9957645877718537 gap
# [0.75015458 1.78385984 2.91828053]
# -2.8108366561868805 gap
# [0.74959883 1.78421345 2.91837414]
# -3.2013216730147183 gap
# [0.74882749 1.7848043  2.91922173]
# -3.492399558724281 gap
# [0.74836974 1.78538538 2.92020902]
# -3.1827978996816793 gap
# [0.747777   1.78583306 2.92116884]
# -1.7268959196076787 gap
# [0.74749581 1.78619274 2.91943734]
# -2.8783225010863362 gap
# [0.74696553 1.78611412 2.91930802]
# -2.1582209021723657 gap
# [0.74631307 1.78308377 2.91811486]
# -3.0014594584616656 gap
# [0.74580043 1.78366251 2.91803606]
# -2.6274283453745615 gap
# [0.74525176 1.7835047  2.91752907]
# -2.630714344455331 gap
# [0.74485069 1.78382349 2.91706199]
# -2.6590121317133306 gap
# [0.74435334 1.78387018 2.91792679]
# -3.8107673072313086 gap
# [0.74352388 1.78446506 2.91909255]
# -3.1710748234233925 gap
# [0.74287518 1.78451192 2.91936869]
# -2.847756613255703 gap
# [0.742175   1.78470815 2.91999697]
# -2.9842197012511043 gap
# [0.7415715  1.78459519 2.9205975 ]
# -2.5637648227212217 gap
# [0.74113676 1.78453369 2.92012561]
# -2.833007699773251 gap
# [0.74039221 1.78458703 2.91922683]
# -2.647509912182755 gap
# [0.73986677 1.78513975 2.91874121]
# -2.3781471011107445 gap
# [0.73947993 1.78545878 2.91890772]
# -2.9379017771319966 gap
# [0.73891661 1.7863201  2.91895111]
# -2.5104578166824005 gap
# [0.73838501 1.78622922 2.9187999 ]
# -2.5083463483810204 gap
# [0.73776159 1.78679791 2.91855785]
# -2.2662792024756335 gap
# [0.73742417 1.78671818 2.91859959]
# -3.032589514930969 gap
# [0.73689317 1.78690912 2.91866242]
# -2.3403746256481814 gap
# [0.73622944 1.78727646 2.91738082]
# -2.528485706095604 gap
# [0.73543449 1.78748837 2.91723061]
# -2.500637584608453 gap
# [0.73479608 1.78764497 2.91708512]
# -2.589605395096382 gap
# [0.73419268 1.78791301 2.91743184]
# -2.605816596383191 gap
# [0.73367939 1.78831301 2.91762591]
# -2.7012162393973456 gap
# [0.73313115 1.78846698 2.91701427]
# -2.228300899583829 gap
# [0.73283616 1.78877324 2.91697926]
# -3.247354313215421 gap
# [0.73237773 1.78910221 2.91703039]
# -2.854950383225044 gap
# [0.73200297 1.78932962 2.91744786]
# -3.24346070026107 gap
# [0.73137038 1.78978106 2.91835312]
# -2.826092152202145 gap
# [0.73098823 1.78967393 2.91847892]
# -3.3113313706605596 gap
# [0.73016581 1.7903176  2.9189299 ]
# -2.263804124256437 gap
# [0.72976982 1.79047954 2.9177645 ]
# -3.020861331810804 gap
# [0.72936564 1.79074277 2.91816566]
# -2.627908512620128 gap
# [0.72890671 1.79117847 2.91849126]
# -3.0962302518349696 gap
# [0.72824513 1.79125969 2.9187168 ]
# -2.879631551191034 gap
# [0.72772384 1.79159344 2.91889096]
# -2.698634417371739 gap
# [0.72713295 1.79191522 2.91894954]
# -3.033806322753112 gap
# [0.72641136 1.79209994 2.91922394]
# -3.2506287902199933 gap
# [0.72595369 1.79245575 2.91984326]
# -2.5295655950460203 gap
# [0.72561469 1.79270654 2.91963   ]
# -2.6550411433158247 gap
# [0.72502886 1.79293333 2.91919184]
# -2.5124019993812405 gap
# [0.72438061 1.79300629 2.91853894]
# -1.8570476992597693 gap
# [0.72425063 1.79281548 2.91639062]
# -3.024037302739911 gap
# [0.72367135 1.79314538 2.91660869]
# -3.1772677620013976 gap
# [0.72301202 1.79383289 2.91731822]
# -2.8098539125056643 gap
# [0.72254356 1.7941062  2.91809581]
# -2.8033244033199494 gap
# [0.72189349 1.7938966  2.91541238]
# -3.007986713685373 gap
# [0.72142329 1.7939499  2.91599743]
# -2.773329724519287 gap
# [0.72076562 1.7943977  2.9152106 ]
# -2.5298702936587127 gap
# [0.72025501 1.79470935 2.9152691 ]
# -3.1644012587091015 gap
# [0.71970922 1.79527762 2.91553001]
# -2.7762605898414643 gap
# [0.71927418 1.79578212 2.91609198]
# -2.7868598950624595 gap
# [0.71869704 1.79607964 2.91603037]
# -2.2210174908656337 gap
# [0.71800996 1.79629532 2.91509971]
# -2.596955287176434 gap
# [0.71743625 1.79646202 2.915105  ]
# -2.0624341952680396 gap
# [0.717083   1.79643224 2.9148972 ]
# -2.648278360388602 gap
# [0.71648358 1.79662785 2.91538605]
# -2.2156840438113843 gap
# [0.7158993  1.79595194 2.91494953]
# -3.0758291142492387 gap
# [0.71522879 1.79634208 2.9158435 ]
# -3.228548474079291 gap
# [0.71453644 1.79657861 2.91568896]
# -3.058631866717848 gap
# [0.71403472 1.79692181 2.91654128]
# -2.8125559453780613 gap
# [0.71345948 1.79759881 2.91714893]
# -3.1809914069104304 gap
# [0.71282041 1.79778737 2.91655613]
# -2.5749872138990297 gap
# [0.71236229 1.79781021 2.91657313]
# -1.9947790321566716 gap
# [0.71192463 1.79806872 2.91623405]
# -2.353900502534457 gap
# [0.71132089 1.79810789 2.91632317]
# -2.4649504545771106 gap
# [0.71087625 1.79829975 2.91493258]
# -2.5247324902041677 gap
# [0.71035687 1.79855374 2.91421661]
# -2.510517004307681 gap
# [0.70970554 1.79864061 2.9138115 ]
# -2.812108349363926 gap
# [0.70900087 1.7986509  2.91366351]
# -3.2472177422947164 gap
# [0.70830221 1.79887063 2.91353647]
# -2.468554431564508 gap
# [0.70774225 1.79895212 2.91383437]
# -3.110335024850559 gap
# [0.7070947  1.79930649 2.91398105]
# -3.682927549811559 gap
# [0.70629367 1.79965027 2.91462588]
# -2.5968794170344904 gap
# [0.70588011 1.79986394 2.91418589]
# -2.787978060818795 gap
# [0.70541472 1.80022559 2.91342259]
# -2.39110768165194 gap
# [0.7047423  1.80057985 2.91310731]
# -2.340978231753318 gap
# [0.70418548 1.80049047 2.91159996]
# -2.8646062869148237 gap
# [0.70352002 1.80085639 2.91124918]
# -2.8009958059025504 gap
# [0.70283947 1.80090613 2.91044652]
# -2.5244653493476163 gap
# [0.70250238 1.80129351 2.91025002]
# -3.113338917131171 gap
# [0.70188217 1.80172492 2.91047763]
# -2.894639263708094 gap
# [0.70120388 1.80206927 2.91082752]
# -2.168655195990892 gap
# [0.70068022 1.80179009 2.90914009]
# -3.0580377170955653 gap
# [0.70016674 1.80208308 2.90947316]
# -3.0382545831855854 gap
# [0.69937234 1.80259033 2.91003981]
# -3.2051710609654025 gap
# [0.69874887 1.80291826 2.91095084]
# -2.9781781420133746 gap
# [0.69817397 1.80327358 2.91156733]
# -3.3912371147331504 gap
# [0.697523   1.80371924 2.91257222]
# -2.3861506554256207 gap
# [0.69716979 1.80412347 2.91267923]
# -2.968256819261754 gap
# [0.6965933  1.8043612  2.91278696]
# -2.8671249526965648 gap
# [0.69588595 1.80482918 2.91339606]
# -2.266432034747977 gap
# [0.69544274 1.80316176 2.91308954]
# -2.4200151303232835 gap
# [0.69488006 1.80338634 2.91251504]
# -2.298455154242877 gap
# [0.69448632 1.80347844 2.91189776]
# -2.2392398107120908 gap
# [0.69418343 1.80375732 2.91128685]
# -3.0763811387197655 gap
# [0.6935929  1.80401146 2.91181484]
# -2.6925570600776245 gap
# [0.69310537 1.80400387 2.91176609]
# -3.2905551190114215 gap
# [0.69233266 1.80448171 2.91231365]
# -2.5626192762647633 gap
# [0.69185467 1.80467542 2.91239203]
# -3.058221583201373 gap
# [0.69098803 1.80490428 2.91276868]
# -2.793593828508042 gap
# [0.69047885 1.80511382 2.91250182]
# -3.249199316922437 gap
# [0.68980401 1.80559402 2.91308403]
# -2.0037607302126115 gap
# [0.68928515 1.80562885 2.91253548]
# -3.777547290381021 gap
# [0.68843151 1.80620443 2.91332191]
# -3.477647586964417 gap
# [0.68783185 1.80647966 2.91421502]
# -2.988391681359656 gap
# [0.6872456  1.80678218 2.91466036]
# -3.844563470821598 gap
# [0.68627233 1.8072781  2.91563739]
# -2.683656586017375 gap
# [0.68564251 1.80775709 2.91573844]
# -2.3862517489020627 gap
# [0.68525624 1.80823789 2.91553076]
# -2.265446194764767 gap
# [0.68470079 1.80854167 2.91495686]
# -3.5154536363922144 gap
# [0.68391665 1.80895664 2.91566438]
# -2.368575726981159 gap
# [0.6832823  1.8090162  2.91474714]
# -2.416924867052835 gap
# [0.68280725 1.809108   2.91518459]
# -3.069751525882832 gap
# [0.68220688 1.80969556 2.91566532]
# -2.1633458897860667 gap
# [0.68178868 1.80992938 2.91556373]
# -2.702589445973546 gap
# [0.68129263 1.81022423 2.91554301]
# -3.364637904925504 gap
# [0.6805271  1.81059373 2.91608127]
# -3.140914095594535 gap
# [0.67968632 1.81107134 2.91653765]
# -2.9188998185303086 gap
# [0.67909305 1.81152182 2.91621039]
# -2.8844415393714637 gap
# [0.67856716 1.81157156 2.9161696 ]
# -2.4522124855146514 gap
# [0.67813186 1.81171036 2.91560651]
# -2.9211824627203127 gap
# [0.67745159 1.81193184 2.91557104]
# -3.031129132619274 gap
# [0.67680897 1.81210434 2.9165062 ]
# -3.0494822780959363 gap
# [0.67629766 1.81249947 2.91730711]
# -2.673083348065652 gap
# [0.67589808 1.81282221 2.91659112]
# -2.6935311132384867 gap
# [0.67534493 1.81312949 2.9165911 ]
# -3.468505932436721 gap
# [0.67460581 1.81356263 2.9170333 ]
# -3.041464722466994 gap
# [0.67385841 1.81395957 2.91719463]
# -2.2096865879836978 gap
# [0.67352148 1.81397877 2.91741071]
# -2.8518188135679985 gap
# [0.67297393 1.8144326  2.91821445]
# -2.898431522530062 gap
# [0.67228765 1.81468555 2.91789649]
# -2.1483406363637245 gap
# [0.67183766 1.81478099 2.91767043]
# -2.9982788589150466 gap
# [0.6713633  1.81506529 2.91797783]
# -2.735350186639547 gap
# [0.67076404 1.81523082 2.91836786]
# -2.8786266987318045 gap
# [0.67025702 1.81549436 2.91842286]
# -2.3617296646898223 gap
# [0.66979921 1.81581717 2.91787048]
# -2.8095087154173997 gap
# [0.66912548 1.81602634 2.91831534]
# -2.7829294774593816 gap
# [0.66860843 1.81611004 2.91865002]
# -2.8932240270407625 gap
# [0.66795826 1.81646047 2.9190643 ]
# -3.1231104264205634 gap
# [0.66733308 1.81698444 2.91998123]
# -2.0267035949419854 gap
# [0.66685967 1.8168351  2.91883587]
# -2.4815010201787397 gap
# [0.66641562 1.81720265 2.91854618]
# -2.6657013341555937 gap
# [0.66579037 1.81716118 2.91816583]
# -3.009811446314381 gap
# [0.6652099  1.81738335 2.91857044]
# -2.107769872069952 gap
# [0.66483887 1.81773287 2.91748833]
# -2.8064684919754934 gap
# [0.66419748 1.81815231 2.91710374]
# -2.210660333317378 gap
# [0.66374019 1.8182023  2.91641852]
# -2.3239738042319216 gap
# [0.66338141 1.81790852 2.91550911]
# -2.466163196832056 gap
# [0.66287791 1.8180941  2.91542006]
# -2.614624438561687 gap
# [0.66248099 1.81853401 2.91592193]
# -2.8178216989215255 gap
# [0.66195177 1.81849475 2.9161842 ]
# -3.2110102140589074 gap
# [0.66125242 1.8187587  2.91638335]
# -2.823595520100751 gap
# [0.66058259 1.8187723  2.91653843]
# -3.0867153045170506 gap
# [0.65984108 1.81906106 2.91720118]
# -2.358512924814149 gap
# [0.6593905  1.81892803 2.91745213]
# -3.289979534364102 gap
# [0.65869527 1.81952631 2.91822392]
# -3.2222047820285944 gap
# [0.65794524 1.81990773 2.91876812]
# -2.9831908105871685 gap
# [0.6573372  1.82036986 2.91936671]
# -3.411631600215884 gap
# [0.65663019 1.82064681 2.92012976]
# -2.379943340006076 gap
# [0.65618831 1.82032332 2.91936824]
# -2.450338436707167 gap
# [0.65562702 1.81996866 2.91790828]
# -2.56972704282608 gap
# [0.65523053 1.8199635  2.91754336]
# -2.0432728130075537 gap
# [0.65478935 1.8202214  2.91765332]
# -3.0044400699516074 gap
# [0.65411484 1.82045107 2.91738878]
# -2.785077431048249 gap
# [0.65350233 1.82080943 2.91729253]
# -2.3788211633595155 gap
# [0.65277536 1.82091195 2.91723159]
# -2.948634873553483 gap
# [0.65212846 1.82114388 2.91717314]
# -3.318043256115017 gap
# [0.65144343 1.82117413 2.91762249]
# -3.0350234219826864 gap
# [0.65076113 1.82180559 2.91819719]
# -2.1460369743584193 gap
# [0.65036403 1.82200369 2.9177173 ]
# -3.447070942335982 gap
# [0.64958449 1.82226828 2.91851984]
# -2.1037679597631525 gap
# [0.64903882 1.8223886  2.91751381]
# -2.179455755159411 gap
# [0.64859387 1.82231863 2.91710633]
# -2.171466168524527 gap
# [0.64803753 1.82271297 2.91663842]
# -3.1118345244814667 gap
# [0.64731863 1.82312621 2.917425  ]
# -2.4502237277569194 gap
# [0.64668219 1.82333723 2.91763265]
# -1.9769298399559332 gap
# [0.64645726 1.82291086 2.91678856]
# -3.137671700823971 gap
# [0.64584096 1.82318855 2.91754223]
# -2.529878061872004 gap
# [0.6454221  1.82321349 2.91767909]
# -1.853852375387014 gap
# [0.64503656 1.82298213 2.91694338]
# -3.1740080265473067 gap
# [0.64431708 1.82339806 2.91751268]
# -2.498044167567977 gap
# [0.64377082 1.82319904 2.91696589]
# -2.567496392391773 gap
# [0.64314647 1.82361985 2.91720185]
# -2.1155179517263294 gap
# [0.6426716  1.82358858 2.91623484]
# -1.8157347011590321 gap
# [0.64231113 1.82307332 2.91466837]
# -3.083911502833782 gap
# [0.64157735 1.823523   2.91555581]
# -2.6632734860643423 gap
# [0.64110931 1.82385343 2.91526964]
# -2.2365077142499827 gap
# [0.64070728 1.82353772 2.91241712]
# -2.321281984321353 gap
# [0.64025498 1.82384677 2.91249705]
# -2.5168606436474534 gap
# [0.63973172 1.82372713 2.91270942]
# -3.0259120895985934 gap
# [0.63908105 1.82395476 2.91283626]
# -1.954060901022438 gap
# [0.63867929 1.82410354 2.91221574]
# -2.028117241148783 gap
# [0.63821542 1.82398755 2.91138461]
# -2.822169351801477 gap
# [0.63765739 1.82407955 2.911925  ]
# -3.357924228694227 gap
# [0.63692721 1.82462166 2.91189918]
# -2.6320165745391026 gap
# [0.63642505 1.82472306 2.91148262]
# -2.5300493608167254 gap
# [0.63580392 1.8249544  2.91165776]
# -2.687836165738147 gap
# [0.63530981 1.8249621  2.91166715]
# -2.810972789292539 gap
# [0.6345986  1.82529882 2.91176053]
# -2.797554342936553 gap
# [0.63396594 1.825537   2.91171401]
# -2.357310485266035 gap
# [0.6333888  1.82557523 2.91107845]
# -2.608593849366302 gap
# [0.63278393 1.82515545 2.9116595 ]
# -3.0112030143396193 gap
# [0.63204115 1.82550789 2.91197271]
# -2.2169483927294764 gap
# [0.63158131 1.82536199 2.91100476]
# -2.9564969070901266 gap
# [0.63093185 1.82569414 2.91170003]
# -2.241772599920904 gap
# [0.63050229 1.82595121 2.9116517 ]
# -2.4732547224072623 gap
# [0.62995146 1.82628436 2.91136171]
# -2.4538756907861967 gap
# [0.62940539 1.82633275 2.91113568]
# -2.641487304006351 gap
# [0.62877271 1.82608967 2.91151093]
# -2.407886150738017 gap
# [0.62815288 1.82560193 2.91078269]
# -2.0840156108067394 gap
# [0.62747106 1.82549819 2.90880136]
# -2.684056674387358 gap
# [0.62682424 1.82572788 2.90920944]
# -2.8864438326662434 gap
# [0.62608585 1.82597289 2.90821556]
# -3.080202744208128 gap
# [0.62535138 1.82647557 2.9088597 ]
# -1.6136105280438569 gap
# [0.62508431 1.82636168 2.90661859]
# -2.8770542212617705 gap
# [0.62432421 1.82664053 2.90701656]
# -2.7332457424545242 gap
# [0.62379121 1.82684331 2.90711579]
# -3.070008047705183 gap
# [0.6231329  1.82724526 2.90763327]
# -2.686515256913166 gap
# [0.62264926 1.82724862 2.90738616]
# -2.7427643269072206 gap
# [0.62211411 1.82749613 2.90737542]
# -1.7863387748500477 gap
# [0.62182765 1.82711717 2.90503613]
# -3.4115525645942717 gap
# [0.62103605 1.82757114 2.90525357]
# -3.433089978377181 gap
# [0.62026197 1.8280402  2.90565786]
# -2.7084926572348333 gap
# [0.61955496 1.82821242 2.90599793]
# -2.6922106834653925 gap
# [0.61901205 1.82817989 2.90652113]
# -2.795447220824299 gap
# [0.61841726 1.8287381  2.90669157]
# -2.4641133309675176 gap
# [0.61813833 1.82881125 2.906678  ]
# -2.822503104237976 gap
# [0.61746228 1.82900141 2.90691639]
# -2.270855102669482 gap
# [0.61700542 1.82825168 2.90638087]
# -1.9481659182536517 gap
# [0.61660085 1.82807985 2.90531722]
# -2.92130178788464 gap
# [0.61590332 1.82859048 2.9037721 ]
# -2.0547142820131215 gap
# [0.61536213 1.82881514 2.90363377]
# -2.9911999952390134 gap
# [0.61468995 1.82892558 2.90374552]
# -2.6895147708633096 gap
# [0.6141453  1.82938981 2.90378794]
# -3.139422306834446 gap
# [0.61347509 1.82986153 2.90433538]
# -2.458082133255781 gap
# [0.61288632 1.83013215 2.90405195]
# -2.6901721004134767 gap
# [0.612197   1.83027754 2.903775  ]
# -2.129516278031364 gap
# [0.61177915 1.83018407 2.90194249]
# -2.305765421549083 gap
# [0.61120141 1.83039781 2.90207982]
# -2.768200050024975 gap
# [0.61060702 1.83059982 2.90229542]
# -2.6684765201731295 gap
# [0.60992682 1.83092704 2.90271454]
# -2.696449582221942 gap
# [0.60933535 1.83107776 2.90243191]
# -2.5437682863647724 gap
# [0.6088768  1.83124317 2.90175179]
# -2.8310716330283014 gap
# [0.60813491 1.83163905 2.9020626 ]
# -2.450564594435104 gap
# [0.607508   1.83185596 2.90127109]
# -3.2433530456609914 gap
# [0.60675887 1.83223092 2.90139823]
# -2.1883494395349405 gap
# [0.60628433 1.83229434 2.90133821]
# -2.292756564814915 gap
# [0.60568834 1.83205049 2.89973324]
# -3.4518039813957415 gap
# [0.6049242  1.83232222 2.90017215]
# -2.3415641966640464 gap
# [0.60441131 1.83246452 2.90015499]
# -2.145705024862804 gap
# [0.60398436 1.83258773 2.8994802 ]
# -2.9113716702602823 gap
# [0.60333494 1.83288942 2.89911207]
# -2.7486086222507877 gap
# [0.60266695 1.83300376 2.89954657]
# -2.070772747035666 gap
# [0.60213438 1.83261791 2.89932467]
# -2.949403935996201 gap
# [0.60147365 1.83304072 2.89979491]
# -2.538444224819418 gap
# [0.60095519 1.83316409 2.90070992]
# -2.6306378566209903 gap
# [0.60027929 1.83334923 2.90061545]
# -3.015404994928355 gap
# [0.59960574 1.83360499 2.90124129]
# -2.7563045087107256 gap
# [0.59904816 1.83360815 2.90116969]
# -2.2235664166649025 gap
# [0.59859896 1.83392175 2.9006794 ]
# -2.778758894790326 gap
# [0.59788002 1.83404456 2.90072228]
# -1.781272568809691 gap
# [0.59755809 1.83389591 2.90006322]
# -2.9640166479568366 gap
# [0.59684407 1.83368728 2.90046809]
# -2.696092815474369 gap
# [0.5961237  1.83404887 2.90089232]
# -1.7309066307155587 gap
# [0.59560588 1.83390504 2.89856876]
# -1.9066716509449904 gap
# [0.59530727 1.8340184  2.89733016]
# -2.802326898179272 gap
# [0.59463871 1.83447008 2.89737749]
# -3.124719782214103 gap
# [0.59387792 1.83474314 2.89790649]
# -2.170575309747873 gap
# [0.59327253 1.83484534 2.89742584]
# -3.0819828797000706 gap
# [0.59258589 1.83505119 2.89753548]
# -1.8696939570008462 gap
# [0.59216572 1.83507407 2.89666603]
# -2.7064749166088706 gap
# [0.59168963 1.83472408 2.89708465]
# -2.5442653565714552 gap
# [0.59100817 1.83501268 2.89736133]
# -3.0648804121152464 gap
# [0.5903271  1.83511474 2.89716635]
# -2.787888728441504 gap
# [0.58967014 1.83543715 2.89709597]
# -2.7259938694057477 gap
# [0.58909049 1.83547797 2.89683581]
# -2.6502320613885444 gap
# [0.58855174 1.83542088 2.89673138]
# -3.4741379546274196 gap
# [0.58773192 1.83574773 2.89744229]
# -2.5497818582410297 gap
# [0.58713493 1.83599748 2.89780813]
# -2.405236268366338 gap
# [0.58652288 1.8361973  2.89740423]
# -1.9956726021769169 gap
# [0.58606828 1.83627662 2.89644804]
# -1.2167557409449967 gap
# [0.58562433 1.83605931 2.89516308]
# -1.8160447671934283 gap
# [0.58523622 1.83591246 2.89237843]
# -3.0682371857555903 gap
# [0.58447637 1.83630813 2.89261816]
# -2.4919402873866794 gap
# [0.58381345 1.83652648 2.8922644 ]
# -2.9755605260618374 gap
# [0.58307361 1.8367984  2.89281467]
# -2.5458941236375896 gap
# [0.58247779 1.83707509 2.89269682]
# -2.3852653651367413 gap
# [0.58188414 1.83721778 2.89305398]
# -2.6498577591112173 gap
# [0.58120487 1.83732554 2.89291248]
# -2.549782311767233 gap
# [0.58062745 1.83737137 2.89338815]
# -3.1145644636592396 gap
# [0.57989121 1.83779459 2.8940729 ]
# -2.8861369588820223 gap
# [0.57923616 1.83830544 2.89461152]
# -2.670835642812425 gap
# [0.57869817 1.83857429 2.89330267]
# -2.166186161138472 gap
# [0.57817958 1.83890362 2.89255577]
# -2.2100645693327983 gap
# [0.57765073 1.83896137 2.89166001]
# -2.9974699774406948 gap
# [0.57696782 1.83926768 2.89211185]
# -2.696321224514427 gap
# [0.57622623 1.83930135 2.89214095]
# -2.3309361857892053 gap
# [0.57560509 1.83943978 2.89253596]
# -2.8310867983965537 gap
# [0.57485859 1.83976041 2.89226498]
# -2.9104773414099943 gap
# [0.57421784 1.84004883 2.89213059]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(lbs[1][:1000])
plt.title("variational inference elbo")
# Out:
# Text(0.5, 1.0, 'variational inference elbo')

# %%
plt.plot(np.convolve(lbs[1], np.ones(100)/100, mode='valid'))
plt.title("smoothed loss log function")
# Out:
# Text(0.5, 1.0, 'smoothed loss log function')

# %%
time_expected = [1/ 0.57421784, 1/1.84004883, 1/2.89213059][::-1]
time_expected
# Out:
# [0.3457658528482976, 0.5434638384025928, 1.7414993585012963]

# %%
likelihood(states, 3, time_expected)
# Out:
# 0.00642946196364697

# %%
likelihood(states, 3, [1,1,1])
# Out:
# 0.0033822697169852652

# %%
# [1/.7, 1/1.3, 1/1.8]
# [kchoose2(2)/3, kchoose2(3)/3, kchoose2(4)/3]
r_m_sequence(10)
# Out:
# 0.09099181073703366

# %% [markdown]
# ### exponential prior topology
# ### population trajectory prior on the coalescent time
#
# ### I already had likelihood partially labelled
#
# #### 1. plug in log(likelihood * prior topology* prior coalescent)
# #### 2. q only needs to approximate the prior coalescent time
# #### 3. q can be product of n indepdent exponential distribution
# #### 4. take gradient of q from each lambda from n indepdent exponential distribution
#
# rate of coalescent, branch length time informed by data
# Ne is a function of the coalescent time, weight on the prior of the branch length. assume it is a constant function, do variational infernece, people only use the information from mutation.
# recalibration method,
#
# $$ \exp(-\lambda t)$$
# $$-\lambda t$$
#
# $$p(topology | time, Ne) * p(time | Ne) * p( Ne)$$
#
# z = t,
# continous relaxation
#
#
#
# $$p($$

# %%
from math import factorial
def construct_F_matrix(states):
    F_mat = np.zeros((len(states), len(states)))
    
    n = len(states)
    
    #########update diagonals##################
    for i in range(F_mat.shape[0]):
        F_mat[i,i] = i+2
    subtraction_time = {i:0 for i in range(F_mat.shape[0])}
    #########update off-diagonal###############
    for j in range(F_mat.shape[0]):
        start_val = F_mat[j,j]
        left_child, right_child = states[n-1-j]
        if type(left_child) in [int, float]:
            subtraction_time[n - left_child] -= 1
        if type(right_child) in [int, float]:
            subtraction_time[n - right_child] -= 1
        for i in range(j+1, F_mat.shape[0]):
            F_mat[i,j] = F_mat[i-1,j] + subtraction_time[i]
            
    return F_mat

F_mat = construct_F_matrix(states)
        

    
def get_labels(states):
    dict_ = {}
    labels = []
    for level in states:
        left, right = level[0], level[1]
        if type(left) not in [int, float]:
            labels.append(left)
            if left not in dict_:
                dict_[left] = 1
            else:
                dict_[left] += 1
                
        if type(right) not in [int, float]:
            labels.append(right)
            if right not in dict_:
                dict_[right] = 1
            else:
                dict_[right] += 1
                
    return dict_, labels
            
    
def compute_num_partially_labelled_trees(states):
    dict_, labels = get_labels(states)
    num_two_children = 0
    for level in states:
        if (type(level[0]) not in [int, float]) and (type(level[1]) not in [int, float]):
            num_two_children += 1
    return compute_num_partailly_labelled_trees_recurse(states, num_two_children, dict_)

def compute_num_partailly_labelled_trees_recurse(states, num_two_children, dict_):

    result = 0
    if num_two_children == 0:
        cts = []
        tots = 0
        for label in dict_:
            tots += dict_[label]
            cts.append(dict_[label])
            
        result = factorial(tots)
        for ct in cts:
            result = result/factorial(ct)
        return result
    else:
        uniques = list(dict_.keys())
        for i in range(len(uniques)):
            label1 = uniques[i]
            if dict_[label1] >= 2:
                dict_[label1] -= 2
                if dict_[label1] <= 0:
                    dict_.pop(label1, None)
                result_dup = compute_num_partailly_labelled_trees_recurse(states, num_two_children - 1, dict_)
                result = result + result_dup
                if label1 not in dict_:
                    dict_[label1] = 0
                dict_[label1] += 2
                
            for j in range(i+1, len(uniques)):
                label1, label2 = uniques[i], uniques[j]
                dict_[label1] -= 1
                dict_[label2] -= 1
                if dict_[label1] <= 0:
                    dict_.pop(label1, None)
                if dict_[label2] <= 0:
                    dict_.pop(label2, None)
                result_nodup = compute_num_partailly_labelled_trees_recurse(states, num_two_children - 1, dict_)
                result = result + result_nodup
                if label1 not in dict_:
                    dict_[label1] = 0
                if label2 not in dict_:
                    dict_[label2] = 0
                dict_[label1] += 1
                dict_[label2] += 1
                
        return result

# %%
states = [['a', 'b'],['b', 1],['a', 2],['c',3]]
# get_labels(states)
# # F_mat = construct_F_matrix(states)
# # F_mat

compute_num_partially_labelled_trees(states)
# Out:
# 18.0

# %%
states
compute_num_partially_labelled_trees(states)
# Out:
# 18.0

# %%
states = [['l1', 'l2'],[1, 'l3'],['l4', 'l5'],[2,3]]
F_mat = construct_F_matrix(states)
F_mat
# Out:
# array([[2., 0., 0., 0.],
#        [1., 3., 0., 0.],
#        [0., 2., 4., 0.],
#        [0., 2., 3., 5.]])

# %%
states = [['l4', 'l5'],['l1','l2'],[2, 'l3'],[1,3]]
F_mat = construct_F_matrix(states)
F_mat
# Out:
# array([[2., 0., 0., 0.],
#        [1., 3., 0., 0.],
#        [1., 2., 4., 0.],
#        [0., 1., 3., 5.]])

# %%
states = [['l2', 'l3'],['l4','l5'],[1, 2],['l1',3]]
F_mat = construct_F_matrix(states)
F_mat
# Out:
# array([[2., 0., 0., 0.],
#        [1., 3., 0., 0.],
#        [1., 2., 4., 0.],
#        [1., 1., 3., 5.]])

# %%
states = [['l4', 'l5'],['l3',1],['l2', 2],['l1',3]]
F_mat = construct_F_matrix(states)
F_mat
# Out:
# array([[2., 0., 0., 0.],
#        [1., 3., 0., 0.],
#        [1., 2., 4., 0.],
#        [1., 2., 3., 5.]])

# %% [markdown]
# #### Need to use the prior for partially labelled trees instead of unlabelled tree

# %%
def compute_stationary_probability(states):
    ####aabb: 0, aabc: 0,aaba: 1/2, abca,  abab
    stationary_prob = 0
    for i in range(1, len(states)):
        s1, s2, s3, s4 = states[i-1][0], states[i-1][1], states[i][0], states[i][1]
        c1 = s1 == s3
        c2 = s1 == s4
        c3 = s2 == s3
        c4 = s2 == s4
        prob = (c1 + c2 + c3 +c4)/4
        stationary_prob += prob*1/(len(states)-1)
        
    return stationary_prob

# %%
states = [['C', 'C'],['A', 'G'], ['T', 1], ['T', 2], ['A', 4], [3,5], ['A', 6]]
compute_stationary_probability(states)
likeli
# Out:
# 0.041666666666666664

# %%
def markov_chain_forward(n, states):
    prob, reverse_prob = 0,0
    stationary_prob = compute_stationary_probability(states)
    k = np.random.randint(low= 1, high = n-1)
    swap1 = np.random.randint(low=0, high = 2) ###output 0, 1
    swap2 = np.random.randint(low=0, high = 2) ###output 0, 1
    ##swap from left to right should be good
    ####k is original k
    #### states[k-1]: kth state, states[k]: k+1 state 
    #max k can be n-2
    status_firstchild = type(states[k][swap2]) in [int, float]
    if status_firstchild:
        status_firstchild = states[k][swap2]

    ###compute forward prob
    if status_firstchild < k:####make the swap
        if states[k-1][swap1] == states[k][swap2]:
            prob = stationary_prob
        else: 
            prob = 1/4
            ##aabc
            status_secondchild = (type(states[k][1-swap2]) in [int, float])
            if status_secondchild == 1:
                status_secondchild = states[k][1- swap2]
            if status_secondchild < k:
                if states[k][swap2] == states[k][1 - swap2]:
                    prob = prob * 2
                if states[k-1][swap1] == states[k-1][1-swap1]:
                    prob = prob * 2
            else: ###not elible to swap for 1 - swap2
                prob = 1/2
                if states[k-1][swap1] == states[k-1][1 - swap1]:
                    prob = prob * 2
            prob = prob/(n-2)

        states[k-1][swap1], states[k][swap2] = states[k][swap2], states[k-1][swap1]
        ###compute reverse prob
        if states[k-1][swap1] == states[k][swap2]:
            reverse_prob = prob
        else:
            reverse_prob = 1/4
            status_secondchild = (type(states[k][1-swap2]) in [int, float])
            if status_secondchild == 1:
                status_secondchild = states[k][1- swap2]
            if status_secondchild < k:
                if states[k][swap2] == states[k][1 - swap2]:
                    reverse_prob = reverse_prob * 2
                if states[k-1][swap1] == states[k-1][1-swap1]:
                    reverse_prob = reverse_prob * 2
            else: ###not elible to swap for 1 - swap2
                reverse_prob = 1/2
                if states[k-1][swap1] == states[k-1][1 - swap1]:
                    reverse_prob = reverse_prob * 2
            reverse_prob = reverse_prob/(n-2)
        return True, prob, reverse_prob
    else:###dont make the swap
        return False, prob, reverse_prob

        
def markov_chain_seq(n, sequence):
    k = np.random.randint(low= 1, high = n-1)
    swap1 = np.random.randint(low=0, high = 2) ###output 0, 1
    swap2 = np.random.randint(low=0, high = 2) ###output 0, 1
    state = sequence[0]
    try:
        if state[k][swap2] < k:
            for x in range(len(sequence)):
                sequence[x][k-1][swap1], sequence[x][k][swap2] =  sequence[x][k][swap2],sequence[x][k-1][swap1]
            return True
        else:
            return False
    except:
        for x in range(len(sequence)):
            sequence[x][k-1][swap1], sequence[x][k][swap2] =  sequence[x][k][swap2],sequence[x][k-1][swap1]
        return True

# %%
markov_chain_forward(len(states)+1, states)
# Out:
# (False, 0, 0)

# %%
n = 3
# states = [['C', 'C'],['A', 'G'], ['T', 1], ['T', 2], ['A', 4], [3,5], ['A', 6]]
coalescent_times = [.15, .6, 2]
states = [['A', 'A'],['C', 'T'], [1, 2]]
mmap = {'A':0, 'C':1, 'G':2, 'T':3}
q = np.ones((4,4))/3
for i in range(4):
    q[i,i]= -1
evals, evecs = la.eig(q)
evec_inv = la.inv(evecs)

states
# Out:
# [['A', 'A'], ['C', 'T'], [1, 2]]

# %% [markdown]
# ### Validation on the likelihood Computation

# %%
l = []
simulations = []
from copy import deepcopy
for i in range(50):
    states[0][0] = np.random.choice(['A','C','G','T'])
    states[0][1] = np.random.choice(['A','C','G','T'])
    states[1][0] = np.random.choice(['A','C','G','T'])
    states[1][1] = np.random.choice(['A','C','G','T'])
    
    print(i, 'loop')
    print(states)
    s = deepcopy(states)
    l.append(likelihood(s, 3))
    p = 0
    for j in range(100000):
        if j %20000 == 0:
            print(j//20000, 'iter')
        p += mc_probability(s, coalescent_times)[0]
    simulations.append(p/100000)
#         markov_chain_forward(n, states)

# %%
l = np.array(l)

# %%
simulations = np.array(simulations)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(np.log(l), np.log(simulations))
plt.xlabel('log likelihood')
plt.ylabel('simulated monte carlo probability')
# Out:
# Text(0,0.5,'simulated monte carlo probability')

# %%
import numpy as np
np.corrcoef(np.log(l), np.log(simulations))
# Out:
# array([[1.        , 0.99583784],
#        [0.99583784, 1.        ]])

# %%
r_squared = 1 - np.sum((np.array(l) - np.array(simulations))**2)/np.sum((np.array(simulations) - np.mean(np.array(simulations)))**2)

print(r_squared, 'r_squared')
# Out:
# 0.9983294680025736 r_squared

# %% [markdown]
# ### accelerate likelihood computation by changing a minor part of the tree.

# %%
import numpy.linalg as la
def Pij(t, evecs, evals, evec_inv):
    return evecs@np.diag(np.exp(evals*t))@evec_inv
    
def mc_probability(states, coalescent_times):
    mmap = {'A':0, 'C':1, 'G':2, 'T':3}
    global labels
    labels = [1]
    root_label = np.zeros(4)
    root_label[np.random.choice([0,1,2,3])] = 1
    mc_probability_recurse(states, coalescent_times, len(states), root_label)
    return labels
       
def mc_probability_recurse(states, coalescent_times, subroot, subroot_label):
    ###simulate from subroot with a fixed label
    
    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    
    if type(left_child) not in [int, float]:
        left_time = coalescent_times[subroot-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_left)
        if simulated_leaf == left_child:
            labels[0] = labels[0]*1
        else:
            labels[0] = 0
        
#         labels.add(left_child)
    else:
        left_time = coalescent_times[subroot-1] - coalescent_times[left_child-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_left)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        mc_probability_recurse(states, coalescent_times, left_child, newlabel)

    if type(right_child) not in [int, float]:
        right_time = coalescent_times[subroot-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_right)
        if simulated_leaf == right_child:
            labels[0] = labels[0]*1
        else:
            labels[0] = 0    
#         labels.add(left_child)
    else:
        right_time = coalescent_times[subroot-1] - coalescent_times[right_child-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_right)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        mc_probability_recurse(states, coalescent_times, right_child, newlabel)
        return
        


from copy import deepcopy
def generate_data(states, coalescent_times):
    
    mmap = {'A':0, 'C':1, 'G':2, 'T':3}
    q = np.ones((4,4))/3
    for i in range(4):
        q[i,i]= -1
    evals, evecs = la.eig(q)
    evec_inv = la.inv(evecs)
    root_label = np.zeros(4)
    root_label[np.random.choice([0,1,2,3])] = 1

    generate_data_recurse(states, coalescent_times, len(states), root_label)
    
    
     
    
def generate_data_recurse(states, coalescent_times, subroot, subroot_label):
    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    if type(left_child) not in [int, float]:
        ####it is a leaf, change the state based on the sampled leaf
        left_time = coalescent_times[subroot-1]
        
        
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_left)
        states[subroot-1][0] = simulated_leaf
    else:
        ###generate intermediate node
        left_time = coalescent_times[subroot-1] - coalescent_times[left_child-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_left)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        generate_data_recurse(states, coalescent_times, left_child, newlabel)
        
    
    if type(right_child) not in [int, float]:
        right_time = coalescent_times[subroot-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label 
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_right)
        states[subroot-1][1] = simulated_leaf
        
    else:
        right_time = coalescent_times[subroot-1] - coalescent_times[right_child-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_right)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        generate_data_recurse(states, coalescent_times, right_child, newlabel)


def compute_likelihood(states, site, subroot, coalescent_times):

    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    left_child_likelihood, right_child_likelihood = 0,0
    left_t, right_t = -1,-1
    
    
    if type(left_child) not in [int, float]:
        init_state = np.zeros(4)
        init_state[mmap[left_child]] = 1
        left_child_likelihood = init_state
        left_t = coalescent_times[subroot-1]
    
    else:   
        left_child_likelihood = compute_likelihood(states, site, left_child)
        left_t = coalescent_times[subroot-1] - coalescent_times[left_child-1] 
        
    if type(right_child) not in [int, float]:
        init_state = np.zeros(4)
        init_state[mmap[right_child]] = 1
        right_t = coalescent_times[subroot-1]
        right_child_likelihood = init_state
        
        ###gradient corresponding to coalescent time?
        ###have the
    else:
        
        right_child_likelihood = compute_likelihood(states, site, right_child)
        right_t = coalescent_times[subroot-1] - coalescent_times[right_child-1]   
    likelihood = (Pij(left_t, evecs, evals, evec_inv)@left_child_likelihood) *\
    (Pij(right_t, evecs, evals, evec_inv)@right_child_likelihood)
    return likelihood

mmap = {'A':0, 'C':1, 'G':2, 'T':3}
q = np.ones((4,4))/3
for i in range(4):
    q[i,i]= -1
evals, evecs = la.eig(q)
evec_inv = la.inv(evecs)


def likelihood(states, root, coalescent_times):
    
    """
    root is the number of leaves - 1
    
    """
    likelihood_vec = compute_likelihood(states, 0, root, coalescent_times)
    final_likelihood = 0.25*np.sum(likelihood_vec)
    return final_likelihood


def seq_likelihood(sequence, n):
    l = 1
    for state in sequence:
        ll = likelihood(state, n)
        l *= ll
    return l

def compute_prior(states, fmat0):
    num_trees = compute_num_partially_labelled_trees(states)
    cur_fmat = construct_F_matrix(states)
    l2_distance = np.sum((cur_fmat - fmat0)**2)
    return 1/num_trees * np.exp(-l2_distance)

# %%
coalescent_times = [7.3, .5, .9]
states = [['A', 'C'],['G', 'G'], [1, 2]]
likelihood(states, 3)
# Out:
# 0.0048501857269609506

# %%
import numpy as np
np.log(0.003904)
# Out:
# -5.545753610431291

# %% [markdown]
# ### test whether generate data gives the correct generation

# %%
coalescent_times = [.2,.5,.6,.8,1.3,1.9,2.9]
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]

freq = {}
for i in range(100000):
    generate_data(states, coalescent_times)
    cur_states = deepcopy(states)
    if str(cur_states) not in freq:
        freq[str(cur_states)] = 1
    else:
        freq[str(cur_states)] += 1

# %%
list(freq.keys())[0]

# list(freq.keys())[0].strip('][').split(', ')
# Out:
# "[['C', 'C'], ['G', 'G'], ['A', 1], ['C', 2], ['C', 4], [3, 5], ['G', 6]]"

# %%
sorted(freq.items(), key=lambda item: item[1],reverse = True)[:10]
# Out:
# [("[['A', 'A'], ['A', 'A'], ['A', 1], ['A', 2], ['A', 4], [3, 5], ['C', 6]]",
#   43),
#  ("[['G', 'G'], ['G', 'G'], ['G', 1], ['G', 2], ['G', 4], [3, 5], ['C', 6]]",
#   43),
#  ("[['T', 'T'], ['C', 'C'], ['T', 1], ['C', 2], ['C', 4], [3, 5], ['G', 6]]",
#   38),
#  ("[['C', 'C'], ['T', 'T'], ['C', 1], ['T', 2], ['T', 4], [3, 5], ['G', 6]]",
#   37),
#  ("[['T', 'T'], ['A', 'A'], ['T', 1], ['A', 2], ['A', 4], [3, 5], ['G', 6]]",
#   34),
#  ("[['C', 'C'], ['G', 'G'], ['C', 1], ['G', 2], ['G', 4], [3, 5], ['G', 6]]",
#   33),
#  ("[['T', 'T'], ['C', 'C'], ['T', 1], ['C', 2], ['C', 4], [3, 5], ['C', 6]]",
#   32),
#  ("[['T', 'T'], ['T', 'T'], ['T', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]]",
#   32),
#  ("[['G', 'G'], ['T', 'T'], ['G', 1], ['T', 2], ['T', 4], [3, 5], ['T', 6]]",
#   32),
#  ("[['T', 'T'], ['T', 'T'], ['T', 1], ['T', 2], ['T', 4], [3, 5], ['C', 6]]",
#   32)]

# %%
sorted(freq.items(), key=lambda item: item[1],reverse = False)[:10]
# Out:
# [("[['T', 'G'], ['C', 'C'], ['C', 1], ['G', 2], ['C', 4], [3, 5], ['G', 6]]",
#   1),
#  ("[['C', 'C'], ['A', 'T'], ['G', 1], ['C', 2], ['T', 4], [3, 5], ['G', 6]]",
#   1),
#  ("[['G', 'C'], ['G', 'C'], ['T', 1], ['C', 2], ['T', 4], [3, 5], ['A', 6]]",
#   1),
#  ("[['G', 'A'], ['T', 'G'], ['T', 1], ['G', 2], ['C', 4], [3, 5], ['A', 6]]",
#   1),
#  ("[['T', 'A'], ['C', 'G'], ['A', 1], ['A', 2], ['A', 4], [3, 5], ['A', 6]]",
#   1),
#  ("[['G', 'A'], ['G', 'T'], ['A', 1], ['C', 2], ['A', 4], [3, 5], ['T', 6]]",
#   1),
#  ("[['T', 'G'], ['T', 'T'], ['C', 1], ['A', 2], ['A', 4], [3, 5], ['G', 6]]",
#   1),
#  ("[['G', 'G'], ['T', 'G'], ['A', 1], ['C', 2], ['G', 4], [3, 5], ['A', 6]]",
#   1),
#  ("[['C', 'A'], ['T', 'C'], ['G', 1], ['C', 2], ['T', 4], [3, 5], ['T', 6]]",
#   1),
#  ("[['G', 'T'], ['T', 'G'], ['A', 1], ['G', 2], ['C', 4], [3, 5], ['C', 6]]",
#   1)]

# %%
likelihood([['A', 'A'], ['A', 'A'], ['A', 1], ['A', 2], ['A', 4], [3, 5], ['C', 6]], 7)*100000
# Out:
# 29.518394210451508

# %%
likelihood([['G', 'G'], ['G', 'G'], ['G', 1], ['G', 2], ['G', 4], [3, 5], ['C', 6]], 7)*100000
# Out:
# 29.518394210451525

# %%
likelihood([['T', 'T'], ['C', 'C'], ['T', 1], ['C', 2], ['C', 4], [3, 5], ['G', 6]], 7)*100000
# Out:
# 25.09778779010806

# %%
likelihood([['C', 'C'], ['T', 'T'], ['C', 1], ['T', 2], ['T', 4], [3, 5], ['G', 6]], 7)*100000
# Out:
# 25.09778779010805

# %%
likelihood([['T', 'T'], ['T', 'T'], ['T', 1], ['T', 2], ['T', 4], [3, 5], ['C', 6]], 7) *100000
# Out:
# 29.518394210451454

# %%
likelihood([['T', 'G'], ['C', 'C'], ['C', 1], ['G', 2], ['C', 4], [3, 5], ['G', 6]], 7)*100000
# Out:
# 0.7892108033376971

# %%
likelihood([['G', 'T'], ['T', 'G'], ['A', 1], ['G', 2], ['C', 4], [3, 5], ['C', 6]], 7)*100000
# Out:
# 0.38648965494562204

# %%
likelihood([['G', 'T'], ['T', 'G'], ['A', 1], ['G', 2], ['C', 4], [3, 5], ['C', 6]], 7)*100000
# Out:
# 0.38648965494562204

# %% [markdown]
# ### Start MCMC sampling posterior

# %%
coalescent_times = [.2,.5,.6,.8,1.3,1.9,2.9]
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
# likelihood(states, 7)

# %%
from copy import deepcopy

# %% [markdown]
# ### testing on sample a single site

# %%
import copy
posterior_sampled = []
n=7 ######n = 8 actually, here n = 7 means that there are 7 coalescent events
prob_avg = 0
start_state = deepcopy(states)
mean_state = [['G', 'G'],['C', 'A'], ['C', 'A'], ['C', 1], ['A', 2], [3,4], [5, 6]]
###upgma, to have an initial tree, uses the data (should be close to the maximum likelihood tree)
fmat0 = construct_F_matrix(mean_state)
for i in range(10000):
    if i%1000 == 0:
        print(i)
    prev_state = deepcopy(states)
    
    state_flag, forward_prob, reverse_prob = markov_chain_forward(n+1, states)
    while not state_flag:
        state_flag, forward_prob, reverse_prob = markov_chain_forward(n+1, states)
            
    new_state = deepcopy(states)
    
    prev_likelihood = likelihood(prev_state, n)
    new_likelihood = likelihood(new_state, n)
    prior_prev_state = compute_prior(prev_state, fmat0)
    prior_new_state = compute_prior(new_state, fmat0)
    
    acceptance_prob = min(new_likelihood * prior_new_state * reverse_prob/ (prev_likelihood * prior_prev_state * forward_prob), 1)
    prob_avg += acceptance_prob
    U = np.random.rand()
    if U < acceptance_prob:
        ###accept
        if i > 999:
            posterior_sampled.append(deepcopy(states))
        prev_state = deepcopy(states)
    else:
        states = deepcopy(prev_state)
prob_avg /= 10000
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
# posterior_sampled
# [['a','b'],['a','c'],[3,4]]
# [['a','b'], ['a','c'],[3,4]]
# 1. mcmc without the new prior
# 2. mcmc with the new prior
# same markov chain
# black box paper. 

### black box variational for branch length, try this with the new prior
# Out:
# [[['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], [2, 'C'], [5, 4], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], ['A', 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], ['A', 'C'], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], [2, 'C'], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'C'], [2, 'A'], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [2, 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], ['C', 'C'], [2, 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], [1, 'C'], [2, 'C'], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], [1, 'C'], [2, 'C'], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'A'], [1, 'C'], [2, 'C'], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'A'], [1, 'C'], [2, 'C'], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'A'], ['C', 'C'], [2, 1], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'A'], ['C', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['C', 'G'], ['G', 'A'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['C', 'G'], ['G', 'A'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['C', 'G'], ['G', 'A'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'A'], ['C', 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'A'], ['C', 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'A'], ['C', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 1], ['A', 'A'], ['C', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['A', 'G'], ['G', 1], ['A', 'A'], ['C', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['A', 'G'], ['G', 1], ['A', 'A'], ['C', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['A', 'G'], ['G', 'A'], [1, 'A'], ['C', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'A'], ['C', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'C'], ['A', 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], [1, 2], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], ['C', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['C', 'A'], ['A', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 'C'], [3, 2], [1, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 'A'], ['A', 'A'], [3, 2], [1, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 'A'], [3, 2], [1, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 2], [3, 'A'], [1, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 2], [1, 'A'], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 'A'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 1], ['A', 'A'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 1], ['A', 'A'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 1], ['A', 'A'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [2, 'C'], ['A', 1], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [2, 'C'], ['A', 1], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [2, 'A'], ['A', 1], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [2, 'A'], ['A', 1], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 4], [3, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 4], [3, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [2, 'A'], ['C', 1], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [2, 'C'], ['A', 1], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 1], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 2], [1, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 2], [1, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'A'], ['A', 'A'], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'A'], ['A', 'A'], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'A'], ['A', 'A'], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'A'], ['A', 'A'], [4, 'C'], [2, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [4, 'C'], [2, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], [1, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], [1, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 'C'], [1, 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'C'], ['A', 'A'], ['A', 4], [3, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 1], ['C', 'C'], ['A', 'A'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], [1, 'C'], ['C', 'C'], ['A', 'A'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], [1, 'C'], ['C', 'C'], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 1], ['A', 'A'], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 'A'], ['A', 1], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['C', 'A'], ['A', 1], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['C', 'C'], ['A', 1], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['C', 1], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['C', 1], ['A', 4], [2, 3], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['C', 1], ['A', 4], [2, 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 4], [2, 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], [2, 4], ['A', 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], [2, 4], ['A', 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], [2, 3], ['A', 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], [2, 3], ['A', 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'G'], ['A', 'A'], [1, 'C'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], [2, 1], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'A'], ['G', 'A'], [2, 1], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], [2, 1], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'G'], ['A', 'C'], [2, 1], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'G'], [2, 1], ['C', 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'G'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'G'], ['A', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'G'], ['A', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'G'], ['C', 'A'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['G', 'A'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'G'], ['C', 'A'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'G'], [1, 'A'], ['C', 'C'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'A'], ['C', 'C'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'A'], ['C', 'C'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'C'], ['C', 'A'], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [1, 'C'], ['C', 'A'], ['C', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], ['C', 1], ['C', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 1], ['C', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 3], [1, 'C'], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 3], [1, 'C'], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 3], [1, 'C'], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 3], [1, 'C'], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 3], [1, 'C'], [4, 5], [2, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [4, 5], [2, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'C'], ['A', 3], [4, 5], [2, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [4, 5], [2, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 3], [2, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 1], ['C', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 5], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 1], ['C', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 2], ['C', 1], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 1], ['C', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 1], ['C', 2], [4, 5], [3, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['A', 'G'], ['A', 'G'], ['C', 'C'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], ['C', 3], [4, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], ['A', 3], [4, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], ['C', 3], [4, 2], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], ['A', 1], ['C', 3], [4, 2], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], ['C', 3], [4, 2], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 3], [4, 'C'], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 'G'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['G', 1], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['G', 'C'], [2, 1], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['G', 'C'], [2, 1], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 'G'], [2, 1], [5, 4], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], ['G', 'G'], [2, 1], [5, 4], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], ['G', 'G'], [2, 1], [5, 4], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], ['G', 'G'], [2, 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'G'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [2, 1], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], ['G', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], ['G', 2], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], ['G', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], [1, 'C'], ['G', 'A'], ['G', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], ['G', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [2, 1], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [2, 1], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [2, 1], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [2, 1], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], [2, 'C'], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], ['G', 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], ['G', 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], ['A', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], ['A', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], ['A', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['G', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['A', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['A', 1], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], ['G', 1], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 1], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 2], [1, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], ['G', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], ['G', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [2, 'C'], ['G', 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [2, 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [2, 'C'], ['G', 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], [2, 'A'], ['G', 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [2, 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [2, 1], ['G', 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'C'], [2, 1], ['G', 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'C'], [2, 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 'C'], [2, 'G'], [1, 'C'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 'C'], [2, 'C'], [1, 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 'C'], [2, 'C'], [4, 'G'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 2], ['C', 'C'], [4, 'G'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 2], ['G', 'C'], [4, 'C'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 2], ['G', 'C'], [4, 'C'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 2], ['G', 'C'], [4, 'C'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 2], ['G', 'G'], [4, 'C'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 2], ['C', 'G'], [4, 'G'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 2], ['C', 'G'], [4, 'G'], [3, 1], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 2], ['C', 'G'], [1, 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [2, 'G'], [1, 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [2, 'G'], [1, 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [2, 1], ['G', 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [2, 1], ['G', 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], ['G', 1], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'G'], ['C', 1], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], [1, 'G'], ['C', 'C'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'G'], [1, 'C'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 'G'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 4], ['G', 3], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [2, 'G'], [1, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [2, 'G'], [1, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 3], ['G', 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 'G'], [2, 'G'], [4, 5], [3, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [1, 'G'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 'G'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['C', 'C'], [1, 2], ['G', 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['C', 'A'], ['A', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 'G'], ['G', 2], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 'G'], ['G', 2], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 'G'], ['G', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], ['C', 'G'], ['G', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], ['C', 2], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 2], ['G', 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 2], ['G', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], [1, 'G'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'C'], ['G', 'G'], [2, 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'C'], ['G', 'A'], [2, 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], [1, 'A'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], [1, 'A'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], [1, 'A'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], [1, 'A'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], [1, 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], ['G', 'A'], [3, 1], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], ['G', 1], [3, 'A'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['C', 1], [3, 'A'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 1], ['C', 'C'], [3, 'A'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 1], ['C', 'C'], [3, 'A'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 1], ['C', 'C'], [2, 'A'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 1], ['C', 'C'], [2, 'A'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], [1, 'C'], ['C', 'C'], [2, 'A'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], [1, 'C'], ['C', 'C'], [4, 'A'], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [4, 'A'], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [4, 'A'], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [3, 'A'], [4, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], [2, 'C'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['A', 1], [2, 'C'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 1], ['A', 'C'], [2, 'C'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 1], ['A', 'C'], [2, 'C'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 1], ['A', 'C'], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['G', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 3], [4, 'A'], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 4], [3, 'A'], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], [2, 4], [5, 'A'], [3, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], ['A', 4], [5, 2], [3, 6]],
#  [['A', 'A'], ['G', 'G'], [1, 'C'], ['C', 'C'], ['A', 4], [5, 2], [3, 6]],
#  [['A', 'A'], ['G', 'G'], [1, 'C'], ['C', 'A'], ['C', 4], [5, 2], [3, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [1, 'A'], ['C', 4], [5, 2], [3, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [1, 'A'], ['C', 4], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 'A'], [1, 4], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 'A'], [1, 4], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 4], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 4], [3, 2], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 2], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [2, 1], ['A', 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [2, 'C'], ['A', 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [1, 'C'], ['A', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [1, 'C'], ['A', 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [1, 'A'], ['C', 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 'A'], [1, 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 'A'], [1, 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 2], [5, 4], [3, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'G'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['C', 'G'], [1, 3], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [3, 'G'], [1, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 2], ['C', 1], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 1], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'G'], ['A', 'A'], ['C', 'C'], ['G', 1], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'G'], ['A', 'A'], ['G', 'C'], ['C', 1], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'G'], ['A', 'A'], ['G', 'C'], ['C', 1], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'G'], ['A', 'A'], ['G', 1], ['C', 'C'], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'G'], ['A', 'A'], ['G', 1], ['C', 'C'], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'G'], ['A', 'A'], ['G', 1], ['C', 'C'], ['C', 2], [5, 3], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['G', 1], ['C', 'C'], ['C', 2], [5, 3], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 1], ['G', 'C'], ['C', 2], [5, 3], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 1], ['C', 2], [5, 3], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['G', 1], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['G', 'C'], ['C', 1], ['C', 2], [5, 4], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['G', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['G', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 'C'], ['C', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], ['C', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], ['C', 2], [3, 5], [4, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [1, 2], [3, 5], [4, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [3, 2], [1, 5], [4, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [3, 'C'], ['A', 2], [1, 5], [4, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [3, 'C'], ['A', 2], [1, 4], [5, 6]],
#  [['A', 'G'], ['A', 'G'], ['C', 'C'], [3, 'C'], ['A', 2], [1, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [3, 'C'], ['A', 2], [1, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [2, 'C'], ['A', 3], [1, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [2, 'C'], ['A', 3], [1, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [2, 3], [1, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [2, 4], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 'C'], ['C', 'C'], [2, 4], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [2, 4], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [2, 'C'], ['A', 4], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], [2, 'C'], ['A', 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 2], [1, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 2], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], ['C', 2], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], [2, 'G'], ['C', 'C'], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], [2, 'C'], ['C', 'C'], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['G', 'G'], [2, 'C'], ['C', 'C'], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], [2, 'G'], ['C', 'C'], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], [2, 'C'], [1, 'A'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], [2, 'A'], [1, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], [2, 'A'], [1, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], [2, 'A'], [1, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], [2, 'A'], [1, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'G'], [1, 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 1], ['G', 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 1], ['G', 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], ['G', 'G'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [1, 'G'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 1], ['G', 'G'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [1, 'G'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [1, 'G'], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 1], ['C', 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 1], ['C', 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 1], ['C', 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 1], ['C', 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [1, 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [2, 'C'], [1, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [1, 'C'], [2, 'G'], [4, 5], [3, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [1, 'C'], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [1, 'G'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], [1, 'A'], ['G', 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], ['G', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], ['G', 1], [4, 'C'], [3, 2], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['G', 'A'], ['G', 1], [4, 'C'], [3, 2], [5, 6]],
#  [['A', 'A'], ['C', 'C'], [1, 'A'], ['G', 'G'], [4, 'C'], [3, 2], [5, 6]],
#  [['A', 'A'], ['C', 'C'], [1, 'A'], ['G', 'C'], [4, 'G'], [3, 2], [5, 6]],
#  [['A', 'A'], ['C', 'C'], [1, 'A'], ['G', 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'A'], ['G', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], ['A', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], ['A', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'C'], ['A', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 1], ['A', 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 1], ['A', 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 1], ['A', 2], ['C', 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 1], ['A', 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'A'], [1, 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], [3, 'C'], [1, 'G'], [2, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], [3, 'C'], [1, 'G'], [2, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], [3, 'C'], [1, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [3, 'C'], [1, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['C', 'G'], [1, 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 'C'], [1, 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 1], ['C', 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 1], ['G', 'A'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['C', 1], ['C', 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'C'], ['G', 'A'], ['C', 1], ['C', 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'C'], ['G', 'A'], ['A', 1], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'C'], ['G', 1], ['A', 'A'], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 1], ['A', 'A'], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 1], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'C'], ['G', 'A'], ['A', 1], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'C'], ['G', 'A'], ['A', 1], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['A', 'C'], ['G', 'A'], ['C', 1], ['A', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['A', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['A', 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['A', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 1], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['C', 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['C', 'A'], [3, 'G'], [2, 5], [4, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['C', 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 1], ['C', 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 'C'], [1, 'C'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 'C'], [1, 'A'], [3, 'G'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 'C'], [1, 'G'], [3, 'A'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 1], ['C', 'G'], [3, 'A'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 'C'], [1, 'G'], [3, 'A'], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 'C'], ['A', 'G'], [3, 1], [2, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['C', 'C'], ['A', 'G'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 'C'], ['C', 'G'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 'C'], [2, 'G'], ['C', 1], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 'G'], [2, 'C'], ['C', 1], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 'G'], ['C', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'C'], ['A', 'A'], ['A', 'G'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'G'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'G'], ['C', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['A', 'A'], ['C', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['C', 'A'], ['A', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['A', 'A'], ['C', 1], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['A', 'A'], ['C', 'C'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['A', 'A'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'C'], ['A', 'A'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'C'], ['A', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['A', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['A', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'G'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'G'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'G'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [2, 'C'], [4, 5], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], [1, 'G'], [2, 'C'], [4, 3], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['C', 'C'], ['C', 'G'], [2, 1], [4, 3], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], ['C', 'G'], [2, 1], [4, 3], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 2], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 2], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 2], [1, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['C', 'G'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['G', 'C'], ['C', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'A'], ['C', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['A', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['G', 'C'], ['A', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['A', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['A', 'C'], ['G', 'C'], [4, 1], [2, 3], [5, 6]],
#  [['A', 'A'], ['G', 'C'], ['A', 'C'], ['G', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], ['G', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [2, 'C'], ['G', 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'G'], [2, 'C'], ['G', 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'G'], ['G', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'A'], ['G', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'A'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'A'], ['C', 'G'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'C'], ['A', 'G'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], [1, 'C'], [2, 'G'], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], ['G', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], ['G', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'C'], ['G', 'C'], [2, 1], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['A', 'G'], ['C', 'C'], [2, 1], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], ['C', 'A'], [2, 1], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], ['C', 2], ['A', 1], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], ['C', 2], ['A', 3], [5, 1], [4, 6]],
#  [['A', 'A'], ['C', 'G'], ['C', 'G'], ['A', 2], ['C', 3], [5, 1], [4, 6]],
# ...
#  [['A', 'G'], ['C', 'C'], ['C', 'A'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'G'], ['C', 'C'], ['A', 'A'], ['C', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'G'], ['C', 'C'], ['A', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'G'], ['C', 'A'], ['C', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'G'], ['C', 'C'], ['A', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'G'], ['C', 'C'], ['A', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'C'], ['C', 'G'], ['A', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'G'], ['C', 'C'], ['A', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'C'], ['C', 'G'], ['A', 'C'], ['A', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'C'], ['C', 'G'], ['A', 'A'], ['C', 1], [2, 'G'], [3, 5], [4, 6]],
#  [['A', 'C'], ['C', 'G'], ['A', 'A'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'C'], ['A', 'G'], ['C', 'A'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'C'], ['A', 'A'], ['C', 'G'], ['C', 1], [2, 'G'], [3, 4], [5, 6]],
#  [['A', 'C'], ['A', 'A'], ['C', 'G'], ['C', 1], [2, 'G'], [5, 4], [3, 6]],
#  [['A', 'C'], ['A', 'A'], ['C', 'G'], ['G', 1], [2, 'C'], [5, 4], [3, 6]],
#  [['A', 'C'], ['A', 'A'], ['G', 'G'], ['C', 1], [2, 'C'], [5, 4], [3, 6]],
#  [['A', 'C'], ['A', 'A'], ['G', 'G'], ['C', 2], [1, 'C'], [5, 4], [3, 6]],
#  [['A', 'C'], ['A', 'A'], ['G', 'G'], ['C', 2], [1, 'C'], [5, 4], [3, 6]],
#  [['A', 'C'], ['A', 'A'], ['G', 'G'], ['C', 1], [2, 'C'], [5, 4], [3, 6]],
#  [['A', 'C'], ['A', 'A'], ['G', 'G'], [2, 1], ['C', 'C'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [2, 1], ['C', 'C'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [2, 'C'], [1, 'C'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], ['C', 'C'], [1, 2], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], ['C', 'C'], [1, 2], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], ['C', 'C'], [3, 2], [5, 1], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], ['C', 'C'], [3, 1], [5, 2], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], ['C', 'C'], [2, 1], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [1, 'C'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [1, 'C'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [1, 'C'], [2, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [2, 'C'], [1, 'C'], [5, 3], [4, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [2, 'C'], [1, 'C'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [2, 'C'], [1, 'C'], [5, 4], [3, 6]],
#  [['A', 'A'], ['C', 'A'], ['G', 'G'], [1, 'C'], [2, 'C'], [5, 4], [3, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 'G'], [1, 'C'], [2, 'C'], [5, 4], [3, 6]],
#  [['C', 'A'], ['A', 'A'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'C'], [1, 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [1, 'C'], ['G', 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'C'], ['A', 'A'], [1, 'C'], ['G', 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'C'], ['A', 'A'], [1, 'C'], ['G', 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'C'], ['A', 'A'], [1, 'C'], ['G', 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [1, 'C'], ['G', 'G'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [1, 'G'], ['G', 'C'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [1, 'G'], ['G', 'C'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [1, 'G'], ['G', 'C'], [3, 'C'], [2, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], [1, 'G'], ['G', 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 5], [4, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [1, 'C'], [2, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'C'], ['G', 'G'], [2, 'C'], [1, 'C'], [3, 4], [5, 6]],
#  [['A', 'A'], ['A', 'G'], ['G', 'C'], [2, 'C'], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['G', 'C'], [2, 'C'], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['G', 'C'], [2, 'C'], [1, 'C'], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['G', 'C'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['A', 'A'], ['G', 'C'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['A', 'C'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 'C'], ['C', 'C'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 'A'], [1, 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['A', 'A'], ['G', 'G'], ['C', 'C'], ['A', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['C', 'C'], ['A', 1], ['C', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'A'], ['G', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 1], ['A', 2], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 2], ['A', 1], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [2, 1], [3, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [2, 3], [1, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], ['C', 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], ['C', 'A'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'A'], ['C', 'C'], [1, 3], [2, 4], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'A'], ['C', 'C'], [1, 4], [2, 3], [5, 6]],
#  [['G', 'A'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [1, 4], [2, 3], [5, 6]],
#  [['G', 'C'], ['A', 'G'], ['A', 'A'], ['C', 'C'], [1, 4], [2, 3], [5, 6]],
#  [['G', 'C'], ['A', 'G'], ['A', 'A'], ['C', 'C'], [2, 4], [1, 3], [5, 6]],
#  [['G', 'C'], ['A', 'G'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'C'], ['G', 'G'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'G'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['A', 'G'], ['C', 'G'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['C', 'G'], ['A', 'G'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 1], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 3], [4, 1], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 3], [4, 1], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], ['C', 'C'], [2, 3], [4, 1], [5, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], [2, 'C'], ['C', 3], [4, 1], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [2, 'A'], ['C', 'C'], ['C', 3], [4, 1], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [2, 'A'], ['C', 'C'], [1, 3], [4, 'C'], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [2, 'A'], ['C', 'C'], [1, 3], [4, 'C'], [5, 6]],
#  [['G', 'G'], ['A', 'A'], [2, 'A'], ['C', 'C'], [1, 3], [5, 'C'], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], [2, 'C'], [1, 3], [5, 'C'], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'A'], [2, 'C'], [1, 3], [5, 'C'], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [2, 'A'], [1, 3], [5, 'C'], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [2, 'A'], [1, 3], [4, 'C'], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], [2, 'A'], [1, 3], [4, 'C'], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], [3, 'A'], [1, 2], [4, 'C'], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], [3, 'A'], [1, 'C'], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], [3, 'A'], [1, 'C'], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['C', 'A'], [1, 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['C', 'A'], [1, 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'A'], ['C', 'C'], ['A', 'A'], [1, 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], ['A', 'A'], [1, 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'C'], ['A', 'A'], [1, 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 'C'], [1, 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 'C'], [1, 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'A'], ['A', 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], [1, 'A'], ['A', 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'A'], ['C', 'A'], ['A', 1], ['C', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], ['C', 2], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], ['C', 1], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], ['C', 1], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], ['C', 1], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], [2, 'A'], ['A', 'A'], ['C', 1], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'A'], [2, 'C'], ['A', 'A'], ['C', 1], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'A'], [2, 'C'], ['A', 'A'], ['C', 1], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['A', 2], ['C', 1], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['A', 2], ['C', 1], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['A', 2], ['C', 1], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['A', 'C'], [2, 1], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['A', 'C'], ['A', 1], [2, 'C'], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'A'], [1, 'C'], ['A', 'A'], [2, 'C'], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 1], ['A', 'C'], ['A', 'A'], [2, 'C'], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 1], ['A', 'A'], [2, 'C'], [5, 4], [3, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 1], ['A', 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [2, 'A'], [1, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 'A'], [1, 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 1], ['A', 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 2], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'A'], ['C', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], [1, 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['C', 'A'], [1, 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['C', 'A'], [1, 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'C'], ['A', 3], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], [1, 'C'], ['A', 'A'], ['C', 'C'], ['A', 3], [4, 2], [5, 6]],
#  [['G', 'G'], [1, 'C'], ['A', 'A'], ['C', 'C'], ['A', 2], [4, 3], [5, 6]],
#  [['G', 'G'], [1, 'C'], ['A', 'A'], ['C', 'C'], [3, 2], [4, 'A'], [5, 6]],
#  [['G', 'G'], [1, 'C'], ['A', 'A'], ['C', 'C'], [3, 2], [5, 'A'], [4, 6]],
#  [['G', 'G'], [1, 'C'], ['A', 'A'], ['C', 'C'], [3, 'A'], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'C'], [3, 'A'], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'A'], [3, 'C'], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'A'], [3, 'C'], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'A'], ['C', 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'C'], ['A', 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], [1, 'C'], ['C', 'A'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'C'], ['C', 1], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [3, 'A'], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'C'], [3, 'A'], [5, 2], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [2, 'A'], [1, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'A'], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 'C'], [1, 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'A'], ['C', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [2, 'A'], [5, 3], [4, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'C'], [1, 'C'], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 1], ['C', 'C'], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'C'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'C'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['A', 'C'], ['A', 'C'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 1], [2, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [5, 3], [4, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 1], [2, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['A', 2], [1, 'C'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 2], [1, 'A'], [4, 3], [5, 6]],
#  [['G', 'G'], ['C', 'C'], ['A', 'A'], ['C', 'A'], [1, 2], [4, 3], [5, 6]],
#  ...]

# %%
posterior_ll = []

for state in posterior_sampled:
    posterior_ll.append(likelihood(state, n))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(posterior_ll)
# Out:
# (array([1065.,  634.,  652.,  475.,  419.,  144.,    5.,   88.,   73.,
#           28.]),
#  array([2.87305446e-06, 2.52530566e-05, 4.76330587e-05, 7.00130608e-05,
#         9.23930630e-05, 1.14773065e-04, 1.37153067e-04, 1.59533069e-04,
#         1.81913071e-04, 2.04293074e-04, 2.26673076e-04]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.log(posterior_ll))
# Out:
# (array([ 87., 128., 285., 125., 448., 217., 922., 650., 530., 191.]),
#  array([-12.76013482, -12.32332152, -11.88650821, -11.44969491,
#         -11.0128816 , -10.5760683 , -10.13925499,  -9.70244169,
#          -9.26562838,  -8.82881508,  -8.39200177]),
#  <a list of 10 Patch objects>)

# %%
np.log(likelihood(start_state, n)), likelihood(start_state, n)
# Out:
# (-10.555622557558927, 2.6046619768292894e-05)

# %% [markdown]
# ### average acceptance probability

# %%
prob_avg
# Out:
# 0.3958253976048061

# %% [markdown]
# ### sampling for sequence

# %%
sequences = []
for i in range(30):
    generate_data(states, coalescent_times)
    sequences.append(deepcopy(states))
# evecs

start_sequence= deepcopy(sequences)

# %%
start_sequence
# Out:
# [[['A', 'A'], ['C', 'C'], ['C', 1], ['C', 2], ['A', 4], [3, 5], ['C', 6]],
#  [['T', 'C'], ['A', 'T'], ['C', 1], ['C', 2], ['G', 4], [3, 5], ['A', 6]],
#  [['T', 'T'], ['C', 'G'], ['A', 1], ['T', 2], ['G', 4], [3, 5], ['T', 6]],
#  [['T', 'T'], ['G', 'C'], ['C', 1], ['A', 2], ['T', 4], [3, 5], ['G', 6]],
#  [['A', 'A'], ['A', 'A'], ['G', 1], ['A', 2], ['A', 4], [3, 5], ['T', 6]],
#  [['G', 'A'], ['G', 'G'], ['G', 1], ['G', 2], ['A', 4], [3, 5], ['C', 6]],
#  [['A', 'A'], ['A', 'G'], ['A', 1], ['G', 2], ['A', 4], [3, 5], ['A', 6]],
#  [['T', 'T'], ['C', 'C'], ['G', 1], ['T', 2], ['T', 4], [3, 5], ['T', 6]],
#  [['C', 'T'], ['G', 'G'], ['T', 1], ['A', 2], ['A', 4], [3, 5], ['G', 6]],
#  [['A', 'A'], ['A', 'A'], ['A', 1], ['G', 2], ['A', 4], [3, 5], ['G', 6]],
#  [['G', 'T'], ['C', 'T'], ['T', 1], ['T', 2], ['G', 4], [3, 5], ['A', 6]],
#  [['C', 'C'], ['C', 'G'], ['C', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]],
#  [['G', 'G'], ['G', 'G'], ['G', 1], ['A', 2], ['G', 4], [3, 5], ['C', 6]],
#  [['A', 'A'], ['A', 'A'], ['T', 1], ['G', 2], ['C', 4], [3, 5], ['C', 6]],
#  [['G', 'C'], ['C', 'C'], ['G', 1], ['T', 2], ['G', 4], [3, 5], ['A', 6]],
#  [['G', 'G'], ['A', 'T'], ['C', 1], ['C', 2], ['C', 4], [3, 5], ['C', 6]],
#  [['T', 'G'], ['A', 'A'], ['T', 1], ['C', 2], ['A', 4], [3, 5], ['C', 6]],
#  [['C', 'A'], ['G', 'T'], ['G', 1], ['G', 2], ['G', 4], [3, 5], ['C', 6]],
#  [['T', 'T'], ['A', 'G'], ['A', 1], ['G', 2], ['C', 4], [3, 5], ['T', 6]],
#  [['T', 'T'], ['T', 'T'], ['G', 1], ['T', 2], ['G', 4], [3, 5], ['C', 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 1], ['C', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['C', 'T'], ['A', 'G'], ['C', 1], ['C', 2], ['T', 4], [3, 5], ['T', 6]],
#  [['T', 'T'], ['T', 'T'], ['C', 1], ['G', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['T', 'G'], ['T', 'T'], ['A', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]],
#  [['C', 'G'], ['A', 'T'], ['A', 1], ['A', 2], ['C', 4], [3, 5], ['C', 6]],
#  [['G', 'G'], ['A', 'G'], ['C', 1], ['C', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['C', 'C'], ['T', 'G'], ['G', 1], ['G', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['C', 'C'], ['T', 'T'], ['C', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]],
#  [['T', 'A'], ['T', 'G'], ['A', 1], ['A', 2], ['T', 4], [3, 5], ['C', 6]],
#  [['G', 'T'], ['T', 'T'], ['G', 1], ['A', 2], ['T', 4], [3, 5], ['C', 6]]]

# %%
import copy
posterior_sampled = []
n=7 ######n = 8 actually, here n = 7 means that there are 7 coalescent events
prob_avg = 0
sequences = deepcopy(start_sequence)
for i in range(10000):
    if i%1000 == 0:
        print(i)
    prev_sequence = copy.deepcopy(sequences)
    
    state_flag = markov_chain_seq(n+1, sequences)
    while not state_flag:
        state_flag = markov_chain_seq(n+1, sequences)
            
    prev_likelihood = seq_likelihood(prev_sequence, n)
    new_likelihood = seq_likelihood(sequences, n)
    acceptance_prob = min(new_likelihood/prev_likelihood, 1)
    prob_avg += acceptance_prob
    U = np.random.rand()
    if U < acceptance_prob:
        ###accept
        if i > 999:
            posterior_sampled.append(deepcopy(sequences))
        prev_sequence = deepcopy(sequences)
    else:
        sequences = deepcopy(prev_sequence)
prob_avg /= 10000
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000

# %%
start_sequence
# Out:
# [[['A', 'A'], ['C', 'C'], ['C', 1], ['C', 2], ['A', 4], [3, 5], ['C', 6]],
#  [['T', 'C'], ['A', 'T'], ['C', 1], ['C', 2], ['G', 4], [3, 5], ['A', 6]],
#  [['T', 'T'], ['C', 'G'], ['A', 1], ['T', 2], ['G', 4], [3, 5], ['T', 6]],
#  [['T', 'T'], ['G', 'C'], ['C', 1], ['A', 2], ['T', 4], [3, 5], ['G', 6]],
#  [['A', 'A'], ['A', 'A'], ['G', 1], ['A', 2], ['A', 4], [3, 5], ['T', 6]],
#  [['G', 'A'], ['G', 'G'], ['G', 1], ['G', 2], ['A', 4], [3, 5], ['C', 6]],
#  [['A', 'A'], ['A', 'G'], ['A', 1], ['G', 2], ['A', 4], [3, 5], ['A', 6]],
#  [['T', 'T'], ['C', 'C'], ['G', 1], ['T', 2], ['T', 4], [3, 5], ['T', 6]],
#  [['C', 'T'], ['G', 'G'], ['T', 1], ['A', 2], ['A', 4], [3, 5], ['G', 6]],
#  [['A', 'A'], ['A', 'A'], ['A', 1], ['G', 2], ['A', 4], [3, 5], ['G', 6]],
#  [['G', 'T'], ['C', 'T'], ['T', 1], ['T', 2], ['G', 4], [3, 5], ['A', 6]],
#  [['C', 'C'], ['C', 'G'], ['C', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]],
#  [['G', 'G'], ['G', 'G'], ['G', 1], ['A', 2], ['G', 4], [3, 5], ['C', 6]],
#  [['A', 'A'], ['A', 'A'], ['T', 1], ['G', 2], ['C', 4], [3, 5], ['C', 6]],
#  [['G', 'C'], ['C', 'C'], ['G', 1], ['T', 2], ['G', 4], [3, 5], ['A', 6]],
#  [['G', 'G'], ['A', 'T'], ['C', 1], ['C', 2], ['C', 4], [3, 5], ['C', 6]],
#  [['T', 'G'], ['A', 'A'], ['T', 1], ['C', 2], ['A', 4], [3, 5], ['C', 6]],
#  [['C', 'A'], ['G', 'T'], ['G', 1], ['G', 2], ['G', 4], [3, 5], ['C', 6]],
#  [['T', 'T'], ['A', 'G'], ['A', 1], ['G', 2], ['C', 4], [3, 5], ['T', 6]],
#  [['T', 'T'], ['T', 'T'], ['G', 1], ['T', 2], ['G', 4], [3, 5], ['C', 6]],
#  [['A', 'A'], ['G', 'G'], ['A', 1], ['C', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['C', 'T'], ['A', 'G'], ['C', 1], ['C', 2], ['T', 4], [3, 5], ['T', 6]],
#  [['T', 'T'], ['T', 'T'], ['C', 1], ['G', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['T', 'G'], ['T', 'T'], ['A', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]],
#  [['C', 'G'], ['A', 'T'], ['A', 1], ['A', 2], ['C', 4], [3, 5], ['C', 6]],
#  [['G', 'G'], ['A', 'G'], ['C', 1], ['C', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['C', 'C'], ['T', 'G'], ['G', 1], ['G', 2], ['G', 4], [3, 5], ['G', 6]],
#  [['C', 'C'], ['T', 'T'], ['C', 1], ['T', 2], ['T', 4], [3, 5], ['A', 6]],
#  [['T', 'A'], ['T', 'G'], ['A', 1], ['A', 2], ['T', 4], [3, 5], ['C', 6]],
#  [['G', 'T'], ['T', 'T'], ['G', 1], ['A', 2], ['T', 4], [3, 5], ['C', 6]]]

# %%
posterior_sampled[700]
# Out:
# [[['A', 'A'], ['C', 'C'], ['C', 2], ['A', 'C'], [4, 1], ['C', 5], [3, 6]],
#  [['T', 'C'], ['C', 'A'], ['T', 2], ['G', 'C'], [4, 1], ['A', 5], [3, 6]],
#  [['T', 'T'], ['A', 'C'], ['G', 2], ['G', 'T'], [4, 1], ['T', 5], [3, 6]],
#  [['T', 'T'], ['C', 'G'], ['C', 2], ['T', 'A'], [4, 1], ['G', 5], [3, 6]],
#  [['A', 'A'], ['G', 'A'], ['A', 2], ['A', 'A'], [4, 1], ['T', 5], [3, 6]],
#  [['G', 'A'], ['G', 'G'], ['G', 2], ['A', 'G'], [4, 1], ['C', 5], [3, 6]],
#  [['A', 'A'], ['A', 'A'], ['G', 2], ['A', 'G'], [4, 1], ['A', 5], [3, 6]],
#  [['T', 'T'], ['G', 'C'], ['C', 2], ['T', 'T'], [4, 1], ['T', 5], [3, 6]],
#  [['C', 'T'], ['T', 'G'], ['G', 2], ['A', 'A'], [4, 1], ['G', 5], [3, 6]],
#  [['A', 'A'], ['A', 'A'], ['A', 2], ['A', 'G'], [4, 1], ['G', 5], [3, 6]],
#  [['G', 'T'], ['T', 'C'], ['T', 2], ['G', 'T'], [4, 1], ['A', 5], [3, 6]],
#  [['C', 'C'], ['C', 'C'], ['G', 2], ['T', 'T'], [4, 1], ['A', 5], [3, 6]],
#  [['G', 'G'], ['G', 'G'], ['G', 2], ['G', 'A'], [4, 1], ['C', 5], [3, 6]],
#  [['A', 'A'], ['T', 'A'], ['A', 2], ['C', 'G'], [4, 1], ['C', 5], [3, 6]],
#  [['G', 'C'], ['G', 'C'], ['C', 2], ['G', 'T'], [4, 1], ['A', 5], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['T', 2], ['C', 'C'], [4, 1], ['C', 5], [3, 6]],
#  [['T', 'G'], ['T', 'A'], ['A', 2], ['A', 'C'], [4, 1], ['C', 5], [3, 6]],
#  [['C', 'A'], ['G', 'G'], ['T', 2], ['G', 'G'], [4, 1], ['C', 5], [3, 6]],
#  [['T', 'T'], ['A', 'A'], ['G', 2], ['C', 'G'], [4, 1], ['T', 5], [3, 6]],
#  [['T', 'T'], ['G', 'T'], ['T', 2], ['G', 'T'], [4, 1], ['C', 5], [3, 6]],
#  [['A', 'A'], ['A', 'G'], ['G', 2], ['G', 'C'], [4, 1], ['G', 5], [3, 6]],
#  [['C', 'T'], ['C', 'A'], ['G', 2], ['T', 'C'], [4, 1], ['T', 5], [3, 6]],
#  [['T', 'T'], ['C', 'T'], ['T', 2], ['G', 'G'], [4, 1], ['G', 5], [3, 6]],
#  [['T', 'G'], ['A', 'T'], ['T', 2], ['T', 'T'], [4, 1], ['A', 5], [3, 6]],
#  [['C', 'G'], ['A', 'A'], ['T', 2], ['C', 'A'], [4, 1], ['C', 5], [3, 6]],
#  [['G', 'G'], ['C', 'A'], ['G', 2], ['G', 'C'], [4, 1], ['G', 5], [3, 6]],
#  [['C', 'C'], ['G', 'T'], ['G', 2], ['G', 'G'], [4, 1], ['G', 5], [3, 6]],
#  [['C', 'C'], ['C', 'T'], ['T', 2], ['T', 'T'], [4, 1], ['A', 5], [3, 6]],
#  [['T', 'A'], ['A', 'T'], ['G', 2], ['T', 'A'], [4, 1], ['C', 5], [3, 6]],
#  [['G', 'T'], ['G', 'T'], ['T', 2], ['T', 'A'], [4, 1], ['C', 5], [3, 6]]]

# %%
prob_avg
# Out:
# 0.381861474415789

# %%
for i in range(10):
    ct = {'A': 0, 'C':0,'G':0,'T':0}
    for state in posterior_sampled[0]:
        for pair in state:
            for val in pair:
                if val in ct:
                    ct[val] += 1
    print(ct)
# Out:
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}

# %%
ct = {'A': 0, 'C':0,'G':0,'T':0}
for state in start_sequence:
    for pair in state:
        for val in pair:
            if val in ct:
                ct[val] += 1
ct
# Out:
# {'A': 59, 'C': 53, 'G': 66, 'T': 62}

# %%
np.log(seq_likelihood(start_sequence, n))
# Out:
# -317.9072775283018

# %%
posterior_ll = []

for seq in posterior_sampled:
    posterior_ll.append(seq_likelihood(seq, n))

# %%
np.mean(posterior_ll)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.hist(np.log(posterior_ll), bins = 20)
# Out:
# (array([  2.,   1.,   6.,  17.,  30.,  46.,  36.,  49.,  53.,  68., 160.,
#         261., 352., 400., 550., 417., 235., 311., 226., 200.]),
#  array([-325.3936962 , -324.87591188, -324.35812756, -323.84034324,
#         -323.32255891, -322.80477459, -322.28699027, -321.76920594,
#         -321.25142162, -320.7336373 , -320.21585297, -319.69806865,
#         -319.18028433, -318.6625    , -318.14471568, -317.62693136,
#         -317.10914703, -316.59136271, -316.07357839, -315.55579407,
#         -315.03800974]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(posterior_ll, bins = 20)
# Out:
# (array([1604.,  674.,  286.,   96.,  133.,   79.,  122.,   61.,   45.,
#           95.,   25.,    0.,   11.,   70.,   16.,   22.,    0.,   59.,
#            0.,   22.]),
#  array([4.82295592e-142, 7.58513297e-139, 1.51654430e-138, 2.27457530e-138,
#         3.03260630e-138, 3.79063730e-138, 4.54866831e-138, 5.30669931e-138,
#         6.06473031e-138, 6.82276131e-138, 7.58079231e-138, 8.33882331e-138,
#         9.09685432e-138, 9.85488532e-138, 1.06129163e-137, 1.13709473e-137,
#         1.21289783e-137, 1.28870093e-137, 1.36450403e-137, 1.44030713e-137,
#         1.51611023e-137]),
#  <a list of 20 Patch objects>)

# %%
seq_likelihood(start_sequence, n)
# Out:
# 8.602478830831119e-139

# %%
values, base = np.histogram(np.log(posterior_ll), bins=40)
#evaluate the cumulative
cumulative = np.cumsum(values)
# plot the cumulative function
plt.plot(base[:-1], cumulative, c='blue')

# %%
values, base = np.histogram(posterior_ll, bins=40)
#evaluate the cumulative
cumulative = np.cumsum(values)
# plot the cumulative function
plt.plot(base[:-1], cumulative, c='blue')

# %%
np.median(np.log(posterior_ll))
# Out:
# -317.9477637755995

# %%
np.median(posterior_ll)
# Out:
# 8.261152871156952e-139

# %%
np.mean(np.log(posterior_ll))
# Out:
# -318.055259448476

# %%
posterior_distribution = {}
for state in posterior_sampled:
    if str(state) not in posterior_distribution:
        posterior_distribution[str(state)] = 1
    else:
        posterior_distribution[str(state)] += 1

# %%
len(posterior_distribution.keys())
# Out:
# 3846

# %%
seq_likelihood(start_sequence, 7)
# Out:
# 1.1945359780905916e-47

# %%
len(posterior_sampled)
# Out:
# 689

# %%
sorted(posterior_distribution.items(), key=lambda item: item[1],reverse = True)[0]
# Out:
# ("[[['T', 'G'], ['A', 1], ['A', 2], ['A', 'T'], ['G', 4], ['A', 3], [5, 6]], [['G', 'G'], ['A', 'C'], ['G', 'G'], [1, 2], [3, 'C'], [5, 'C'], [4, 6]], [['A', 'A'], [1, 'A'], [2, 'T'], ['A', 'A'], ['G', 3], [4, 'A'], [5, 6]], [['G', 'G'], ['G', 'T'], [1, 2], ['C', 'G'], [3, 4], ['G', 'T'], [5, 6]], [['C', 'C'], ['T', 'A'], ['G', 1], [2, 'A'], ['T', 3], [5, 'A'], [4, 6]], [['G', 'A'], [1, 'T'], ['C', 'T'], [2, 'T'], ['G', 3], [4, 5], ['G', 6]], [['T', 'T'], ['C', 'A'], [1, 'T'], [2, 'T'], ['A', 3], ['T', 5], [4, 6]], [['T', 'G'], ['T', 1], ['C', 'G'], [2, 3], ['G', 'A'], [4, 'G'], [5, 6]], [['C', 'C'], ['T', 1], ['G', 'A'], [2, 3], [4, 'A'], [5, 'T'], ['A', 6]], [['A', 'A'], ['T', 'G'], [2, 'G'], [1, 'G'], [3, 'C'], [5, 4], ['T', 6]], [['T', 'T'], [1, 'T'], [2, 'C'], ['C', 'C'], [3, 4], ['C', 'G'], [5, 6]], [['A', 'A'], ['A', 1], ['T', 'C'], ['A', 2], ['G', 3], [4, 'C'], [5, 6]], [['C', 'C'], ['C', 'T'], ['A', 2], ['T', 'T'], [1, 'T'], [3, 5], [4, 6]], [['C', 'A'], [1, 'T'], ['A', 'A'], [2, 'A'], ['A', 3], [4, 'G'], [5, 6]], [['G', 'G'], ['A', 'G'], ['T', 'C'], [1, 'T'], [2, 4], ['A', 3], [5, 6]], [['C', 'C'], ['A', 'T'], ['G', 'G'], [3, 'G'], [2, 4], [5, 'T'], [1, 6]], [['T', 'T'], ['G', 'G'], [2, 'C'], ['A', 3], [4, 1], [5, 'G'], ['C', 6]], [['G', 'A'], ['G', 'G'], ['T', 'T'], [2, 'C'], [3, 4], [5, 1], ['T', 6]], [['C', 'C'], ['C', 'C'], [2, 'T'], ['G', 3], [1, 'T'], [4, 5], ['G', 6]], [['C', 'C'], ['A', 'A'], [2, 1], ['T', 3], ['T', 'C'], ['A', 5], [4, 6]]]",
#  1)

# %%
seq_likelihood([[['T', 'G'], ['A', 1], ['A', 2], ['A', 'T'], ['G', 4], ['A', 3], [5, 6]], [['G', 'G'], ['A', 'C'], ['G', 'G'], [1, 2], [3, 'C'], [5, 'C'], [4, 6]], [['A', 'A'], [1, 'A'], [2, 'T'], ['A', 'A'], ['G', 3], [4, 'A'], [5, 6]], [['G', 'G'], ['G', 'T'], [1, 2], ['C', 'G'], [3, 4], ['G', 'T'], [5, 6]], [['C', 'C'], ['T', 'A'], ['G', 1], [2, 'A'], ['T', 3], [5, 'A'], [4, 6]], [['G', 'A'], [1, 'T'], ['C', 'T'], [2, 'T'], ['G', 3], [4, 5], ['G', 6]], [['T', 'T'], ['C', 'A'], [1, 'T'], [2, 'T'], ['A', 3], ['T', 5], [4, 6]], [['T', 'G'], ['T', 1], ['C', 'G'], [2, 3], ['G', 'A'], [4, 'G'], [5, 6]], [['C', 'C'], ['T', 1], ['G', 'A'], [2, 3], [4, 'A'], [5, 'T'], ['A', 6]], [['A', 'A'], ['T', 'G'], [2, 'G'], [1, 'G'], [3, 'C'], [5, 4], ['T', 6]], [['T', 'T'], [1, 'T'], [2, 'C'], ['C', 'C'], [3, 4], ['C', 'G'], [5, 6]], [['A', 'A'], ['A', 1], ['T', 'C'], ['A', 2], ['G', 3], [4, 'C'], [5, 6]], [['C', 'C'], ['C', 'T'], ['A', 2], ['T', 'T'], [1, 'T'], [3, 5], [4, 6]], [['C', 'A'], [1, 'T'], ['A', 'A'], [2, 'A'], ['A', 3], [4, 'G'], [5, 6]], [['G', 'G'], ['A', 'G'], ['T', 'C'], [1, 'T'], [2, 4], ['A', 3], [5, 6]], [['C', 'C'], ['A', 'T'], ['G', 'G'], [3, 'G'], [2, 4], [5, 'T'], [1, 6]], [['T', 'T'], ['G', 'G'], [2, 'C'], ['A', 3], [4, 1], [5, 'G'], ['C', 6]], [['G', 'A'], ['G', 'G'], ['T', 'T'], [2, 'C'], [3, 4], [5, 1], ['T', 6]], [['C', 'C'], ['C', 'C'], [2, 'T'], ['G', 3], [1, 'T'], [4, 5], ['G', 6]], [['C', 'C'], ['A', 'A'], [2, 1], ['T', 3], ['T', 'C'], ['A', 5], [4, 6]]], 7)
# Out:
# 8.958743873643202e-93

# %%
likelihood([['A', 'G'], ['G', 'G'], ['G', 1], ['T', 2], ['C', 4], [3, 5], ['G', 6]], 7)
# Out:
# 1.0672997341361499e-05

# %%
likelihood([['G', 'G'], ['G', 'G'], [2, 'G'], ['A', 3], ['T', 'C'], [1, 4], [5, 6]], 7)
# Out:
# 0.00011566432806316471

# %%
prior_sampled = []
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
coalescent_times = [.2,.5,.6,.8,1.3,1.9,2.9]
for i in range(7707):
    prev_state = copy.deepcopy(states)
    prior_sampled.append(prev_state)
    state_flag = markov_chain_forward(n+1,states)
    while not state_flag:
        state_flag = markov_chain_forward(n+1,states)

# %%
posterior_ll = []
ct = 0
for tree in posterior_sampled:
    ct += 1
    posterior_ll.append(likelihood(tree, 7))
    if ct %1000==0:
        print(ct//1000, 'iter_')
# Out:
# 1 iter_
# 2 iter_
# 3 iter_
# 4 iter_
# 5 iter_
# 6 iter_
# 7 iter_

# %%
prior_ll = []
for tree in prior_sampled:
    prior_ll.append(likelihood(tree, 7))

# %%
posterior_ll = np.array(posterior_ll)
prior_ll = np.array(prior_ll)

# %%
import seaborn as sns
sns.set()
plt.hist(np.log(posterior_ll),alpha = .5, label = 'posterior sampled')
plt.hist(np.log(prior_ll), alpha = .5, label = 'prior sampled')
plt.legend()
plt.xlabel('log likelihood')
# Out:
# Text(0.5,0,'log likelihood')

# %%
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
print(np.log(likelihood(states, 7)))
# Out:
# -10.555622557558927

# %%
np.log(likelihood(posterior_sampled[np.argmax(posterior_ll)], 7))
# Out:
# -8.354450743754589

# %%
posterior_sampled[np.argmax(posterior_ll)]
# Out:
# [['A', 'A'], ['A', 1], ['C', 'C'], [3, 'C'], ['G', 'G'], [5, 4], [2, 6]]

# %%
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]

# %%
coalescent_times
###fix coalescent time, fix tree, simulation the data
# Out:
# [0.2, 0.5, 0.6, 0.8, 1.3, 1.9, 2.9]

# %%
q
# Out:
# array([[-1.        ,  0.33333333,  0.33333333,  0.33333333],
#        [ 0.33333333, -1.        ,  0.33333333,  0.33333333],
#        [ 0.33333333,  0.33333333, -1.        ,  0.33333333],
#        [ 0.33333333,  0.33333333,  0.33333333, -1.        ]])

# %%
Pij(1, evecs, evals,evec_inv)
# Out:
# array([[0.44769785, 0.18410072, 0.18410072, 0.18410072],
#        [0.18410072, 0.44769785, 0.18410072, 0.18410072],
#        [0.18410072, 0.18410072, 0.44769785, 0.18410072],
#        [0.18410072, 0.18410072, 0.18410072, 0.44769785]])

# %% [markdown]
# ### variational using the prior distance function
# ### using swapping markov chain, (run again or improve time efficiency) TODO..
# ### getting stuck and sampling
#
#
# #### starting about thinking branch length , hmc etc.. (gradients on branch length), marginalized on branch length (variational inference relying on automatic differentiation) another latent layer (one layer is effective population size, one layer is coalescent time)
#
# gradient for coalescent time and likelihood
# biggest problem for HMC, tree is easy to construct. cannot propose to have negative branch length (one proposal increasing decreasing branch length (negative branch length)), parmaterice increment. keep step size of Hamiltonian.
#
# problem to compute the gradient, they use estimate of gradient, and improve the estimation.
# out win a problem that cannot compute the gradient
#
# black-box
# simulated annealling, distance, exponential
#
# doing greedy search
#
# fixed unlabelled tree, uniformly labelling
# distribution on = distribution of unlabelled * uniform
# MCMC (save likelihood and posterior at each iteration)

# %%
np.log(np.mean(posterior_ll))
# Out:
# -10.21916362447655

# %%
import numpy as np

# %% [markdown]
# MCMC()
# ###simulate data from the model, fix one tree, simulate data, compute the likelihood of different trees, hopefully convex function, with a peak on the simulated trees.
#
# have a tree, needs to compute transition probability
#
# matrix exponential, conditional on time, look at the corresponding row to
# sample multinomial by row value
#
# simulate with a lot of possible mutations (high mutation rate).
