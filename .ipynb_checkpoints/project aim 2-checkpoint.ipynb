# %%
import numpy as np
import pandas as pd

# %%
def markov_chain_forward(n, states):
    k = np.random.randint(low= 1, high = n-1)
    swap1 = np.random.randint(low=0, high = 2) ###output 0, 1
    swap2 = np.random.randint(low=0, high = 2) ###output 0, 1
    ##swap from left to right should be good
    try:
        ####k is original k
        #### states[k-1]: kth state, states[k]: k+1 state 
        
        #max k can be n-2
        if states[k][swap2] < k: 

            states[k-1][swap1], states[k][swap2] = states[k][swap2], states[k-1][swap1]
            return True
        else:

            return False
    except:

            states[k-1][swap1], states[k][swap2] = states[k][swap2], states[k-1][swap1]
            return True

# %%
n = 3
# states = [['C', 'C'],['A', 'G'], ['T', 1], ['T', 2], ['A', 4], [3,5], ['A', 6]]
coalescent_times = [.15, .6, 2]
states = [['A', 'A'],['C', 'T'], [1, 2]]

# coalescent_times = [2,5,6,8,13,19,29]
mmap = {'A':0, 'C':1, 'G':2, 'T':3}
q = np.ones((4,4))/3
for i in range(4):
    q[i,i]= -1
evals, evecs = la.eig(q)
evec_inv = la.inv(evecs)

states
# Out:
# [['A', 'A'], ['C', 'T'], [1, 2]]

# %%
l = []
simulations = []
from copy import deepcopy
for i in range(50):
    states[0][0] = np.random.choice(['A','C','G','T'])
    states[0][1] = np.random.choice(['A','C','G','T'])
    states[1][0] = np.random.choice(['A','C','G','T'])
    states[1][1] = np.random.choice(['A','C','G','T'])
    
    print(i, 'loop')
    print(states)
    s = deepcopy(states)
    l.append(likelihood(s, 3))
    p = 0
    for j in range(100000):
        if j %20000 == 0:
            print(j//20000, 'iter')
        p += mc_probability(s, coalescent_times)[0]
    simulations.append(p/100000)
#         markov_chain_forward(n, states)
# Out:
# 0 loop
# [['C', 'T'], ['A', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 1 loop
# [['A', 'C'], ['G', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 2 loop
# [['T', 'A'], ['T', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 3 loop
# [['G', 'C'], ['C', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 4 loop
# [['C', 'C'], ['G', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 5 loop
# [['T', 'G'], ['C', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 6 loop
# [['C', 'C'], ['C', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 7 loop
# [['T', 'G'], ['A', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 8 loop
# [['A', 'G'], ['A', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 9 loop
# [['T', 'A'], ['C', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 10 loop
# [['G', 'T'], ['A', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 11 loop
# [['A', 'C'], ['G', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 12 loop
# [['A', 'T'], ['G', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 13 loop
# [['T', 'C'], ['G', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 14 loop
# [['C', 'C'], ['G', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 15 loop
# [['T', 'A'], ['T', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 16 loop
# [['A', 'T'], ['A', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 17 loop
# [['T', 'G'], ['A', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 18 loop
# [['A', 'C'], ['G', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 19 loop
# [['G', 'C'], ['G', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 20 loop
# [['A', 'G'], ['G', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 21 loop
# [['T', 'G'], ['A', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 22 loop
# [['T', 'C'], ['T', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 23 loop
# [['G', 'C'], ['C', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 24 loop
# [['A', 'T'], ['T', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 25 loop
# [['C', 'T'], ['C', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 26 loop
# [['T', 'C'], ['A', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 27 loop
# [['G', 'C'], ['T', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 28 loop
# [['A', 'A'], ['C', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 29 loop
# [['G', 'T'], ['C', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 30 loop
# [['T', 'G'], ['C', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 31 loop
# [['C', 'C'], ['C', 'T'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 32 loop
# [['C', 'G'], ['G', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 33 loop
# [['A', 'A'], ['T', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 34 loop
# [['T', 'C'], ['G', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 35 loop
# [['T', 'A'], ['T', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 36 loop
# [['G', 'A'], ['G', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 37 loop
# [['C', 'G'], ['A', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 38 loop
# [['G', 'A'], ['G', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 39 loop
# [['T', 'A'], ['T', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 40 loop
# [['T', 'A'], ['T', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 41 loop
# [['A', 'T'], ['G', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 42 loop
# [['G', 'T'], ['A', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 43 loop
# [['C', 'G'], ['G', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 44 loop
# [['C', 'C'], ['G', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 45 loop
# [['G', 'A'], ['A', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 46 loop
# [['C', 'A'], ['T', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 47 loop
# [['T', 'A'], ['T', 'G'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 48 loop
# [['G', 'G'], ['T', 'C'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter
# 49 loop
# [['C', 'G'], ['C', 'A'], [1, 2]]
# 0 iter
# 1 iter
# 2 iter
# 3 iter
# 4 iter

# %%
l = np.array(l)

# %%
simulations = np.array(simulations)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(np.log(l), np.log(simulations))
plt.xlabel('log likelihood')
plt.ylabel('simulated monte carlo probability')
# Out:
# Text(0,0.5,'simulated monte carlo probability')

# %%
import numpy as np
np.corrcoef(np.log(l), np.log(simulations))
# Out:
# array([[1.        , 0.99583784],
#        [0.99583784, 1.        ]])

# %%
r_squared = 1 - np.sum((np.array(l) - np.array(simulations))**2)/np.sum((np.array(simulations) - np.mean(np.array(simulations)))**2)

print(r_squared, 'r_squared')
# Out:
# 0.9983294680025736 r_squared

# %%
states
# coalescent_times = [.3, .5, .9]
### accelerate likelihood computation by changing a minor part of the tree.
# Out:
# [['G', 'A'], ['G', 'A'], [1, 2]]

# %%
# # np.random.randint()
# coalescent_times = [2,5,6,8,13,19,29]
Mrbayes

# %%
import numpy.linalg as la
def Pij(t, evecs, evals, evec_inv):
    return evecs@np.diag(np.exp(evals*t))@evec_inv
    
def mc_probability(states, coalescent_times):
    mmap = {'A':0, 'C':1, 'G':2, 'T':3}
    global labels
    labels = [1]
    root_label = np.zeros(4)
    root_label[np.random.choice([0,1,2,3])] = 1
    mc_probability_recurse(states, coalescent_times, len(states), root_label)
    return labels


def assign_labels(states, coalescent_time):
    mmap = {'A': 0, 'C':1, 'G':2, 'T':3}
    root_label = np.zeros(4)
    root_label[np.random.choice([0,1,2,3])] = 1
    assign_labels_recurse(states, coalescent_time, len(states), root_label)
    

def assign_labels_recurse(states, coalescent_time, subroot, subroot_label):
    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    if type(left_child) not in [int, float]:
        left_time = coalescent_times[subroot-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_left)
        states[subroot-1][0] = simulated_leaf ###assign simulated leaf to the tree
    else:
        left_time = coalescent_times[subroot-1] - coalescent_times[left_child-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_left)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        assign_labels_recurse(states, coalescent_times, left_child, newlabel)
        
    if type(right_child) not in [int, float]:
        right_time = coalescent_times[subroot-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_right)
        states[subroot-1][1] = simulated_leaf
    else:
        right_time = coalescent_times[subroot-1]-coalescent_times[right_child-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_right)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        assign_labels_recurse(states, coalescent_times, right_child, newlabel)


def mc_probability_recurse(states, coalescent_times, subroot, subroot_label):
    ###simulate from subroot with a fixed label
    
    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    
    if type(left_child) not in [int, float]:
        left_time = coalescent_times[subroot-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_left)
        if simulated_leaf == left_child:
            labels[0] = labels[0]*1
        else:
            labels[0] = 0
        
#         labels.add(left_child)
    else:
        left_time = coalescent_times[subroot-1] - coalescent_times[left_child-1]
        prob_left = Pij(left_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_left)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        mc_probability_recurse(states, coalescent_times, left_child, newlabel)

    if type(right_child) not in [int, float]:
        right_time = coalescent_times[subroot-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        
        simulated_leaf = np.random.choice(['A','C','G','T'], p = prob_right)
        if simulated_leaf == right_child:
            labels[0] = labels[0]*1
        else:
            labels[0] = 0    
#         labels.add(left_child)
    else:
        right_time = coalescent_times[subroot-1] - coalescent_times[right_child-1]
        prob_right = Pij(right_time, evecs, evals, evec_inv)@subroot_label
        newlabelindex = np.random.choice([0,1,2,3], p = prob_right)
        newlabel = np.array([0,0,0,0])
        newlabel[newlabelindex] = 1
        mc_probability_recurse(states, coalescent_times, right_child, newlabel)
        return
        
    
    
    

def compute_likelihood(states, site, subroot):

    left_child, right_child = states[subroot-1][0], states[subroot-1][1]
    left_child_likelihood, right_child_likelihood = 0,0
    left_t, right_t = -1,-1
    

    if type(left_child) not in [int, float]:
        init_state = np.zeros(4)
        init_state[mmap[left_child]] = 1
        left_child_likelihood = init_state
        left_t = coalescent_times[subroot-1]
    
    else:   
        left_child_likelihood = compute_likelihood(states, site, left_child)
        left_t = coalescent_times[subroot-1] - coalescent_times[left_child-1] 
        
    if type(right_child) not in [int, float]:
        init_state = np.zeros(4)
        init_state[mmap[right_child]] = 1
        right_t = coalescent_times[subroot-1]
        right_child_likelihood = init_state
        
        ###gradient corresponding to coalescent time?
        ###have the
    else:
        
        right_child_likelihood = compute_likelihood(states, site, right_child)
        right_t = coalescent_times[subroot-1] - coalescent_times[right_child-1]   
    likelihood = (Pij(left_t, evecs, evals, evec_inv)@left_child_likelihood) *\
    (Pij(right_t, evecs, evals, evec_inv)@right_child_likelihood)
    return likelihood

# mmap = {'A':0, 'C':1, 'G':2, 'T':3}
# q = np.ones((4,4))/3
# for i in range(4):
#     q[i,i]= -1
# evals, evecs = la.eig(q)
# evec_inv = la.inv(evecs)


def likelihood(states, root):
    likelihood_vec = compute_likelihood(states, 0, root)
    final_likelihood = 0.25*np.sum(likelihood_vec)
    return final_likelihood

# %%
coalescent_times = [3, 5, 9]
states = [['A', 'C'],['G', 'G'], [1, 2]]
likelihood(states, 3)
# Out:
# 0.0039049585718129104

# %%
p = 0
for i in range(100000):
    p += mc_probability(states, coalescent_times)[0]

# %%
p/100000
# Out:
# 0.00389

# %%
import numpy as np
np.log(0.003904)
# Out:
# -5.545753610431291

# %% [markdown]
# ### Start MCMC sampling posterior

# %%
coalescent_times = [2,5,6,8,13,19,29]
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
likelihood(states, 7)
# Out:
# 1.5479569532151385e-05

# %%
# np.random.rand()
# mu = 0.5
# q*mu
q
# Out:
# array([[-1.        ,  0.33333333,  0.33333333,  0.33333333],
#        [ 0.33333333, -1.        ,  0.33333333,  0.33333333],
#        [ 0.33333333,  0.33333333, -1.        ,  0.33333333],
#        [ 0.33333333,  0.33333333,  0.33333333, -1.        ]])

# %%
import copy
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
coalescent_times = [.2,.5,.6,.8,1.3,1.9,2.9]

origin_likelihood = []
posterior_average = []
prior_average = []

for k in range(100):
    assign_labels(states, coalescent_times)
    init_state = copy.deepcopy(states)
    
    print(init_state)
    posterior_sampled = []
    n=7 ######n = 8 actually, here n = 7 means that there are 7 coalescent events
    prob_avg = 0
    for i in range(20000):
        prev_state = copy.deepcopy(states)
        state_flag = markov_chain_forward(n+1,states)
        while not state_flag:
            state_flag = markov_chain_forward(n+1,states)
        new_state = copy.deepcopy(states)
        prev_likelihood = likelihood(list(prev_state), n)
        new_likelihood = likelihood(list(new_state), n)
        acceptance_prob = min(new_likelihood/prev_likelihood, 1)
        prob_avg += acceptance_prob
        U = np.random.rand()
        if U < acceptance_prob:
            ###accept
            if i > 10000:
                posterior_sampled.append(copy.deepcopy(states))
                states = copy.deepcopy(new_state)
        else:
            ###reject
            states = copy.deepcopy(prev_state)
    print(prob_avg/20000)
    
    prior_sampled = []
    states = init_state
    # states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
    # coalescent_times = [.2,.5,.6,.8,1.3,1.9,2.9]
    for i in range(len(posterior_sampled)):
        prev_state = copy.deepcopy(states)
        prior_sampled.append(prev_state)
        state_flag = markov_chain_forward(n+1,states)
        while not state_flag:
            state_flag = markov_chain_forward(n+1,states)
            
    posterior_ll = []
    for tree in posterior_sampled:
        posterior_ll.append(likelihood(tree, 7))
        
    prior_ll = []
    for tree in prior_sampled:
        prior_ll.append(likelihood(tree, 7))
            
    
    print(np.log(likelihood(init_state, 7)), 'likelihood initial state')

    print(np.log(np.mean(posterior_ll)), 'posterior sample average likelihood')
    print(np.log(np.mean(prior_ll)), 'prior sample average likelihood')
    
    origin_likelihood.append(np.log(likelihood(states, 7)))
    posterior_average.append(np.log(np.mean(posterior_ll)))
    prior_average.append(np.log(np.mean(prior_ll)))
# Out:
# [['G', 'G'], ['A', 'A'], ['C', 1], ['A', 2], ['A', 4], [3, 5], ['G', 6]]
# 0.8017623908575916
# -10.786498388106228 likelihood initial state
# -9.938942324251752 posterior sample average likelihood
# -10.778922640634525 prior sample average likelihood
# [['A', 'A'], ['A', 'A'], ['G', 'C'], [1, 2], ['A', 3], ['A', 4], [5, 6]]
# 0.9126625499646641
# -9.84287955990986 likelihood initial state
# -9.309490387900869 posterior sample average likelihood
# -9.81986878680442 prior sample average likelihood
# [['C', 'C'], ['G', 'G'], ['C', 'A'], ['C', 3], [2, 4], [1, 'C'], [5, 6]]
# 0.8429608065744923
# -11.400060670800967 likelihood initial state
# -9.627451008592255 posterior sample average likelihood
# -10.480759307677454 prior sample average likelihood
# [['C', 'A'], ['G', 'G'], ['G', 'C'], ['G', 3], [2, 4], [5, 1], ['G', 6]]
# 0.8543480702412258
# -9.671022125463107 likelihood initial state
# -9.621110767411162 posterior sample average likelihood
# -10.421295871785345 prior sample average likelihood
# [['C', 'C'], ['G', 'C'], [2, 'C'], [3, 'C'], ['T', 'G'], [5, 4], [1, 6]]
# 0.8453993943182597
# -10.061160191787836 likelihood initial state
# -9.610447910074592 posterior sample average likelihood
# -10.466003665195243 prior sample average likelihood
# [['A', 'A'], ['A', 'G'], [1, 2], ['C', 'C'], ['T', 'T'], [3, 5], [4, 6]]
# 0.8137951120720789
# -11.571161836756211 likelihood initial state
# -10.62322393380379 posterior sample average likelihood
# -11.595010363107932 prior sample average likelihood
# [['T', 'T'], ['G', 'A'], ['C', 1], [2, 3], ['C', 4], ['T', 5], ['G', 6]]
# 0.8069515655630312
# -12.733241377239395 likelihood initial state
# -10.668728767572835 posterior sample average likelihood
# -11.593057581137929 prior sample average likelihood
# [['G', 'G'], ['C', 'A'], [1, 'G'], ['G', 3], [4, 2], [5, 'C'], ['T', 6]]
# 0.8263844213538194
# -10.854286192230681 likelihood initial state
# -10.315904177969388 posterior sample average likelihood
# -11.175943516753753 prior sample average likelihood
# [['G', 'G'], ['C', 'C'], ['A', 'G'], [1, 2], ['G', 'C'], [4, 3], [5, 6]]
# 0.7868677352424085
# -11.671176675587104 likelihood initial state
# -9.96369214724591 posterior sample average likelihood
# -10.746943764662362 prior sample average likelihood
# [['C', 'C'], ['A', 'C'], [1, 'C'], [3, 'C'], [2, 'T'], [5, 4], ['T', 6]]
# 0.8406156538062647
# -12.338151354208215 likelihood initial state
# -9.67099560795774 posterior sample average likelihood
# -10.419920640044475 prior sample average likelihood
# [['A', 'A'], ['A', 1], [2, 'A'], [3, 'T'], ['C', 4], ['A', 'A'], [5, 6]]
# 0.9140356793841451
# -9.94817106260538 likelihood initial state
# -9.127231012203278 posterior sample average likelihood
# -9.938733266634044 prior sample average likelihood
# [['C', 'C'], ['T', 'T'], ['T', 2], ['G', 'G'], [1, 4], ['A', 3], [5, 6]]
# 0.801359302246449
# -12.630440753263352 likelihood initial state
# -10.672901409707244 posterior sample average likelihood
# -11.609774474862956 prior sample average likelihood
# [['T', 'A'], ['T', 'T'], ['C', 'G'], [1, 'T'], [4, 2], ['G', 3], [5, 6]]
# 0.8318405208514253
# -12.059092083082094 likelihood initial state
# -10.281398585243794 posterior sample average likelihood
# -11.134830060602214 prior sample average likelihood
# [['G', 'T'], ['A', 'C'], ['A', 2], ['G', 1], ['C', 3], ['G', 4], [5, 6]]
# 0.8098071394265628
# -10.532259866970572 likelihood initial state
# -10.714454435447335 posterior sample average likelihood
# -11.574181772178422 prior sample average likelihood
# [['G', 'C'], ['T', 'C'], ['A', 'C'], ['G', 2], [3, 1], ['C', 5], [4, 6]]
# 0.821642553982328
# -12.211139168396077 likelihood initial state
# -10.306285345863241 posterior sample average likelihood
# -11.227358856340983 prior sample average likelihood
# [['A', 'A'], ['C', 'C'], ['C', 2], ['A', 'G'], [3, 'T'], [4, 5], [1, 6]]
# 0.808223414224911
# -11.988211921973166 likelihood initial state
# -10.582604493242842 posterior sample average likelihood
# -11.380724031677456 prior sample average likelihood
# [['T', 'T'], ['T', 'A'], [1, 2], [3, 'T'], ['T', 'T'], [5, 'T'], [4, 6]]
# 0.9533761269177563
# -10.533164594917515 likelihood initial state
# -8.628451153796739 posterior sample average likelihood
# -9.01599595667698 prior sample average likelihood
# [['T', 'C'], ['G', 'G'], ['C', 'C'], [1, 3], ['C', 'C'], [2, 5], [4, 6]]
# 0.8449847109137593
# -11.996170992588015 likelihood initial state
# -9.670096715542947 posterior sample average likelihood
# -10.464517085125909 prior sample average likelihood
# [['A', 'G'], ['G', 1], ['A', 'A'], ['T', 'T'], [2, 4], [3, 'G'], [5, 6]]
# 0.7734937375675762
# -10.67810048937058 likelihood initial state
# -10.232614650060814 posterior sample average likelihood
# -11.128799206851074 prior sample average likelihood
# [['A', 'A'], ['A', 'T'], ['T', 'T'], ['A', 'T'], [3, 2], [5, 4], [1, 6]]
# 0.7692429977937374
# -11.473908919729961 likelihood initial state
# -9.454139422440607 posterior sample average likelihood
# -10.32812540874953 prior sample average likelihood
# [['G', 'G'], [1, 'T'], ['A', 'C'], [2, 'A'], ['G', 3], ['C', 5], [4, 6]]
# 0.8089625590238028
# -10.89788751965807 likelihood initial state
# -10.777267362728601 posterior sample average likelihood
# -11.605148109502242 prior sample average likelihood
# [['G', 'G'], ['G', 'G'], ['G', 1], ['C', 2], [3, 4], [5, 'C'], ['T', 6]]
# 0.8525608103313951
# -11.754969406361504 likelihood initial state
# -9.58891357925106 posterior sample average likelihood
# -10.47163407685257 prior sample average likelihood
# [['G', 'G'], ['A', 'A'], ['G', 1], ['C', 'G'], [3, 4], ['C', 5], [2, 6]]
# 0.8004602976706087
# -9.886275194915822 likelihood initial state
# -10.204448469682026 posterior sample average likelihood
# -11.051056019183056 prior sample average likelihood
# [['G', 'G'], [1, 'A'], ['A', 'A'], ['C', 2], [4, 'A'], ['G', 5], [3, 6]]
# 0.7947372529762456
# -11.506273012900307 likelihood initial state
# -9.828369853217547 posterior sample average likelihood
# -10.84704915502251 prior sample average likelihood
# [['A', 'A'], ['C', 'C'], ['C', 2], [1, 3], ['G', 4], ['T', 'T'], [5, 6]]
# 0.8126872705001384
# -12.550236062093273 likelihood initial state
# -10.84255066252284 posterior sample average likelihood
# -11.628212973288104 prior sample average likelihood
# [['A', 'A'], ['T', 'C'], ['G', 'A'], [1, 2], ['G', 3], [4, 5], ['T', 6]]
# 0.8084225507509409
# -12.217305805395494 likelihood initial state
# -10.816514205349675 posterior sample average likelihood
# -11.604039838101361 prior sample average likelihood
# [['G', 'G'], ['C', 'C'], ['G', 1], ['G', 'A'], ['G', 3], [5, 2], [4, 6]]
# 0.8445450665377406
# -11.281199513087907 likelihood initial state
# -9.689303816302367 posterior sample average likelihood
# -10.578926786924047 prior sample average likelihood
# [['T', 'G'], [1, 'C'], ['A', 'A'], [2, 'T'], [4, 'A'], [3, 'C'], [5, 6]]
# 0.8158816979148849
# -12.718950262369933 likelihood initial state
# -10.756473016062653 posterior sample average likelihood
# -11.614431985977586 prior sample average likelihood
# [['C', 'G'], ['G', 1], ['T', 'T'], ['G', 'T'], [3, 'T'], [4, 2], [5, 6]]
# 0.7998673932655922
# -9.922944774693654 likelihood initial state
# -10.015701582029354 posterior sample average likelihood
# -10.81403244602562 prior sample average likelihood
# [['C', 'T'], ['A', 'A'], ['G', 1], ['T', 3], ['C', 'A'], [2, 5], [4, 6]]
# 0.809098300637859
# -12.49115174469231 likelihood initial state
# -10.584233946808865 posterior sample average likelihood
# -11.65302218493365 prior sample average likelihood
# [['T', 'T'], ['A', 'T'], ['C', 1], ['C', 3], ['A', 2], [4, 'T'], [5, 6]]
# 0.8020692315231335
# -12.671408903178754 likelihood initial state
# -10.1802975462817 posterior sample average likelihood
# -11.038147218592556 prior sample average likelihood
# [['A', 'A'], ['T', 'T'], ['T', 'T'], [2, 'T'], [1, 3], [4, 'C'], [5, 6]]
# 0.8485887112861493
# -10.193457990980978 likelihood initial state
# -9.750587590170644 posterior sample average likelihood
# -10.333663061827982 prior sample average likelihood
# [['T', 'T'], ['C', 'T'], ['T', 1], ['A', 'T'], [4, 3], ['G', 5], [2, 6]]
# 0.879094535773525
# -9.44595488691412 likelihood initial state
# -10.070044317864813 posterior sample average likelihood
# -10.751305383955625 prior sample average likelihood
# [['C', 'C'], ['C', 'C'], [1, 2], [3, 'G'], ['T', 4], ['C', 5], ['C', 6]]
# 0.9142371202030789
# -9.541512612260327 likelihood initial state
# -9.161497222628903 posterior sample average likelihood
# -9.849369251466701 prior sample average likelihood
# [['A', 'A'], ['G', 'G'], [2, 'A'], ['A', 'A'], [4, 1], [3, 5], ['G', 6]]
# 0.8072578353871679
# -10.861132784362056 likelihood initial state
# -9.33706992244135 posterior sample average likelihood
# -10.088681236664533 prior sample average likelihood
# [['A', 'C'], ['T', 'T'], ['A', 'T'], [1, 'A'], [3, 2], [4, 'T'], [5, 6]]
# 0.792360827880962
# -12.29388517580853 likelihood initial state
# -9.921722526147079 posterior sample average likelihood
# -10.805152262197625 prior sample average likelihood
# [['G', 'G'], ['C', 'A'], ['C', 'A'], [1, 'G'], [3, 4], [2, 'A'], [5, 6]]
# 0.7769319708123564
# -10.835631691632173 likelihood initial state
# -10.145123517157634 posterior sample average likelihood
# -11.10579114187298 prior sample average likelihood
# [['G', 'T'], ['A', 'A'], ['G', 'G'], [1, 3], [4, 'C'], [5, 'C'], [2, 6]]
# 0.8043479985470753
# -10.789855666768682 likelihood initial state
# -10.674075104936282 posterior sample average likelihood
# -11.56501993505852 prior sample average likelihood
# [['T', 'A'], ['G', 'G'], ['A', 'C'], [2, 1], [3, 'A'], ['C', 5], [4, 6]]
# 0.8129586204214315
# -10.33003373597019 likelihood initial state
# -10.653207191818854 posterior sample average likelihood
# -11.596769981807544 prior sample average likelihood
# [['A', 'C'], ['T', 1], ['T', 2], ['T', 3], ['C', 4], ['A', 'G'], [5, 6]]
# 0.8026718102982002
# -11.515947250697765 likelihood initial state
# -10.635111880599279 posterior sample average likelihood
# -11.49322387959192 prior sample average likelihood
# [['A', 'A'], ['G', 'G'], ['A', 'A'], [3, 1], [2, 'G'], ['C', 4], [5, 6]]
# 0.7935764642291683
# -12.095461502418951 likelihood initial state
# -9.95111945680059 posterior sample average likelihood
# -10.740850247574976 prior sample average likelihood
# [['G', 'G'], ['G', 1], ['A', 'T'], ['A', 'C'], ['G', 3], [5, 2], [4, 6]]
# 0.8311275882216722
# -10.79365643464491 likelihood initial state
# -10.284044484656242 posterior sample average likelihood
# -11.215508854154653 prior sample average likelihood
# [['G', 'G'], ['G', 1], ['A', 'A'], ['G', 'A'], [3, 'G'], [2, 5], [4, 6]]
# 0.8093334023074202
# -10.294079942262961 likelihood initial state
# -9.302378739161721 posterior sample average likelihood
# -10.092692128632716 prior sample average likelihood
# [['G', 'G'], ['G', 'G'], ['G', 2], ['A', 'T'], [1, 'T'], [5, 3], [4, 6]]
# 0.8458791333457344
# -9.399211375119764 likelihood initial state
# -9.729558522687194 posterior sample average likelihood
# -10.439111684492023 prior sample average likelihood
# [['T', 'T'], [1, 'G'], ['G', 'G'], ['A', 'T'], [2, 4], [5, 'T'], [3, 6]]
# 0.7927852772871956
# -11.113123418685356 likelihood initial state
# -9.930658529833941 posterior sample average likelihood
# -10.755036735373817 prior sample average likelihood
# [['A', 'A'], ['C', 'T'], ['C', 'C'], [1, 'C'], ['C', 3], [5, 2], [4, 6]]
# 0.840550986126032
# -11.266749442481691 likelihood initial state
# -9.63085160139889 posterior sample average likelihood
# -10.500423075868792 prior sample average likelihood
# [['T', 'A'], ['T', 1], [2, 'T'], ['A', 'T'], ['G', 'G'], [5, 4], [3, 6]]
# 0.8018925596308843
# -11.818103237010304 likelihood initial state
# -10.001143787206358 posterior sample average likelihood
# -10.934536399806886 prior sample average likelihood
# [['T', 'T'], ['T', 'C'], ['G', 'T'], ['C', 2], [4, 1], ['T', 3], [5, 6]]
# 0.8364371401983705
# -11.398130330401425 likelihood initial state
# -9.501827254153499 posterior sample average likelihood
# -10.475877381259048 prior sample average likelihood
# [['T', 'C'], [1, 'A'], ['C', 'C'], ['A', 'T'], [2, 'C'], [4, 3], [5, 6]]
# 0.7998430376290824
# -11.722028912545001 likelihood initial state
# -10.102342746032706 posterior sample average likelihood
# -11.007092374052005 prior sample average likelihood
# [['C', 'C'], ['C', 1], ['G', 'G'], [3, 2], [4, 'C'], ['A', 5], ['A', 6]]
# 0.8083061452503655
# -12.683523265686762 likelihood initial state
# -10.055271556114434 posterior sample average likelihood
# -11.104952992844463 prior sample average likelihood
# [['C', 'C'], ['C', 'C'], [2, 'A'], ['G', 'T'], [3, 'C'], [5, 1], [4, 6]]
# 0.8808510618928587
# -12.14074696519562 likelihood initial state
# -9.861551197705158 posterior sample average likelihood
# -10.621778114456763 prior sample average likelihood
# [['G', 'A'], ['A', 'A'], ['G', 1], ['T', 'A'], [4, 'G'], [2, 5], [3, 6]]
# 0.8018743475103691
# -11.365258946262268 likelihood initial state
# -9.892965718468004 posterior sample average likelihood
# -10.688444881964983 prior sample average likelihood
# [['A', 'A'], ['T', 'A'], [2, 'A'], ['T', 3], ['C', 'G'], [4, 5], [1, 6]]
# 0.8330734798503199
# -12.228712564669838 likelihood initial state
# -10.332403484110042 posterior sample average likelihood
# -11.156337010096642 prior sample average likelihood
# [['A', 'A'], ['C', 'T'], [2, 'C'], ['C', 'A'], [4, 1], ['A', 3], [5, 6]]
# 0.7946301467122902
# -11.451548947040097 likelihood initial state
# -9.937139357581339 posterior sample average likelihood
# -10.824162112614726 prior sample average likelihood
# [['G', 'T'], ['T', 'T'], ['G', 'A'], [1, 'A'], [3, 4], ['G', 5], [2, 6]]
# 0.7735754776521166
# -10.826150896770358 likelihood initial state
# -10.22162323200726 posterior sample average likelihood
# -11.104239436534428 prior sample average likelihood
# [['A', 'C'], ['A', 'A'], ['T', 'A'], [1, 2], [4, 'T'], ['C', 5], [3, 6]]
# 0.7993990398983305
# -10.841547791566375 likelihood initial state
# -10.077019160039352 posterior sample average likelihood
# -11.06843263403044 prior sample average likelihood
# [['T', 'T'], ['T', 1], ['A', 'A'], [3, 'G'], [2, 4], ['A', 5], ['G', 6]]
# 0.7762185186183181
# -10.87500338329526 likelihood initial state
# -10.271395964405356 posterior sample average likelihood
# -11.176665909166346 prior sample average likelihood
# [['C', 'C'], ['A', 'A'], ['A', 1], [2, 'A'], ['C', 'C'], [5, 4], [3, 6]]
# 0.7635471928394936
# -10.558450297725622 likelihood initial state
# -9.46054528097623 posterior sample average likelihood
# -10.278183332470771 prior sample average likelihood
# [['C', 'C'], ['A', 'T'], [2, 1], ['G', 'G'], ['A', 4], ['G', 3], [5, 6]]
# 0.8104257237357927
# -12.054143414018709 likelihood initial state
# -10.753128774198688 posterior sample average likelihood
# -11.545025008853981 prior sample average likelihood
# [['G', 'G'], ['G', 'T'], [2, 1], ['G', 'T'], [3, 'G'], ['A', 4], [5, 6]]
# 0.8486708888122811
# -10.064910615039574 likelihood initial state
# -9.395472066656703 posterior sample average likelihood
# -10.657304266642589 prior sample average likelihood
# [['C', 'C'], ['T', 'A'], ['T', 2], ['A', 'T'], [1, 'C'], [3, 4], [5, 6]]
# 0.7844869059197324
# -11.230014909031569 likelihood initial state
# -10.252328222143767 posterior sample average likelihood
# -11.135052262105049 prior sample average likelihood
# [['C', 'C'], ['C', 'A'], ['T', 'T'], [1, 2], [3, 'G'], ['A', 5], [4, 6]]
# 0.8148526813696089
# -12.009398793469884 likelihood initial state
# -10.692911526108382 posterior sample average likelihood
# -11.661260975174548 prior sample average likelihood
# [['T', 'T'], ['G', 'T'], [2, 1], ['C', 3], ['A', 'A'], ['A', 5], [4, 6]]
# 0.8049209548808773
# -12.424537473459269 likelihood initial state
# -10.487218317024272 posterior sample average likelihood
# -11.421430291043489 prior sample average likelihood
# [['G', 'G'], ['G', 'G'], ['G', 'G'], [3, 2], [4, 'A'], [5, 1], ['C', 6]]
# 0.9101170163432671
# -10.019330421243161 likelihood initial state
# -9.166801013973796 posterior sample average likelihood
# -10.016514565348835 prior sample average likelihood
# [['A', 'T'], ['A', 1], ['C', 'C'], [2, 'A'], [3, 'G'], [4, 5], ['T', 6]]
# 0.8105589554571178
# -12.62723450537512 likelihood initial state
# -10.760299052566122 posterior sample average likelihood
# -11.561636215665503 prior sample average likelihood
# [['G', 'T'], [1, 'T'], ['A', 'G'], [2, 3], ['T', 'C'], [5, 'C'], [4, 6]]
# 0.8190554447888534
# -10.919003726501321 likelihood initial state
# -10.738621683023345 posterior sample average likelihood
# -11.473091750304587 prior sample average likelihood
# [['T', 'T'], ['T', 1], ['T', 2], ['G', 'A'], ['T', 4], [3, 5], ['C', 6]]
# 0.8775779312235343
# -10.80753549158343 likelihood initial state
# -9.861053290765405 posterior sample average likelihood
# -10.56672177072095 prior sample average likelihood
# [['T', 'T'], ['C', 'C'], ['C', 'T'], [2, 1], [3, 4], ['A', 5], ['G', 6]]
# 0.805635074304552
# -11.710975470599001 likelihood initial state
# -10.41157623307155 posterior sample average likelihood
# -11.418843008761785 prior sample average likelihood
# [['T', 'C'], [1, 'T'], ['T', 'A'], ['C', 'A'], [2, 3], [5, 4], ['C', 6]]
# 0.7719003332016102
# -12.163712466584318 likelihood initial state
# -10.234143977742182 posterior sample average likelihood
# -11.157730470436356 prior sample average likelihood
# [['C', 'C'], ['C', 'C'], ['T', 2], [1, 'A'], ['G', 4], [5, 'C'], [3, 6]]
# 0.882148662904119
# -11.228596184736249 likelihood initial state
# -9.79793049428327 posterior sample average likelihood
# -10.5033053441097 prior sample average likelihood
# [['T', 'T'], ['A', 'A'], ['T', 'T'], [3, 1], [4, 'A'], [5, 2], ['A', 6]]
# 0.7716435657951514
# -11.799870418591905 likelihood initial state
# -9.429807937613779 posterior sample average likelihood
# -10.25426948844027 prior sample average likelihood
# [['A', 'A'], ['C', 'C'], ['A', 1], [2, 'C'], ['T', 'T'], [3, 4], [5, 6]]
# 0.7769680533488601
# -9.56017543240526 likelihood initial state
# -10.218302206696254 posterior sample average likelihood
# -11.141319131208888 prior sample average likelihood
# [['C', 'G'], ['C', 'A'], ['T', 2], ['C', 1], ['G', 3], [4, 'A'], [5, 6]]
# 0.8079603373379882
# -10.192199420403181 likelihood initial state
# -10.67718845917252 posterior sample average likelihood
# -11.620892464156903 prior sample average likelihood
# [['T', 'T'], ['T', 'C'], ['T', 2], ['A', 3], ['G', 'A'], [5, 1], [4, 6]]
# 0.8300031884716372
# -11.971097551403604 likelihood initial state
# -10.21256655326705 posterior sample average likelihood
# -11.061892301447305 prior sample average likelihood
# [['A', 'A'], ['G', 'C'], ['A', 'C'], [3, 'A'], [4, 2], [5, 'A'], [1, 6]]
# 0.83464250488594
# -11.538710072810579 likelihood initial state
# -9.60881961023941 posterior sample average likelihood
# -10.456684267755664 prior sample average likelihood
# [['T', 'T'], ['A', 'A'], ['C', 'T'], [2, 'T'], [1, 3], [5, 4], ['A', 6]]
# 0.7982774460001925
# -12.38765022382926 likelihood initial state
# -9.941931667232945 posterior sample average likelihood
# -10.728218266356446 prior sample average likelihood
# [['A', 'A'], ['A', 'G'], ['C', 'C'], [2, 'T'], [4, 1], [5, 3], ['G', 6]]
# 0.8068954857614448
# -12.734452268307525 likelihood initial state
# -10.750611735309736 posterior sample average likelihood
# -11.551686602536366 prior sample average likelihood
# [['G', 'G'], ['T', 'A'], ['T', 2], [1, 'C'], ['C', 3], [4, 5], ['C', 6]]
# 0.8162355683966015
# -10.969906597153944 likelihood initial state
# -10.804575514140673 posterior sample average likelihood
# -11.574710758383723 prior sample average likelihood
# [['A', 'A'], ['A', 'G'], [2, 1], ['C', 'A'], ['G', 4], ['T', 5], [3, 6]]
# 0.8279129640016712
# -11.738055497584357 likelihood initial state
# -10.328467826768657 posterior sample average likelihood
# -11.279215595153728 prior sample average likelihood
# [['A', 'A'], ['T', 'C'], ['G', 'G'], ['C', 3], [2, 4], ['G', 5], [1, 6]]
# 0.8105045302288519
# -11.115311428313923 likelihood initial state
# -10.815448777158 posterior sample average likelihood
# -11.546457660637886 prior sample average likelihood
# [['G', 'T'], ['T', 'T'], ['T', 'T'], ['G', 'A'], [2, 4], [3, 1], [5, 6]]
# 0.8460728151002924
# -9.534205428464153 likelihood initial state
# -9.712806566904444 posterior sample average likelihood
# -10.496168495486629 prior sample average likelihood
# [['T', 'G'], ['G', 'G'], ['G', 2], [1, 'G'], [4, 3], [5, 'T'], ['T', 6]]
# 0.8082973730487388
# -12.106342662870224 likelihood initial state
# -9.337544276726259 posterior sample average likelihood
# -10.078409348631338 prior sample average likelihood
# [['A', 'A'], ['G', 'A'], [1, 'G'], ['G', 3], [2, 'T'], [4, 'T'], [5, 6]]
# 0.7771312604298752
# -12.044272681690336 likelihood initial state
# -10.198230734904747 posterior sample average likelihood
# -11.11805411696938 prior sample average likelihood
# [['T', 'T'], ['A', 'T'], [2, 1], ['A', 'A'], ['C', 3], [5, 'G'], [4, 6]]
# 0.8005209190993948
# -12.551905655209424 likelihood initial state
# -10.388942379720481 posterior sample average likelihood
# -11.480937341053242 prior sample average likelihood
# [['A', 'T'], ['T', 'A'], ['T', 'T'], [3, 1], [2, 'G'], [4, 'T'], [5, 6]]
# 0.845734404547839
# -9.59132773961328 likelihood initial state
# -9.644969836807492 posterior sample average likelihood
# -10.450701705791928 prior sample average likelihood
# [['G', 'G'], ['C', 'A'], ['G', 1], ['T', 'T'], [2, 4], ['A', 5], [3, 6]]
# 0.8051013872492163
# -11.193618836646356 likelihood initial state
# -10.625911821489256 posterior sample average likelihood
# -11.607868897261893 prior sample average likelihood
# [['G', 'A'], ['A', 'C'], ['A', 'A'], ['T', 2], ['G', 1], [4, 5], [3, 6]]
# 0.8279273138553698
# -11.55409147685272 likelihood initial state
# -10.236296920590815 posterior sample average likelihood
# -11.182049007706503 prior sample average likelihood
# [['C', 'C'], ['T', 'A'], ['T', 1], ['C', 3], ['A', 2], [5, 4], ['A', 6]]
# 0.7806114402617652
# -10.840496856921208 likelihood initial state
# -10.307725354602264 posterior sample average likelihood
# -11.208947939194688 prior sample average likelihood
# [['G', 'G'], ['G', 'T'], ['T', 1], ['A', 2], ['T', 3], ['A', 5], [4, 6]]
# 0.7754721161437897
# -10.253370696989643 likelihood initial state
# -10.28310620844966 posterior sample average likelihood
# -11.196380724452826 prior sample average likelihood
# [['A', 'C'], [1, 'C'], ['C', 'T'], ['G', 3], [2, 'T'], [4, 5], ['G', 6]]
# 0.8012218889087537
# -12.138427597917216 likelihood initial state
# -10.79395457954349 posterior sample average likelihood
# -11.621418890074466 prior sample average likelihood
# [['T', 'T'], ['A', 'A'], ['T', 'A'], ['C', 3], [4, 2], [1, 5], ['T', 6]]
# 0.7954567078050792
# -10.614871165898071 likelihood initial state
# -9.944518389716809 posterior sample average likelihood
# -10.688385896476252 prior sample average likelihood
# [['T', 'T'], ['C', 'T'], ['C', 2], ['C', 1], ['C', 'C'], [3, 4], [5, 6]]
# 0.7990711423687928
# -11.606042351203124 likelihood initial state
# -9.36929843358694 posterior sample average likelihood
# -10.162359782135606 prior sample average likelihood
# [['C', 'C'], ['C', 'C'], ['C', 2], ['G', 'G'], [4, 1], [5, 3], ['C', 6]]
# 0.8776469474989662
# -10.693793820551218 likelihood initial state
# -9.022379160924025 posterior sample average likelihood
# -9.709031420852709 prior sample average likelihood
# [['T', 'T'], ['A', 'T'], ['A', 1], ['T', 2], ['G', 3], [4, 5], ['G', 6]]
# 0.7999444085038036
# -11.345921993113054 likelihood initial state
# -10.03538497209082 posterior sample average likelihood
# -11.08781068176903 prior sample average likelihood
# [['A', 'G'], ['A', 'A'], ['G', 'A'], [2, 3], ['T', 1], [5, 4], ['A', 6]]
# 0.8360141410760016
# -10.237061555301398 likelihood initial state
# -9.713095925373494 posterior sample average likelihood
# -10.561747290472194 prior sample average likelihood
# [['A', 'A'], ['A', 'A'], ['C', 2], [1, 'G'], [3, 4], [5, 'T'], ['C', 6]]
# 0.831149901673933
# -10.257472776310383 likelihood initial state
# -10.353873976342797 posterior sample average likelihood
# -11.122054801171693 prior sample average likelihood
# [['A', 'A'], [1, 'A'], ['G', 'T'], [2, 'A'], ['C', 3], [5, 4], ['T', 6]]
# 0.8279032374651488
# -11.895592822419932 likelihood initial state
# -10.437694623941884 posterior sample average likelihood
# -11.107050237809531 prior sample average likelihood
# [['A', 'A'], ['C', 'C'], ['C', 'C'], ['A', 'A'], [3, 1], [4, 5], [2, 6]]
# 0.7707345462396232
# -10.178063391943299 likelihood initial state
# -9.462103098398169 posterior sample average likelihood
# -10.242104730221117 prior sample average likelihood
# [['A', 'C'], ['A', 'T'], [1, 2], ['G', 3], [4, 'C'], ['C', 5], ['T', 6]]
# 0.801868105513597
# -12.319984077435457 likelihood initial state
# -10.61666562023906 posterior sample average likelihood
# -11.577045092447051 prior sample average likelihood
# [['A', 'G'], [1, 'G'], ['G', 2], [3, 'A'], [4, 'A'], ['G', 'T'], [5, 6]]
# 0.7900613042681353
# -12.064146337391167 likelihood initial state
# -9.905802168274086 posterior sample average likelihood
# -10.747619065466832 prior sample average likelihood

# %%
plt.hist(origin_likelihood, label='origin', alpha = .7)
# plt.hist(posterior_average, label = 'posterior', alpha = .7)
plt.hist(prior_average, label ='prior', alpha = .7)
plt.legend()

# plt.hist(np.log(posterior_ll))

#sample 7000 trees from posterior, likelihood is the log of the average l ikelihood of all the trees

# %%
np.log(likelihood(init_state, 7))
# Out:
# -12.38361610271114

# %%
# for tree in posterior_sampled:
# print(len(posterior_sampled))
# np.mean(origin_likelihood), np.mean(prior_average), np.mean(posterior_average)

# init_state
prior_average
# Out:
# [-10.109840259926145,
#  -11.673681449457558,
#  -10.481052355971512,
#  -10.995044076923907,
#  -10.08293263072388,
#  -10.95154495394259,
#  -11.536272143073584,
#  -11.101546505360846,
#  -10.236311291271507,
#  -11.622545079549718]

# %%
prior_sampled = []
states = init_state
# states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]
# coalescent_times = [.2,.5,.6,.8,1.3,1.9,2.9]
for i in range(len(posterior_sampled)):
    prev_state = copy.deepcopy(states)
    prior_sampled.append(prev_state)
    state_flag = markov_chain_forward(n+1,states)
    while not state_flag:
        state_flag = markov_chain_forward(n+1,states)

# %%
posterior_ll = []
ct = 0
for tree in posterior_sampled:
    ct += 1
    posterior_ll.append(likelihood(tree, 7))
    if ct %1000==0:
        print(ct//1000, 'iter_')
# Out:
# 1 iter_
# 2 iter_
# 3 iter_
# 4 iter_
# 5 iter_
# 6 iter_
# 7 iter_

# %%
prior_ll = []
for tree in prior_sampled:
    prior_ll.append(likelihood(tree, 7))

# %%
posterior_ll = np.array(posterior_ll)
prior_ll = np.array(prior_ll)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
plt.hist(np.log(posterior_ll),alpha = .5, label = 'posterior sampled')
plt.hist(np.log(prior_ll), alpha = .5, label = 'prior sampled')
plt.legend()
plt.xlabel('log likelihood')
# Out:
# Text(0.5, 0, 'log likelihood')

# %%
states = init_state
print(likelihood(states, 7), 'likelihood initial state')

print(np.mean(posterior_ll), 'posterior sample average likelihood')
print(np.mean(prior_ll), 'prior sample average likelihood')


mean_
[]
# Out:
# 4.388133629336888e-05 likelihood initial state
# 3.7214891553144624e-05 posterior sample average likelihood
# 1.5954888795888463e-05 prior sample average likelihood

# %%
np.log(likelihood(posterior_sampled[np.argmax(posterior_ll)], 7))
# Out:
# -8.354450743754589

# %%
posterior_sampled[np.argmax(posterior_ll)]
# Out:
# [['A', 'A'], ['A', 1], ['C', 'C'], [3, 'C'], ['G', 'G'], [5, 4], [2, 6]]

# %%
states = [['G', 'G'],['C', 'A'], ['C', 1], ['C', 2], ['A', 4], [3,5], ['A', 6]]

# %%
coalescent_times
###fix coalescent time, fix tree, simulation the data
# Out:
# [0.2, 0.5, 0.6, 0.8, 1.3, 1.9, 2.9]

# %%
q
# Out:
# array([[-1.        ,  0.33333333,  0.33333333,  0.33333333],
#        [ 0.33333333, -1.        ,  0.33333333,  0.33333333],
#        [ 0.33333333,  0.33333333, -1.        ,  0.33333333],
#        [ 0.33333333,  0.33333333,  0.33333333, -1.        ]])

# %%
Pij(1, evecs, evals,evec_inv)
# Out:
# array([[0.44769785, 0.18410072, 0.18410072, 0.18410072],
#        [0.18410072, 0.44769785, 0.18410072, 0.18410072],
#        [0.18410072, 0.18410072, 0.44769785, 0.18410072],
#        [0.18410072, 0.18410072, 0.18410072, 0.44769785]])

# %% [markdown]
# ### variational using the prior distance function
# ### using swapping markov chain, (run again or improve time efficiency) TODO..
# ### getting stuck and sampling
#
#
# #### starting about thinking branch length , hmc etc.. (gradients on branch length), marginalized on branch length (variational inference relying on automatic differentiation) another latent layer (one layer is effective population size, one layer is coalescent time)
#
# gradient for coalescent time and likelihood
# biggest problem for HMC, tree is easy to construct. cannot propose to have negative branch length (one proposal increasing decreasing branch length (negative branch length)), parmaterice increment. keep step size of Hamiltonian.
#
# problem to compute the gradient, they use estimate of gradient, and improve the estimation.
# out win a problem that cannot compute the gradient
#
# black-box
# simulated annealling, distance, exponential
#
# doing greedy search
#
# fixed unlabelled tree, uniformly labelling
# distribution on = distribution of unlabelled * uniform
# MCMC (save likelihood and posterior at each iteration)

# %%
np.log(np.mean(posterior_ll))
# Out:
# -10.21916362447655

# %% [markdown]
# MCMC()
# ###simulate data from the model, fix one tree, simulate data, compute the likelihood of different trees, hopefully convex function, with a peak on the simulated trees.
#
# have a tree, needs to compute transition probability
#
# matrix exponential, conditional on time, look at the corresponding row to
# sample multinomial by row value
#
# simulate with a lot of possible mutations (high mutation rate).
